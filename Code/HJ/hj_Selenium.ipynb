# %%
from selenium import webdriver
import time
import warnings
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.common.keys import Keys

warnings.filterwarnings(action='ignore')

# %%
# url = "https://kind.krx.co.kr/disclosure/details.do?method=searchDetailsMain#viewer"

# driver = webdriver.Chrome(r"C:\Users\sally\OneDrive\바탕 화면\chromedriver.exe")
# driver.get(url)
# driver.find_element_by_id('rKosdaq').click() #코스닥 선택
# time.sleep(0.3)
# driver.find_element_by_xpath('//*[@id="business"]/option[4]').click()   #업종 - 제조업 선택
# time.sleep(0.3)
# ##########################



# driver.find_element_by_id("fromDate").click()
# time.sleep(0.3)

# driver.double_click(on_element = "fromDate")
# time.sleep(0.3)

# ################
# driver.find_element_by_xpath('//*[@id="ui-datepicker-div"]/div/div/select[1]/option[1]').click()
# time.sleep(0.3)
# driver.find_element_by_xpath('//*[@id="ui-datepicker-div"]/div/div/select[2]/option[12]').click()
# time.sleep(0.3)
# driver.find_element_by_xpath('//*[@id="ui-datepicker-div"]/table/tbody/tr[1]/td[7]/a').click()
# time.sleep(0.3)
# txtItemName = driver.find_element_by_id("toDate").click()
# time.sleep(0.3)
# driver.find_element_by_xpath('//*[@id="ui-datepicker-div"]/div/div/select[1]/option[12]').click()
# time.sleep(0.3)
# driver.find_element_by_xpath('//*[@id="ui-datepicker-div"]/div/div/select[2]/option[14]').click()
# time.sleep(0.3)
# driver.find_element_by_xpath('//*[@id="ui-datepicker-div"]/table/tbody/tr[5]/td[3]/a').click()
# time.sleep(0.3)
# driver.find_element_by_xpath('//*[@id="bfrDsclsType"]').click() # 공시유형 초기화 체크 해제
# time.sleep(0.3)
# driver.find_element_by_xpath('//*[@id="dsclsType01"]').click() # 수시공시 클릭
# time.sleep(0.3)
# driver.find_element_by_xpath('//*[@id="dsclsLayer01_11"]').click() # 대표이사변경
# time.sleep(0.3)
# driver.find_element_by_xpath('//*[@id="dsclsLayer01_14"]').click() # 벌금/과징금/행정조치
# time.sleep(0.3)
# driver.find_element_by_xpath('//*[@id="dsclsLayer01_19"]').click() # 사채/대출원리금미지급
# time.sleep(0.3)
# driver.find_element_by_xpath('//*[@id="dsclsLayer01_23"]').click() # 소송
# time.sleep(0.3)
# driver.find_element_by_xpath('//*[@id="dsclsLayer01_27"]').click() # 어음 위·변조
# time.sleep(0.3)
# driver.find_element_by_xpath('//*[@id="dsclsLayer01_34"]').click() # 자본잠식/매출액미만등
# time.sleep(0.3)
# driver.find_element_by_xpath('//*[@id="dsclsLayer01_37"]').click() # 재해발생
# time.sleep(0.3)
# driver.find_element_by_xpath('//*[@id="dsclsLayer01_65"]').click() # 회계처리기준위반등
# time.sleep(0.3)
# driver.find_element_by_xpath('//*[@id="dsclsLayer01_63"]').click() # 해산/파산
# time.sleep(0.3)
# driver.find_element_by_xpath('//*[@id="dsclsLayer01_66"]').click() # 회생절차
# time.sleep(0.3)
# driver.find_element_by_xpath('//*[@id="dsclsLayer01_67"]').click() # 횡령,배임
# time.sleep(0.3)
# driver.find_element_by_xpath('//*[@id="currentPageSize"]/option[4]').click()
# time.sleep(0.3)
# driver.find_element_by_xpath('//*[@id="searchForm"]/section[1]/div/div[3]/a[1]').click() # 검색
# time.sleep(0.5)
# driver.find_element_by_xpath('//*[@id="searchForm"]/section[1]/div/div[3]/a[2]').click() # 엑셀로 다운로드
# time.sleep(1)

# %%
url = "https://kind.krx.co.kr/disclosure/details.do?method=searchDetailsMain#viewer"

driver = webdriver.Chrome(r"C:\apps\Ubion-CorporateBankruptcyAnalysis\chromedriver.exe")
driver.get(url)
action = ActionChains(driver)

driver.find_element_by_id('rKosdaq').click() #코스닥 선택
time.sleep(0.3)
driver.find_element_by_xpath('//*[@id="business"]/option[4]').click()   #업종 - 제조업 선택
time.sleep(0.3)





driver.find_element_by_xpath('//*[@id="bfrDsclsType"]').click() # 공시유형 초기화 체크 해제
time.sleep(0.3)
driver.find_element_by_xpath('//*[@id="dsclsType01"]').click() # 수시공시 클릭
time.sleep(0.3)
driver.find_element_by_xpath('//*[@id="dsclsLayer01_11"]').click() # 대표이사변경
time.sleep(0.3)
driver.find_element_by_xpath('//*[@id="dsclsLayer01_14"]').click() # 벌금/과징금/행정조치
time.sleep(0.3)
driver.find_element_by_xpath('//*[@id="dsclsLayer01_19"]').click() # 사채/대출원리금미지급
time.sleep(0.3)
driver.find_element_by_xpath('//*[@id="dsclsLayer01_23"]').click() # 소송
time.sleep(0.3)
driver.find_element_by_xpath('//*[@id="dsclsLayer01_27"]').click() # 어음 위·변조
time.sleep(0.3)
driver.find_element_by_xpath('//*[@id="dsclsLayer01_34"]').click() # 자본잠식/매출액미만등
time.sleep(0.3)
driver.find_element_by_xpath('//*[@id="dsclsLayer01_37"]').click() # 재해발생
time.sleep(0.3)
driver.find_element_by_xpath('//*[@id="dsclsLayer01_65"]').click() # 회계처리기준위반등
time.sleep(0.3)
driver.find_element_by_xpath('//*[@id="dsclsLayer01_63"]').click() # 해산/파산
time.sleep(0.3)
driver.find_element_by_xpath('//*[@id="dsclsLayer01_66"]').click() # 회생절차
time.sleep(0.3)
driver.find_element_by_xpath('//*[@id="dsclsLayer01_67"]').click() # 횡령,배임
time.sleep(0.3)
driver.find_element_by_xpath('//*[@id="currentPageSize"]/option[4]').click() # 100개씩 보기 선택
time.sleep(0.3)





# 날짜 선택 부분 (반복문으로 만들어야해서 맨 아래에 둘 것)
year=2000
for i in range((2020-2000)//3+1):
    elem1 = driver.find_element_by_name("fromDate")  #커서를 두겠다는 의미
    time.sleep(0.3)
    elem1.clear()
    time.sleep(0.3)
    elem1.send_keys("{0}-01-01".format(year))
    time.sleep(0.3)
    elem1.send_keys(Keys.RETURN)
    time.sleep(0.3)
    elem1.send_keys("{0}-01-01".format(year))
    time.sleep(0.3)

    elem2 = driver.find_element_by_name("toDate")  #커서를 두겠다는 의미
    time.sleep(0.3)
    elem2.clear()
    time.sleep(0.3)
    elem2.send_keys("{0}-12-31".format(year+2))
    time.sleep(0.3)
    elem2.send_keys(Keys.RETURN)
    time.sleep(0.3)
    elem2.send_keys("{0}-12-31".format(year+2))
    time.sleep(0.3)

    driver.find_element_by_xpath('//*[@id="searchForm"]/section[1]/div/div[3]/a[1]').click() # 검색
    time.sleep(0.5)
    
    #엑셀 for문    
    #전체 페이지 수 
    full_page = driver.find_element_by_xpath('//*[@id="main-contents"]/section[2]/div[2]/em')
    time.sleep(5)
    full_page = full_page.text.astype('int')
    time.sleep(5)
    page_len = full_page//100 + 1
    j=0
    for j in range(page_len):
        driver.find_element_by_xpath('//*[@id="searchForm"]/section[1]/div/div[3]/a[2]').click() # 엑셀로 다운로드
        time.sleep(1)
        driver.find_element_by_xpath('//*[@id="main-contents"]/section[2]/div[1]/a[6]').click()
        time.sleep(0.3)
    
    year=year+1
# Out:
# ---------------------------------------------------------------------------
# StaleElementReferenceException            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16924/2432506666.py in <module>
#      79     full_page = driver.find_element_by_xpath('//*[@id="main-contents"]/section[2]/div[2]/em')
#      80     time.sleep(5)
# ---> 81     full_page = full_page.text.astype('int')
#      82     time.sleep(5)
#      83     page_len = full_page//100 + 1
#
# C:\venvs\myproject\lib\site-packages\selenium\webdriver\remote\webelement.py in text(self)
#      75     def text(self) -> str:
#      76         """The text of the element."""
# ---> 77         return self._execute(Command.GET_ELEMENT_TEXT)['value']
#      78
#      79     def click(self) -> None:
#
# C:\venvs\myproject\lib\site-packages\selenium\webdriver\remote\webelement.py in _execute(self, command, params)
#     708             params = {}
#     709         params['id'] = self._id
# --> 710         return self._parent.execute(command, params)
#     711
#     712     def find_element(self, by=By.ID, value=None):
#
# C:\venvs\myproject\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     422         response = self.command_executor.execute(driver_command, params)
#     423         if response:
# --> 424             self.error_handler.check_response(response)
#     425             response['value'] = self._unwrap_value(
#     426                 response.get('value', None))
#
# C:\venvs\myproject\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     245                 alert_text = value['alert'].get('text')
#     246             raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 247         raise exception_class(message, screen, stacktrace)
#     248
#     249     def _value_or_default(self, obj: Mapping[_KT, _VT], key: _KT, default: _VT) -> _VT:
#
# StaleElementReferenceException: Message: stale element reference: element is not attached to the page document
#   (Session info: chrome=96.0.4664.45)
# Stacktrace:
# Backtrace:
# 	Ordinal0 [0x008F6903+2517251]
# 	Ordinal0 [0x0088F8E1+2095329]
# 	Ordinal0 [0x00792848+1058888]
# 	Ordinal0 [0x00794F44+1068868]
# 	Ordinal0 [0x00794E0E+1068558]
# 	Ordinal0 [0x00795070+1069168]
# 	Ordinal0 [0x007B8DE0+1215968]
# 	Ordinal0 [0x007D64D3+1336531]
# 	Ordinal0 [0x007B3A36+1194550]
# 	Ordinal0 [0x007D65BA+1336762]
# 	Ordinal0 [0x007E5BBF+1399743]
# 	Ordinal0 [0x007D639B+1336219]
# 	Ordinal0 [0x007B27A7+1189799]
# 	Ordinal0 [0x007B3609+1193481]
# 	GetHandleVerifier [0x00A85904+1577972]
# 	GetHandleVerifier [0x00B30B97+2279047]
# 	GetHandleVerifier [0x00986D09+534521]
# 	GetHandleVerifier [0x00985DB9+530601]
# 	Ordinal0 [0x00894FF9+2117625]
# 	Ordinal0 [0x008998A8+2136232]
# 	Ordinal0 [0x008999E2+2136546]
# 	Ordinal0 [0x008A3541+2176321]
# 	BaseThreadInitThunk [0x74E36739+25]
# 	RtlGetFullPathName_UEx [0x76EF8AFF+1215]
# 	RtlGetFullPathName_UEx [0x76EF8ACD+1165]

# %%
url = "https://kind.krx.co.kr/disclosure/details.do?method=searchDetailsMain#viewer"

driver = webdriver.Chrome(r"C:\apps\Ubion-CorporateBankruptcyAnalysis\chromedriver.exe")
driver.get(url)
action = ActionChains(driver)


time.sleep(5)
full_page = driver.find_element_by_xpath('//*[@id="main-contents"]/section[2]/div[2]/em')
time.sleep(5)
print(full_page.text)
print(full_page)
# Out:
# 13,119

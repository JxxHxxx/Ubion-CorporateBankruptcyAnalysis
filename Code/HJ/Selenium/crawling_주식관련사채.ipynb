# %% [markdown]
# # **markdown 정리 미완!!!!**

# %%
from selenium import webdriver
import time
import warnings
from selenium.webdriver.common.keys import Keys

import time
from tqdm import tqdm


warnings.filterwarnings(action='ignore')

# %% [markdown]
# - 아래 주석은 JH의 코드 참조

# %%
# url = "https://kind.krx.co.kr/disclosure/details.do?method=searchDetailsMain#viewer"

# driver = webdriver.Chrome(r"C:\Users\sally\OneDrive\바탕 화면\chromedriver.exe")
# driver.get(url)
# driver.find_element_by_id('rKosdaq').click() #코스닥 선택
# time.sleep(0.3)
# driver.find_element_by_xpath('//*[@id="business"]/option[4]').click()   #업종 - 제조업 선택
# time.sleep(0.3)
# driver.find_element_by_id("fromDate").click()
# time.sleep(0.3)
# driver.double_click(on_element = "fromDate")
# time.sleep(0.3)
# driver.find_element_by_xpath('//*[@id="ui-datepicker-div"]/div/div/select[1]/option[1]').click()
# time.sleep(0.3)
# driver.find_element_by_xpath('//*[@id="ui-datepicker-div"]/div/div/select[2]/option[12]').click()
# time.sleep(0.3)
# driver.find_element_by_xpath('//*[@id="ui-datepicker-div"]/table/tbody/tr[1]/td[7]/a').click()
# time.sleep(0.3)
# txtItemName = driver.find_element_by_id("toDate").click()
# time.sleep(0.3)
# driver.find_element_by_xpath('//*[@id="ui-datepicker-div"]/div/div/select[1]/option[12]').click()
# time.sleep(0.3)
# driver.find_element_by_xpath('//*[@id="ui-datepicker-div"]/div/div/select[2]/option[14]').click()
# time.sleep(0.3)
# driver.find_element_by_xpath('//*[@id="ui-datepicker-div"]/table/tbody/tr[5]/td[3]/a').click()
# time.sleep(0.3)
# driver.find_element_by_xpath('//*[@id="bfrDsclsType"]').click() # 공시유형 초기화 체크 해제
# time.sleep(0.3)
# driver.find_element_by_xpath('//*[@id="dsclsType01"]').click() # 수시공시 클릭
# time.sleep(0.3)
# driver.find_element_by_xpath('//*[@id="dsclsLayer01_11"]').click() # 대표이사변경
# time.sleep(0.3)
# driver.find_element_by_xpath('//*[@id="dsclsLayer01_14"]').click() # 벌금/과징금/행정조치
# time.sleep(0.3)
# driver.find_element_by_xpath('//*[@id="dsclsLayer01_19"]').click() # 사채/대출원리금미지급
# time.sleep(0.3)
# driver.find_element_by_xpath('//*[@id="dsclsLayer01_23"]').click() # 소송
# time.sleep(0.3)
# driver.find_element_by_xpath('//*[@id="dsclsLayer01_27"]').click() # 어음 위·변조
# time.sleep(0.3)
# driver.find_element_by_xpath('//*[@id="dsclsLayer01_34"]').click() # 자본잠식/매출액미만등
# time.sleep(0.3)
# driver.find_element_by_xpath('//*[@id="dsclsLayer01_37"]').click() # 재해발생
# time.sleep(0.3)
# driver.find_element_by_xpath('//*[@id="dsclsLayer01_65"]').click() # 회계처리기준위반등
# time.sleep(0.3)
# driver.find_element_by_xpath('//*[@id="dsclsLayer01_63"]').click() # 해산/파산
# time.sleep(0.3)
# driver.find_element_by_xpath('//*[@id="dsclsLayer01_66"]').click() # 회생절차
# time.sleep(0.3)
# driver.find_element_by_xpath('//*[@id="dsclsLayer01_67"]').click() # 횡령,배임
# time.sleep(0.3)
# driver.find_element_by_xpath('//*[@id="currentPageSize"]/option[4]').click()
# time.sleep(0.3)
# driver.find_element_by_xpath('//*[@id="searchForm"]/section[1]/div/div[3]/a[1]').click() # 검색
# time.sleep(0.5)
# driver.find_element_by_xpath('//*[@id="searchForm"]/section[1]/div/div[3]/a[2]').click() # 엑셀로 다운로드
# time.sleep(1)

# %%
url = "https://kind.krx.co.kr/disclosure/details.do?method=searchDetailsMain#viewer"

driver = webdriver.Chrome(r"C:\Users\sally\OneDrive\바탕 화면\chromedriver.exe")
driver.get(url)


driver.find_element_by_id('rKosdaq').click() #코스닥 선택
time.sleep(0.3)
#driver.find_element_by_xpath('//*[@id="business"]/option[4]').click()   #업종 - 제조업 선택
#time.sleep(0.3)
driver.find_element_by_xpath('//*[@id="bfrDsclsType"]').click() # 공시유형 초기화 체크 해제
time.sleep(0.3)
driver.find_element_by_xpath('//*[@id="dsclsType01"]').click() # 수시공시 클릭
time.sleep(0.3)
driver.find_element_by_xpath('//*[@id="dsclsLayer01_44"]').click() # 주식사채
time.sleep(0.3)


""" driver.find_element_by_xpath('//*[@id="dsclsLayer01_14"]').click() # 벌금/과징금/행정조치
time.sleep(0.3)
driver.find_element_by_xpath('//*[@id="dsclsLayer01_19"]').click() # 사채/대출원리금미지급
time.sleep(0.3)
driver.find_element_by_xpath('//*[@id="dsclsLayer01_23"]').click() # 소송
time.sleep(0.3)
driver.find_element_by_xpath('//*[@id="dsclsLayer01_27"]').click() # 어음 위·변조
time.sleep(0.3)
driver.find_element_by_xpath('//*[@id="dsclsLayer01_34"]').click() # 자본잠식/매출액미만등
time.sleep(0.3)
driver.find_element_by_xpath('//*[@id="dsclsLayer01_37"]').click() # 재해발생
time.sleep(0.3)
driver.find_element_by_xpath('//*[@id="dsclsLayer01_65"]').click() # 회계처리기준위반등
time.sleep(0.3)
driver.find_element_by_xpath('//*[@id="dsclsLayer01_63"]').click() # 해산/파산
time.sleep(0.3)
driver.find_element_by_xpath('//*[@id="dsclsLayer01_66"]').click() # 회생절차
time.sleep(0.3)
driver.find_element_by_xpath('//*[@id="dsclsLayer01_67"]').click() # 횡령,배임
time.sleep(0.3) """
driver.find_element_by_xpath('//*[@id="currentPageSize"]/option[4]').click() # 100개씩 보기 선택
time.sleep(0.3)




# 날짜 선택하는 for문 (반복문으로 만들어야해서 맨 아래에 둘 것)
year=2000
for i in range((2020-2000)+1):
    elem1 = driver.find_element_by_name("fromDate")  #커서를 두겠다는 의미
    time.sleep(0.3)
    elem1.clear()
    time.sleep(0.3)
    elem1.send_keys("{0}-01-01".format(year))
    time.sleep(0.3)
    elem1.send_keys(Keys.RETURN)
    time.sleep(0.3)
    elem1.send_keys("{0}-01-01".format(year))
    time.sleep(0.3)

    elem2 = driver.find_element_by_name("toDate")  #커서를 두겠다는 의미
    time.sleep(0.3)
    elem2.clear()
    time.sleep(0.3)
    elem2.send_keys("{0}-12-31".format(year))
    time.sleep(0.3)
    elem2.send_keys(Keys.RETURN)
    time.sleep(0.3)
    elem2.send_keys("{0}-12-31".format(year))
    time.sleep(0.3)

    driver.find_element_by_xpath('//*[@id="searchForm"]/section[1]/div/div[3]/a[1]').click() # 검색
    time.sleep(5)
    

    # 기간 내 공시 개수 text로 읽어서 int형으로 변환 후 페이지 길이 구하기
    
    full_case = driver.find_element_by_xpath('//*[@id="main-contents"]/section[2]/div[2]/em').text
    time.sleep(1)
    full_case = full_case.replace(',','')
    full_case = int(full_case)

    #print(i,'번째 테스트',full_case)
    
    time.sleep(1)
    page_len = full_case//100+1
    print(year,'년 의')
    print('총 건수는',full_case,'개 입니다')
    print('총 페이지 수는',page_len,'개 입니다.')
    time.sleep(1)
    year=year+3

"""     # 엑셀 다운받는 for문
      
    
    # 총 건수가 1000개 이상이면 다음페이지 버튼 코드에도 변동 발생 -> 이거 처리 어떻게 할지 생각
    if full_case>1000:
        for j in range()

    # 총 건수가 1000개 아래면 다음페이지 버튼 변동 없음
    elif full_case<=1000:
        for j in range()
    else:
        print('오류 발생')





    for j in range(page_len):
        print(page_len, '중', j ,'번째 시도')


        #driver.find_element_by_xpath('//*[@id="searchForm"]/section[1]/div/div[3]/a[2]').send_keys(Keys.ENTER) # 엑셀로 다운로드
        #time.sleep(3)


        print('{0} {1}'.format(j,page_len))
        time.sleep(1)


        
        driver.find_element_by_xpath('//*[@id="main-contents"]/section[2]/div[1]/a[{0}]'.format(page_len+3)).send_keys(Keys.ENTER) # 다음페이지 버튼
        time.sleep(3) """
    
    #year=year+1
# Out:
# 2000 년 의
# 총 건수는 839 개 입니다
# 총 페이지 수는 9 개 입니다.
# 2001 년 의
# 총 건수는 1107 개 입니다
# 총 페이지 수는 12 개 입니다.
# 2002 년 의
# 총 건수는 1442 개 입니다
# 총 페이지 수는 15 개 입니다.
# 2003 년 의
# 총 건수는 1393 개 입니다
# 총 페이지 수는 14 개 입니다.
# 2004 년 의
# 총 건수는 932 개 입니다
# 총 페이지 수는 10 개 입니다.
# 2005 년 의
# 총 건수는 1647 개 입니다
# 총 페이지 수는 17 개 입니다.
# 2006 년 의
# 총 건수는 1152 개 입니다
# 총 페이지 수는 12 개 입니다.
# 2007 년 의
# 총 건수는 928 개 입니다
# 총 페이지 수는 10 개 입니다.
# 2008 년 의
# 총 건수는 1131 개 입니다
# 총 페이지 수는 12 개 입니다.
# 2009 년 의
# 총 건수는 918 개 입니다
# 총 페이지 수는 10 개 입니다.
# 2010 년 의
# 총 건수는 618 개 입니다
# 총 페이지 수는 7 개 입니다.
# 2011 년 의
# 총 건수는 528 개 입니다
# 총 페이지 수는 6 개 입니다.
# 2012 년 의
# 총 건수는 405 개 입니다
# 총 페이지 수는 5 개 입니다.
# 2013 년 의
# 총 건수는 487 개 입니다
# 총 페이지 수는 5 개 입니다.
# 2014 년 의
# 총 건수는 323 개 입니다
# 총 페이지 수는 4 개 입니다.
# 2015 년 의
# 총 건수는 466 개 입니다
# 총 페이지 수는 5 개 입니다.
# 2016 년 의
# 총 건수는 896 개 입니다
# 총 페이지 수는 9 개 입니다.
# 2017 년 의
# 총 건수는 949 개 입니다
# 총 페이지 수는 10 개 입니다.
# 2018 년 의
# 총 건수는 1313 개 입니다
# 총 페이지 수는 14 개 입니다.
# 2019 년 의
# 총 건수는 1417 개 입니다
# 총 페이지 수는 15 개 입니다.
# 2020 년 의
# 총 건수는 1131 개 입니다
# 총 페이지 수는 12 개 입니다.
# '     # 엑셀 다운받는 for문\n      \n    \n    # 총 건수가 1000개 이상이면 다음페이지 버튼 코드에도 변동 발생 -> 이거 처리 어떻게 할지 생각\n    if full_case>1000:\n        for j in range()\n\n    # 총 건수가 1000개 아래면 다음페이지 버튼 변동 없음\n    elif full_case<=1000:\n        for j in range()\n    else:\n        print(\'오류 발생\')\n\n\n\n\n\n    for j in range(page_len):\n        print(page_len, \'중\', j ,\'번째 시도\')\n\n\n        #driver.find_element_by_xpath(\'//*[@id="searchForm"]/section[1]/div/div[3]/a[2]\').send_keys(Keys.ENTER) # 엑셀로 다운로드\n        #time.sleep(3)\n\n\n        print(\'{0} {1}\'.format(j,page_len))\n        time.sleep(1)\n\n\n        \n        driver.find_element_by_xpath(\'//*[@id="main-contents"]/section[2]/div[1]/a[{0}]\'.format(page_len+3)).send_keys(Keys.ENTER) # 다음페이지 버튼\n        time.sleep(3) '

# %% [markdown]
# ---

# %%
# 연습장
print(24%10)
# Out:
# 4

# %%
url = "https://kind.krx.co.kr/disclosure/details.do?method=searchDetailsMain#viewer"

driver = webdriver.Chrome(r"C:\Users\sally\OneDrive\바탕 화면\chromedriver.exe")
driver.get(url)


driver.find_element_by_id('rKosdaq').click() #코스닥 선택
time.sleep(0.3)
#driver.find_element_by_xpath('//*[@id="business"]/option[4]').click()   #업종 - 제조업 선택
#time.sleep(0.3)
driver.find_element_by_xpath('//*[@id="bfrDsclsType"]').click() # 공시유형 초기화 체크 해제
time.sleep(0.3)
driver.find_element_by_xpath('//*[@id="dsclsType01"]').click() # 수시공시 클릭
time.sleep(0.3)
driver.find_element_by_xpath('//*[@id="dsclsLayer01_44"]').click() # 주식사채
time.sleep(0.3)


""" driver.find_element_by_xpath('//*[@id="dsclsLayer01_14"]').click() # 벌금/과징금/행정조치
time.sleep(0.3)
driver.find_element_by_xpath('//*[@id="dsclsLayer01_19"]').click() # 사채/대출원리금미지급
time.sleep(0.3)
driver.find_element_by_xpath('//*[@id="dsclsLayer01_23"]').click() # 소송
time.sleep(0.3)
driver.find_element_by_xpath('//*[@id="dsclsLayer01_27"]').click() # 어음 위·변조
time.sleep(0.3)
driver.find_element_by_xpath('//*[@id="dsclsLayer01_34"]').click() # 자본잠식/매출액미만등
time.sleep(0.3)
driver.find_element_by_xpath('//*[@id="dsclsLayer01_37"]').click() # 재해발생
time.sleep(0.3)
driver.find_element_by_xpath('//*[@id="dsclsLayer01_65"]').click() # 회계처리기준위반등
time.sleep(0.3)
driver.find_element_by_xpath('//*[@id="dsclsLayer01_63"]').click() # 해산/파산
time.sleep(0.3)
driver.find_element_by_xpath('//*[@id="dsclsLayer01_66"]').click() # 회생절차
time.sleep(0.3)
driver.find_element_by_xpath('//*[@id="dsclsLayer01_67"]').click() # 횡령,배임
time.sleep(0.3) """
driver.find_element_by_xpath('//*[@id="currentPageSize"]/option[4]').click() # 100개씩 보기 선택
time.sleep(0.3)




# 날짜 선택하는 for문 (반복문으로 만들어야해서 맨 아래에 둘 것)
year=2000
for i in range((2020-2000)+1):
    elem1 = driver.find_element_by_name("fromDate")  #커서를 두겠다는 의미
    time.sleep(0.3)
    elem1.clear()
    time.sleep(0.3)
    elem1.send_keys("{0}-01-01".format(year))
    time.sleep(0.3)
    elem1.send_keys(Keys.RETURN)
    time.sleep(0.3)
    elem1.send_keys("{0}-01-01".format(year))
    time.sleep(0.3)

    elem2 = driver.find_element_by_name("toDate")  #커서를 두겠다는 의미
    time.sleep(0.3)
    elem2.clear()
    time.sleep(0.3)
    elem2.send_keys("{0}-12-31".format(year))
    time.sleep(0.3)
    elem2.send_keys(Keys.RETURN)
    time.sleep(0.3)
    elem2.send_keys("{0}-12-31".format(year))
    time.sleep(0.3)

    driver.find_element_by_xpath('//*[@id="searchForm"]/section[1]/div/div[3]/a[1]').click() # 검색
    time.sleep(5)
    

    # 기간 내 공시 개수 text로 읽어서 int형으로 변환 후 페이지 길이 구하기
    
    full_case = driver.find_element_by_xpath('//*[@id="main-contents"]/section[2]/div[2]/em').text
    time.sleep(1)
    full_case = full_case.replace(',','')
    full_case = int(full_case)

    #print(i,'번째 테스트',full_case)
    
    time.sleep(1)
    page_len = full_case//100+1


    print(year,'년 의')
    print('총 건수는',full_case,'개 입니다')
    print('총 페이지 수는',page_len,'개 입니다.')
    
    time.sleep(1)
    

    # 엑셀 다운받는 for문
      
    
    # 총 건수가 1000개 이상이면 다음페이지 버튼 코드에도 변동 발생 -> 이거 처리 어떻게 할지 생각
    if full_case>1000:
        small_page_iteration = page_len // 10           # iteration만큼 반복할때는 다음페이지 버튼에 변동없음
        small_page_left = page_len % 10                 # 10 이하 페이지 처리할때 버튼 설정 다시 해주기
        for k in range(1, small_page_iteration*10+1):        # k는 1부터 10까지 (이후도 동일 - 10개씩)
            print('전체', page_len, '중', k ,'페이지')
            #print('{0} {1}'.format(k, page_len))
            time.sleep(1)

            driver.find_element_by_xpath('//*[@id="main-contents"]/section[2]/div[1]/a[13]').send_keys(Keys.ENTER) # 다음페이지 버튼
            time.sleep(3)


        for j in range(1,small_page_left+1):
            first_button_num = 3
            print('10미만 나머지 페이지',small_page_left,'중',j,'페이지')
            #print('{0} {1}'.format(j, page_len))
            time.sleep(1)

            driver.find_element_by_xpath('//*[@id="main-contents"]/section[2]/div[1]/a[{0}]'.format(first_button_num + small_page_left)).send_keys(Keys.ENTER) # 다음페이지 버튼
            time.sleep(3)



            # //*[@id="main-contents"]/section[2]/div[1]/a[13] : 다음페이지 버튼
            # //*[@id="main-contents"]/section[2]/div[1]/a[3] : 반복한번 돌고 난 다음의 11 버튼
            # //*[@id="main-contents"]/section[2]/div[1]/a[8] : 반복 돌고 난 다음의 다음페이지 버튼

    # 총 건수가 1000개 아래면 다음페이지 버튼 변동 없음
    elif full_case<=1000:
        for j in range(1,small_page_left+1):
            print(page_len, '중', j ,'페이지')
            print('{0} {1}'.format(j,page_len))
            time.sleep(1)

            driver.find_element_by_xpath('//*[@id="main-contents"]/section[2]/div[1]/a[{0}]'.format(page_len+3)).send_keys(Keys.ENTER) # 다음페이지 버튼
            time.sleep(3)

    else:
        print('오류 발생')





    """ for j in range(page_len):
        print(page_len, '중', j ,'번째 시도')


        #driver.find_element_by_xpath('//*[@id="searchForm"]/section[1]/div/div[3]/a[2]').send_keys(Keys.ENTER) # 엑셀로 다운로드
        #time.sleep(3)


        print('{0} {1}'.format(j,page_len))
        time.sleep(1)


        
        driver.find_element_by_xpath('//*[@id="main-contents"]/section[2]/div[1]/a[{0}]'.format(page_len+3)).send_keys(Keys.ENTER) # 다음페이지 버튼
        time.sleep(3) """
    
    year=year+1
# Out:
# 2000 년 의
# 총 건수는 839 개 입니다
# 총 페이지 수는 9 개 입니다.
# 9 중 0 번째 시도
# 0 9
# 9 중 1 번째 시도
# 1 9
# 9 중 2 번째 시도
# 2 9
# 9 중 3 번째 시도
# 3 9
# 9 중 4 번째 시도
# 4 9
# 9 중 5 번째 시도
# 5 9
# 9 중 6 번째 시도
# 6 9
# 9 중 7 번째 시도
# 7 9
# 9 중 8 번째 시도
# 8 9
# 2001 년 의
# 총 건수는 1107 개 입니다
# 총 페이지 수는 12 개 입니다.
# 전체 12 중 1 페이지
# 전체 12 중 2 페이지
# 전체 12 중 3 페이지
# 전체 12 중 4 페이지
# 전체 12 중 5 페이지
# 전체 12 중 6 페이지
# 전체 12 중 7 페이지
# 전체 12 중 8 페이지
# 전체 12 중 9 페이지
# 전체 12 중 10 페이지
# 10미만 나머지 페이지 2 중 1 페이지
# 10미만 나머지 페이지 2 중 2 페이지
# 2002 년 의
# 총 건수는 1442 개 입니다
# 총 페이지 수는 15 개 입니다.
# 전체 15 중 1 페이지
# 전체 15 중 2 페이지
# 전체 15 중 3 페이지
# 전체 15 중 4 페이지
# 전체 15 중 5 페이지
# 전체 15 중 6 페이지
# 전체 15 중 7 페이지
# 전체 15 중 8 페이지
# 전체 15 중 9 페이지
# 전체 15 중 10 페이지
# 10미만 나머지 페이지 5 중 1 페이지
# 10미만 나머지 페이지 5 중 2 페이지
# 10미만 나머지 페이지 5 중 3 페이지
# 10미만 나머지 페이지 5 중 4 페이지
# 10미만 나머지 페이지 5 중 5 페이지
# 2003 년 의
# 총 건수는 1393 개 입니다
# 총 페이지 수는 14 개 입니다.
# 전체 14 중 1 페이지
# 전체 14 중 2 페이지
# 전체 14 중 3 페이지
# 전체 14 중 4 페이지
# 전체 14 중 5 페이지
# 전체 14 중 6 페이지
# 전체 14 중 7 페이지
# 전체 14 중 8 페이지
# 전체 14 중 9 페이지
# 전체 14 중 10 페이지
# 10미만 나머지 페이지 4 중 1 페이지
# 10미만 나머지 페이지 4 중 2 페이지
# 10미만 나머지 페이지 4 중 3 페이지
# 10미만 나머지 페이지 4 중 4 페이지
# 2004 년 의
# 총 건수는 932 개 입니다
# 총 페이지 수는 10 개 입니다.
# 10 중 0 번째 시도
# 0 10
# 10 중 1 번째 시도
# 1 10
# 10 중 2 번째 시도
# 2 10
# 10 중 3 번째 시도
# 3 10
# 10 중 4 번째 시도
# 4 10
# 10 중 5 번째 시도
# 5 10
# 10 중 6 번째 시도
# 6 10
# 10 중 7 번째 시도
# 7 10
# 10 중 8 번째 시도
# 8 10
# 10 중 9 번째 시도
# 9 10
# 2005 년 의
# 총 건수는 1647 개 입니다
# 총 페이지 수는 17 개 입니다.
# 전체 17 중 1 페이지
# 전체 17 중 2 페이지
# 전체 17 중 3 페이지
# 전체 17 중 4 페이지
# 전체 17 중 5 페이지
# 전체 17 중 6 페이지
# 전체 17 중 7 페이지
# 전체 17 중 8 페이지
# 전체 17 중 9 페이지
# 전체 17 중 10 페이지
# 10미만 나머지 페이지 7 중 1 페이지
# 10미만 나머지 페이지 7 중 2 페이지
# 10미만 나머지 페이지 7 중 3 페이지
# 10미만 나머지 페이지 7 중 4 페이지
# 10미만 나머지 페이지 7 중 5 페이지
# 10미만 나머지 페이지 7 중 6 페이지
# 10미만 나머지 페이지 7 중 7 페이지
# 2006 년 의
# 총 건수는 1152 개 입니다
# 총 페이지 수는 12 개 입니다.
# 전체 12 중 1 페이지
# 전체 12 중 2 페이지
# 전체 12 중 3 페이지
# 전체 12 중 4 페이지
# 전체 12 중 5 페이지
# 전체 12 중 6 페이지
# 전체 12 중 7 페이지
# 전체 12 중 8 페이지
# 전체 12 중 9 페이지
# 전체 12 중 10 페이지
# 10미만 나머지 페이지 2 중 1 페이지
# 10미만 나머지 페이지 2 중 2 페이지
# 2007 년 의
# 총 건수는 928 개 입니다
# 총 페이지 수는 10 개 입니다.
# 10 중 0 번째 시도
# 0 10
# 10 중 1 번째 시도
# 1 10
# 10 중 2 번째 시도
# 2 10
# 10 중 3 번째 시도
# 3 10
# 10 중 4 번째 시도
# 4 10
# 10 중 5 번째 시도
# 5 10
# 10 중 6 번째 시도
# 6 10
# 10 중 7 번째 시도
# 7 10
# 10 중 8 번째 시도
# 8 10
# 10 중 9 번째 시도
# 9 10
# 2008 년 의
# 총 건수는 1131 개 입니다
# 총 페이지 수는 12 개 입니다.
# 전체 12 중 1 페이지
# 전체 12 중 2 페이지
# 전체 12 중 3 페이지
# 전체 12 중 4 페이지
# 전체 12 중 5 페이지
# 전체 12 중 6 페이지
# 전체 12 중 7 페이지
# 전체 12 중 8 페이지
# 전체 12 중 9 페이지
# 전체 12 중 10 페이지
# 10미만 나머지 페이지 2 중 1 페이지
# 10미만 나머지 페이지 2 중 2 페이지
# 2009 년 의
# 총 건수는 918 개 입니다
# 총 페이지 수는 10 개 입니다.
# 10 중 0 번째 시도
# 0 10
# 10 중 1 번째 시도
# 1 10
# 10 중 2 번째 시도
# 2 10
# 10 중 3 번째 시도
# 3 10
# 10 중 4 번째 시도
# 4 10
# 10 중 5 번째 시도
# 5 10
# 10 중 6 번째 시도
# 6 10
# 10 중 7 번째 시도
# 7 10
# 10 중 8 번째 시도
# 8 10
# 10 중 9 번째 시도
# 9 10
# 2010 년 의
# 총 건수는 618 개 입니다
# 총 페이지 수는 7 개 입니다.
# 7 중 0 번째 시도
# 0 7
# 7 중 1 번째 시도
# 1 7
# 7 중 2 번째 시도
# 2 7
# 7 중 3 번째 시도
# 3 7
# 7 중 4 번째 시도
# 4 7
# 7 중 5 번째 시도
# 5 7
# 7 중 6 번째 시도
# 6 7
# 2011 년 의
# 총 건수는 528 개 입니다
# 총 페이지 수는 6 개 입니다.
# 6 중 0 번째 시도
# 0 6
# 6 중 1 번째 시도
# 1 6
# 6 중 2 번째 시도
# 2 6
# 6 중 3 번째 시도
# 3 6
# 6 중 4 번째 시도
# 4 6
# 6 중 5 번째 시도
# 5 6
# 2012 년 의
# 총 건수는 405 개 입니다
# 총 페이지 수는 5 개 입니다.
# 5 중 0 번째 시도
# 0 5
# 5 중 1 번째 시도
# 1 5
# 5 중 2 번째 시도
# 2 5
# 5 중 3 번째 시도
# 3 5
# 5 중 4 번째 시도
# 4 5
# 2013 년 의
# 총 건수는 487 개 입니다
# 총 페이지 수는 5 개 입니다.
# 5 중 0 번째 시도
# 0 5
# 5 중 1 번째 시도
# 1 5
# 5 중 2 번째 시도
# 2 5
# 5 중 3 번째 시도
# 3 5
# 5 중 4 번째 시도
# 4 5
# 2014 년 의
# 총 건수는 323 개 입니다
# 총 페이지 수는 4 개 입니다.
# 4 중 0 번째 시도
# 0 4
# 4 중 1 번째 시도
# 1 4
# 4 중 2 번째 시도
# 2 4
# 4 중 3 번째 시도
# 3 4
# 2015 년 의
# 총 건수는 466 개 입니다
# 총 페이지 수는 5 개 입니다.
# 5 중 0 번째 시도
# 0 5
# 5 중 1 번째 시도
# 1 5
# 5 중 2 번째 시도
# 2 5
# 5 중 3 번째 시도
# 3 5
# 5 중 4 번째 시도
# 4 5
# 2016 년 의
# 총 건수는 896 개 입니다
# 총 페이지 수는 9 개 입니다.
# 9 중 0 번째 시도
# 0 9
# 9 중 1 번째 시도
# 1 9
# 9 중 2 번째 시도
# 2 9
# 9 중 3 번째 시도
# 3 9
# 9 중 4 번째 시도
# 4 9
# 9 중 5 번째 시도
# 5 9
# 9 중 6 번째 시도
# 6 9
# 9 중 7 번째 시도
# 7 9
# 9 중 8 번째 시도
# 8 9
# 2017 년 의
# 총 건수는 949 개 입니다
# 총 페이지 수는 10 개 입니다.
# 10 중 0 번째 시도
# 0 10
# 10 중 1 번째 시도
# 1 10
# 10 중 2 번째 시도
# 2 10
# 10 중 3 번째 시도
# 3 10
# 10 중 4 번째 시도
# 4 10
# 10 중 5 번째 시도
# 5 10
# 10 중 6 번째 시도
# 6 10
# 10 중 7 번째 시도
# 7 10
# 10 중 8 번째 시도
# 8 10
# 10 중 9 번째 시도
# 9 10
# 2018 년 의
# 총 건수는 1313 개 입니다
# 총 페이지 수는 14 개 입니다.
# 전체 14 중 1 페이지
# 전체 14 중 2 페이지
# 전체 14 중 3 페이지
# 전체 14 중 4 페이지
# 전체 14 중 5 페이지
# 전체 14 중 6 페이지
# 전체 14 중 7 페이지
# 전체 14 중 8 페이지
# 전체 14 중 9 페이지
# 전체 14 중 10 페이지
# 10미만 나머지 페이지 4 중 1 페이지
# 10미만 나머지 페이지 4 중 2 페이지
# 10미만 나머지 페이지 4 중 3 페이지
# 10미만 나머지 페이지 4 중 4 페이지
# 2019 년 의
# 총 건수는 1417 개 입니다
# 총 페이지 수는 15 개 입니다.
# 전체 15 중 1 페이지
# 전체 15 중 2 페이지
# 전체 15 중 3 페이지
# 전체 15 중 4 페이지
# 전체 15 중 5 페이지
# 전체 15 중 6 페이지
# 전체 15 중 7 페이지

# %% [markdown]
# ---

# %% [markdown]
# # **본격 수정들어가기**

# %%
docscode_2 = []
cpy_info = []
link_box = []
date = []
topic = []
checkbox = [44] # 주식관련사채

start = 2000
end = 2020
section = 1

# %%
url = "https://kind.krx.co.kr/disclosure/details.do?method=searchDetailsMain#viewer"

driver = webdriver.Chrome(r"C:\Users\sally\OneDrive\바탕 화면\chromedriver.exe")
driver.get(url)


driver.find_element_by_id('rKosdaq').click() #코스닥 선택
time.sleep(0.3)
driver.find_element_by_xpath('//*[@id="bfrDsclsType"]').click() # 공시유형 초기화 체크 해제
time.sleep(0.3)
driver.find_element_by_xpath('//*[@id="lastReport"]').click() # 최종보고서 체크
time.sleep(0.3)
driver.find_element_by_xpath('//*[@id="dsclsType01"]').click() # 수시공시 클릭
time.sleep(0.3)
for i in range(len(checkbox)):
    driver.find_element_by_xpath('//*[@id="dsclsLayer01_{num}"]'.format(num = checkbox[i])).click() # checklist
time.sleep(0.1) 
driver.find_element_by_xpath('//*[@id="currentPageSize"]/option[4]').click() # 100개씩 보기 선택
time.sleep(0.3)




# 날짜 선택하는 for문 (반복문으로 만들어야해서 맨 아래에 둘 것)
year=2003
for i in tqdm(range((2020-2003)+1)):
    
    elem1 = driver.find_element_by_name("fromDate")  #커서를 두겠다는 의미
    time.sleep(0.3)
    elem1.clear()
    time.sleep(0.3)
    elem1.send_keys("{0}-01-01".format(year))
    time.sleep(0.3)
    elem1.send_keys(Keys.RETURN)
    time.sleep(0.3)
    elem1.send_keys("{0}-01-01".format(year))
    time.sleep(0.3)

    elem2 = driver.find_element_by_name("toDate")  #커서를 두겠다는 의미
    time.sleep(0.3)
    elem2.clear()
    time.sleep(0.3)
    elem2.send_keys("{0}-12-31".format(year))
    time.sleep(0.3)
    elem2.send_keys(Keys.RETURN)
    time.sleep(0.3)
    elem2.send_keys("{0}-12-31".format(year))
    time.sleep(0.3)

    driver.find_element_by_xpath('//*[@id="searchForm"]/section[1]/div/div[3]/a[1]').click() # 검색
    time.sleep(5)
    

    # 기간 내 공시 개수 text로 읽어서 int형으로 변환 후 페이지 길이 구하기
    
    full_case = driver.find_element_by_xpath('//*[@id="main-contents"]/section[2]/div[2]/em').text
    time.sleep(1)
    full_case = full_case.replace(',','')
    full_case = int(full_case)

    #print(i,'번째 테스트',full_case)
    
    time.sleep(1)
    page_len = full_case//100+1


    print(year,'년 의')
    print('총 건수는',full_case,'개 입니다')
    print('총 페이지 수는',page_len,'개 입니다.')
    
    time.sleep(1)
    

    #######################################################################################################################
      
    
    # 총 건수가 1000개 이상이면 다음페이지 버튼 코드에도 변동 발생 -> 이거 처리 어떻게 할지 생각
    if full_case > 1000:
        small_page_iteration = page_len // 10           # iteration만큼 반복할때는 다음페이지 버튼에 변동없음
        small_page_left = page_len % 10                 # 10 이하 페이지 처리할때 버튼 설정 다시 해주기
        lt_append_left = full_case - (full_case//100*100)   # 리스트에 append할때 100개 미만인 것 개수 구하기


        ########## 10개 페이지 단위 처리
        for k in range(1, small_page_iteration*10+1):        # k는 1부터 10까지 (이후도 동일 - 10개씩)
            print('전체', page_len, '중', k ,'페이지')
            #print('{0} {1}'.format(k, page_len))
            time.sleep(1)

            for i in range(100): # 공시 날짜 수집 
                date_value = driver.find_element_by_xpath('//*[@id="main-contents"]/section[1]/table/tbody/tr[{num}]/td[2]'.format(num = i + 1)).text
                date.append(date_value)
                topic_value = driver.find_element_by_xpath('//*[@id="main-contents"]/section[1]/table/tbody/tr[{num}]/td[4]'.format(num = i + 1)).text
                topic.append(topic_value)


            for i in range(100): # 문서 코드
                onclick_value = driver.find_element_by_xpath('//*[@id="main-contents"]/section[1]/table/tbody/tr[{num}]/td[4]/a'.format(num = i + 1)).get_attribute('onclick')
                onclick_value = onclick_value[18:32]
                #time.sleep(0.3)
                docscode_2.append(onclick_value)

            print('공시 날짜 수:{date} 문서 코드 수:{docscode_2}'.format(date=len(date),docscode_2=len(docscode_2)))
            time.sleep(0.2)

            driver.find_element_by_xpath('//*[@id="main-contents"]/section[2]/div[1]/a[13]').send_keys(Keys.ENTER) # 다음페이지 버튼
            time.sleep(3)


        ########## 10개 미만 페이지 단위 처리
        for j in range(1,small_page_left+1):
            if j==small_page_left:          # 마지막 페이지인 경우(= 건수 100개 이하)
                first_button_num = 3
                print('10미만 나머지 페이지',small_page_left,'중',j,'페이지')
                print('남은 건 수는 {0}입니다. 수고했어'.format(lt_append_left))
                time.sleep(1)

                for i in range(lt_append_left): # 공시 날짜 수집
                    date_value = driver.find_element_by_xpath('//*[@id="main-contents"]/section[1]/table/tbody/tr[{num}]/td[2]'.format(num = i + 1)).text
                    date.append(date_value)
                    topic_value = driver.find_element_by_xpath('//*[@id="main-contents"]/section[1]/table/tbody/tr[{num}]/td[4]'.format(num = i + 1)).text
                    topic.append(topic_value)


                for i in range(lt_append_left): # 문서 코드
                    onclick_value = driver.find_element_by_xpath('//*[@id="main-contents"]/section[1]/table/tbody/tr[{num}]/td[4]/a'.format(num = i + 1)).get_attribute('onclick')
                    onclick_value = onclick_value[18:32]
                    #time.sleep(0.3)
                    docscode_2.append(onclick_value)

            else:
                first_button_num = 3
                print('10미만 나머지 페이지',small_page_left,'중',j,'페이지')
                time.sleep(1)


                for i in range(100): # 공시 날짜 수집
                    date_value = driver.find_element_by_xpath('//*[@id="main-contents"]/section[1]/table/tbody/tr[{num}]/td[2]'.format(num = i + 1)).text
                    date.append(date_value)
                    topic_value = driver.find_element_by_xpath('//*[@id="main-contents"]/section[1]/table/tbody/tr[{num}]/td[4]'.format(num = i + 1)).text
                    topic.append(topic_value)


                for i in range(100): # 문서 코드
                    onclick_value = driver.find_element_by_xpath('//*[@id="main-contents"]/section[1]/table/tbody/tr[{num}]/td[4]/a'.format(num = i + 1)).get_attribute('onclick')
                    onclick_value = onclick_value[18:32]
                    #time.sleep(0.3)
                    docscode_2.append(onclick_value)

            print('공시 날짜 수:{date} 문서 코드 수:{docscode_2}'.format(date=len(date),docscode_2=len(docscode_2)))
            time.sleep(0.2)

            driver.find_element_by_xpath('//*[@id="main-contents"]/section[2]/div[1]/a[{0}]'.format(first_button_num + small_page_left)).send_keys(Keys.ENTER) # 다음페이지 버튼
            time.sleep(3)



            


    # 총 건수가 1000개 아래면 다음페이지 버튼 변동 없음
    elif full_case <= 1000:
        lt_append_left = full_case - (full_case//100*100)
        for j in range(1,page_len+1):
            if j==page_len:                     # 마지막 페이지인 경우(= 건수 100개 이하)
                print('전체', page_len, '중', j ,'페이지')
                print('남은 건 수는 {0}입니다. 수고했어'.format(lt_append_left))
                time.sleep(1)


                for i in range(lt_append_left): # 공시 날짜 수집
                    date_value = driver.find_element_by_xpath('//*[@id="main-contents"]/section[1]/table/tbody/tr[{num}]/td[2]'.format(num = i + 1)).text
                    date.append(date_value)
                    topic_value = driver.find_element_by_xpath('//*[@id="main-contents"]/section[1]/table/tbody/tr[{num}]/td[4]'.format(num = i + 1)).text
                    topic.append(topic_value)


                for i in range(lt_append_left): # 문서 코드
                    onclick_value = driver.find_element_by_xpath('//*[@id="main-contents"]/section[1]/table/tbody/tr[{num}]/td[4]/a'.format(num = i + 1)).get_attribute('onclick')
                    onclick_value = onclick_value[18:32]
                    #time.sleep(0.3)
                    docscode_2.append(onclick_value)

            else:
                print('전체', page_len, '중', j ,'페이지')
                time.sleep(1)



                for i in range(100): # 공시 날짜 수집
                    date_value = driver.find_element_by_xpath('//*[@id="main-contents"]/section[1]/table/tbody/tr[{num}]/td[2]'.format(num = i + 1)).text
                    date.append(date_value)
                    topic_value = driver.find_element_by_xpath('//*[@id="main-contents"]/section[1]/table/tbody/tr[{num}]/td[4]'.format(num = i + 1)).text
                    topic.append(topic_value)


                for i in range(100): # 문서 코드
                    onclick_value = driver.find_element_by_xpath('//*[@id="main-contents"]/section[1]/table/tbody/tr[{num}]/td[4]/a'.format(num = i + 1)).get_attribute('onclick')
                    onclick_value = onclick_value[18:32]
                    #time.sleep(0.3)
                    docscode_2.append(onclick_value)

            print('공시 날짜 수:{date} 문서 코드 수:{docscode_2}'.format(date=len(date),docscode_2=len(docscode_2)))
            time.sleep(0.2)




            driver.find_element_by_xpath('//*[@id="main-contents"]/section[2]/div[1]/a[{0}]'.format(page_len+3)).send_keys(Keys.ENTER) # 다음페이지 버튼
            time.sleep(3)

    else:
        print('오류 발생')


    
    year=year+1
# Out:
#   0%|          | 0/21 [00:00<?, ?it/s]
# 2000 년 의
# 총 건수는 839 개 입니다
# 총 페이지 수는 9 개 입니다.
# 전체 9 중 1 페이지
# 공시 날짜 수:100 문서 코드 수:100
# 전체 9 중 2 페이지
# 공시 날짜 수:200 문서 코드 수:200
# 전체 9 중 3 페이지
# 공시 날짜 수:300 문서 코드 수:300
# 전체 9 중 4 페이지
# 공시 날짜 수:400 문서 코드 수:400
# 전체 9 중 5 페이지
# 공시 날짜 수:500 문서 코드 수:500
# 전체 9 중 6 페이지
# 공시 날짜 수:600 문서 코드 수:600
# 전체 9 중 7 페이지
# 공시 날짜 수:700 문서 코드 수:700
# 전체 9 중 8 페이지
# 공시 날짜 수:800 문서 코드 수:800
# 전체 9 중 9 페이지
# 남은 건 수는 39입니다. 수고했어
# 공시 날짜 수:839 문서 코드 수:839
#   5%|▍         | 1/21 [01:52<37:37, 112.86s/it]
# 2001 년 의
# 총 건수는 1107 개 입니다
# 총 페이지 수는 12 개 입니다.
# 전체 12 중 1 페이지
# 공시 날짜 수:939 문서 코드 수:939
# 전체 12 중 2 페이지
# 공시 날짜 수:1039 문서 코드 수:1039
# 전체 12 중 3 페이지
# 공시 날짜 수:1139 문서 코드 수:1139
# 전체 12 중 4 페이지
# 공시 날짜 수:1239 문서 코드 수:1239
# 전체 12 중 5 페이지
# 공시 날짜 수:1339 문서 코드 수:1339
# 전체 12 중 6 페이지
# 공시 날짜 수:1439 문서 코드 수:1439
# 전체 12 중 7 페이지
# 공시 날짜 수:1539 문서 코드 수:1539
# 전체 12 중 8 페이지
# 공시 날짜 수:1639 문서 코드 수:1639
# 전체 12 중 9 페이지
# 공시 날짜 수:1739 문서 코드 수:1739
# 전체 12 중 10 페이지
# 공시 날짜 수:1839 문서 코드 수:1839
# 10미만 나머지 페이지 2 중 1 페이지
# 공시 날짜 수:1939 문서 코드 수:1939
# 10미만 나머지 페이지 2 중 2 페이지
# 남은 건 수는 7입니다. 수고했어
# 공시 날짜 수:1946 문서 코드 수:1946
#  10%|▉         | 2/21 [04:18<41:54, 132.33s/it]
# 2002 년 의
# 총 건수는 1442 개 입니다
# 총 페이지 수는 15 개 입니다.
# 전체 15 중 1 페이지
# 공시 날짜 수:2046 문서 코드 수:2046
# 전체 15 중 2 페이지
# 공시 날짜 수:2146 문서 코드 수:2146
# 전체 15 중 3 페이지
# 공시 날짜 수:2246 문서 코드 수:2246
# 전체 15 중 4 페이지
# 공시 날짜 수:2346 문서 코드 수:2346
# 전체 15 중 5 페이지
# 공시 날짜 수:2446 문서 코드 수:2446
# 전체 15 중 6 페이지
# 공시 날짜 수:2546 문서 코드 수:2546
# 전체 15 중 7 페이지
# 공시 날짜 수:2646 문서 코드 수:2646
# 전체 15 중 8 페이지
# 공시 날짜 수:2746 문서 코드 수:2746
# 전체 15 중 9 페이지
# 공시 날짜 수:2846 문서 코드 수:2846
# 전체 15 중 10 페이지
# 공시 날짜 수:2946 문서 코드 수:2946
# 10미만 나머지 페이지 5 중 1 페이지
# 공시 날짜 수:3046 문서 코드 수:3046
# 10미만 나머지 페이지 5 중 2 페이지
# 공시 날짜 수:3146 문서 코드 수:3146
# 10미만 나머지 페이지 5 중 3 페이지
# 공시 날짜 수:3246 문서 코드 수:3246
# 10미만 나머지 페이지 5 중 4 페이지
# 공시 날짜 수:3346 문서 코드 수:3346
# 10미만 나머지 페이지 5 중 5 페이지
# 남은 건 수는 42입니다. 수고했어
# 공시 날짜 수:3388 문서 코드 수:3388
#  14%|█▍        | 3/21 [08:01<52:06, 173.68s/it]
# 2003 년 의
# 총 건수는 1393 개 입니다
# 총 페이지 수는 14 개 입니다.
# 전체 14 중 1 페이지
# 공시 날짜 수:3488 문서 코드 수:3488
# 전체 14 중 2 페이지
# 공시 날짜 수:3588 문서 코드 수:3588
# 전체 14 중 3 페이지
# 공시 날짜 수:3688 문서 코드 수:3688
# 전체 14 중 4 페이지
# 공시 날짜 수:3788 문서 코드 수:3788
# 전체 14 중 5 페이지
# 공시 날짜 수:3888 문서 코드 수:3888
# 전체 14 중 6 페이지
# 공시 날짜 수:3988 문서 코드 수:3988
# 전체 14 중 7 페이지
# 공시 날짜 수:4088 문서 코드 수:4088
# 전체 14 중 8 페이지
# 공시 날짜 수:4188 문서 코드 수:4188
# 전체 14 중 9 페이지
# 공시 날짜 수:4288 문서 코드 수:4288
# 전체 14 중 10 페이지
# 공시 날짜 수:4388 문서 코드 수:4388
# 10미만 나머지 페이지 4 중 1 페이지
# 공시 날짜 수:4488 문서 코드 수:4488
# 10미만 나머지 페이지 4 중 2 페이지
# 공시 날짜 수:4588 문서 코드 수:4588
# 10미만 나머지 페이지 4 중 3 페이지
# 공시 날짜 수:4688 문서 코드 수:4688
# 10미만 나머지 페이지 4 중 4 페이지
# 남은 건 수는 93입니다. 수고했어
# 공시 날짜 수:4781 문서 코드 수:4781
#  19%|█▉        | 4/21 [11:36<53:47, 189.85s/it]
# 2004 년 의
# 총 건수는 932 개 입니다
# 총 페이지 수는 10 개 입니다.
# 전체 10 중 1 페이지
# 공시 날짜 수:4881 문서 코드 수:4881
# 전체 10 중 2 페이지
# 공시 날짜 수:4981 문서 코드 수:4981
# 전체 10 중 3 페이지
# 공시 날짜 수:5081 문서 코드 수:5081
# 전체 10 중 4 페이지
# 공시 날짜 수:5181 문서 코드 수:5181
# 전체 10 중 5 페이지
# 공시 날짜 수:5281 문서 코드 수:5281
# 전체 10 중 6 페이지
# 공시 날짜 수:5381 문서 코드 수:5381
# 전체 10 중 7 페이지
# 공시 날짜 수:5481 문서 코드 수:5481
# 전체 10 중 8 페이지
# 공시 날짜 수:5581 문서 코드 수:5581
# 전체 10 중 9 페이지
# 공시 날짜 수:5681 문서 코드 수:5681
# 전체 10 중 10 페이지
# 남은 건 수는 32입니다. 수고했어
# 공시 날짜 수:5713 문서 코드 수:5713
#  24%|██▍       | 5/21 [14:11<47:15, 177.25s/it]
# 2005 년 의
# 총 건수는 1647 개 입니다
# 총 페이지 수는 17 개 입니다.
# 전체 17 중 1 페이지
# 공시 날짜 수:5813 문서 코드 수:5813
# 전체 17 중 2 페이지
# 공시 날짜 수:5913 문서 코드 수:5913
# 전체 17 중 3 페이지
# 공시 날짜 수:6013 문서 코드 수:6013
# 전체 17 중 4 페이지
# 공시 날짜 수:6113 문서 코드 수:6113
# 전체 17 중 5 페이지
# 공시 날짜 수:6213 문서 코드 수:6213
# 전체 17 중 6 페이지
# 공시 날짜 수:6313 문서 코드 수:6313
# 전체 17 중 7 페이지
# 공시 날짜 수:6413 문서 코드 수:6413
# 전체 17 중 8 페이지
# 공시 날짜 수:6513 문서 코드 수:6513
# 전체 17 중 9 페이지
# 공시 날짜 수:6613 문서 코드 수:6613
# 전체 17 중 10 페이지
# 공시 날짜 수:6713 문서 코드 수:6713
# 10미만 나머지 페이지 7 중 1 페이지
# 공시 날짜 수:6813 문서 코드 수:6813
# 10미만 나머지 페이지 7 중 2 페이지
# 공시 날짜 수:6913 문서 코드 수:6913
# 10미만 나머지 페이지 7 중 3 페이지
# 공시 날짜 수:7013 문서 코드 수:7013
# 10미만 나머지 페이지 7 중 4 페이지
# 공시 날짜 수:7113 문서 코드 수:7113
# 10미만 나머지 페이지 7 중 5 페이지
# 공시 날짜 수:7213 문서 코드 수:7213
# 10미만 나머지 페이지 7 중 6 페이지
# 공시 날짜 수:7313 문서 코드 수:7313
# 10미만 나머지 페이지 7 중 7 페이지
# 남은 건 수는 47입니다. 수고했어
# 공시 날짜 수:7360 문서 코드 수:7360
#  29%|██▊       | 6/21 [18:56<53:28, 213.88s/it]
# 2006 년 의
# 총 건수는 1152 개 입니다
# 총 페이지 수는 12 개 입니다.
# 전체 12 중 1 페이지
# 공시 날짜 수:7460 문서 코드 수:7460
# 전체 12 중 2 페이지
# 공시 날짜 수:7560 문서 코드 수:7560
# 전체 12 중 3 페이지
# 공시 날짜 수:7660 문서 코드 수:7660
# 전체 12 중 4 페이지
# 공시 날짜 수:7760 문서 코드 수:7760
# 전체 12 중 5 페이지
# 공시 날짜 수:7860 문서 코드 수:7860
# 전체 12 중 6 페이지
# 공시 날짜 수:7960 문서 코드 수:7960
# 전체 12 중 7 페이지
# 공시 날짜 수:8060 문서 코드 수:8060
# 전체 12 중 8 페이지
# 공시 날짜 수:8160 문서 코드 수:8160
# 전체 12 중 9 페이지
# 공시 날짜 수:8260 문서 코드 수:8260
# 전체 12 중 10 페이지
# 공시 날짜 수:8360 문서 코드 수:8360
# 10미만 나머지 페이지 2 중 1 페이지
# 공시 날짜 수:8460 문서 코드 수:8460
# 10미만 나머지 페이지 2 중 2 페이지
# 남은 건 수는 52입니다. 수고했어
# 공시 날짜 수:8512 문서 코드 수:8512
#  33%|███▎      | 7/21 [22:23<49:26, 211.88s/it]
# 2007 년 의
# 총 건수는 928 개 입니다
# 총 페이지 수는 10 개 입니다.
# 전체 10 중 1 페이지
# 공시 날짜 수:8612 문서 코드 수:8612
# 전체 10 중 2 페이지
# 공시 날짜 수:8712 문서 코드 수:8712
# 전체 10 중 3 페이지
# 공시 날짜 수:8812 문서 코드 수:8812
# 전체 10 중 4 페이지
# 공시 날짜 수:8912 문서 코드 수:8912
# 전체 10 중 5 페이지
# 공시 날짜 수:9012 문서 코드 수:9012
# 전체 10 중 6 페이지
# 공시 날짜 수:9112 문서 코드 수:9112
# 전체 10 중 7 페이지
# 공시 날짜 수:9212 문서 코드 수:9212
# 전체 10 중 8 페이지
# 공시 날짜 수:9312 문서 코드 수:9312
# 전체 10 중 9 페이지
# 공시 날짜 수:9412 문서 코드 수:9412
# 전체 10 중 10 페이지
# 남은 건 수는 28입니다. 수고했어
# 공시 날짜 수:9440 문서 코드 수:9440
#  38%|███▊      | 8/21 [25:33<44:23, 204.91s/it]
# 2008 년 의
# 총 건수는 1131 개 입니다
# 총 페이지 수는 12 개 입니다.
# 전체 12 중 1 페이지
# 공시 날짜 수:9540 문서 코드 수:9540
# 전체 12 중 2 페이지
# 공시 날짜 수:9640 문서 코드 수:9640
# 전체 12 중 3 페이지
# 공시 날짜 수:9740 문서 코드 수:9740
# 전체 12 중 4 페이지
# 공시 날짜 수:9840 문서 코드 수:9840
# 전체 12 중 5 페이지
# 공시 날짜 수:9940 문서 코드 수:9940
# 전체 12 중 6 페이지
# 공시 날짜 수:10040 문서 코드 수:10040
# 전체 12 중 7 페이지
# 공시 날짜 수:10140 문서 코드 수:10140
# 전체 12 중 8 페이지
# 공시 날짜 수:10240 문서 코드 수:10240
# 전체 12 중 9 페이지
# 공시 날짜 수:10340 문서 코드 수:10340
# 전체 12 중 10 페이지
# 공시 날짜 수:10440 문서 코드 수:10440
# 10미만 나머지 페이지 2 중 1 페이지
# 공시 날짜 수:10540 문서 코드 수:10540
# 10미만 나머지 페이지 2 중 2 페이지
# 남은 건 수는 31입니다. 수고했어
# 공시 날짜 수:10571 문서 코드 수:10571
#  43%|████▎     | 9/21 [29:30<42:55, 214.66s/it]
# 2009 년 의
# 총 건수는 918 개 입니다
# 총 페이지 수는 10 개 입니다.
# 전체 10 중 1 페이지
# 공시 날짜 수:10671 문서 코드 수:10671
# 전체 10 중 2 페이지
# 공시 날짜 수:10771 문서 코드 수:10771
# 전체 10 중 3 페이지
# 공시 날짜 수:10871 문서 코드 수:10871
# 전체 10 중 4 페이지
# 공시 날짜 수:10971 문서 코드 수:10971
# 전체 10 중 5 페이지
# 공시 날짜 수:11071 문서 코드 수:11071
# 전체 10 중 6 페이지
# 공시 날짜 수:11171 문서 코드 수:11171
# 전체 10 중 7 페이지
# 공시 날짜 수:11271 문서 코드 수:11271
# 전체 10 중 8 페이지
# 공시 날짜 수:11371 문서 코드 수:11371
# 전체 10 중 9 페이지
# 공시 날짜 수:11471 문서 코드 수:11471
# 전체 10 중 10 페이지
# 남은 건 수는 18입니다. 수고했어
# 공시 날짜 수:11489 문서 코드 수:11489
#  48%|████▊     | 10/21 [32:43<38:09, 208.12s/it]
# 2010 년 의
# 총 건수는 618 개 입니다
# 총 페이지 수는 7 개 입니다.
# 전체 7 중 1 페이지
# 공시 날짜 수:11589 문서 코드 수:11589
# 전체 7 중 2 페이지
# 공시 날짜 수:11689 문서 코드 수:11689
# 전체 7 중 3 페이지
# 공시 날짜 수:11789 문서 코드 수:11789
# 전체 7 중 4 페이지
# 공시 날짜 수:11889 문서 코드 수:11889
# 전체 7 중 5 페이지
# 공시 날짜 수:11989 문서 코드 수:11989
# 전체 7 중 6 페이지
# 공시 날짜 수:12089 문서 코드 수:12089
# 전체 7 중 7 페이지
# 남은 건 수는 18입니다. 수고했어
# 공시 날짜 수:12107 문서 코드 수:12107
#  52%|█████▏    | 11/21 [35:01<31:06, 186.61s/it]
# 2011 년 의
# 총 건수는 528 개 입니다
# 총 페이지 수는 6 개 입니다.
# 전체 6 중 1 페이지
# 공시 날짜 수:12207 문서 코드 수:12207
# 전체 6 중 2 페이지
# 공시 날짜 수:12307 문서 코드 수:12307
# 전체 6 중 3 페이지
# 공시 날짜 수:12407 문서 코드 수:12407
# 전체 6 중 4 페이지
# 공시 날짜 수:12507 문서 코드 수:12507
# 전체 6 중 5 페이지
# 공시 날짜 수:12607 문서 코드 수:12607
# 전체 6 중 6 페이지
# 남은 건 수는 28입니다. 수고했어
# 공시 날짜 수:12635 문서 코드 수:12635
#  57%|█████▋    | 12/21 [37:05<25:07, 167.53s/it]
# 2012 년 의
# 총 건수는 405 개 입니다
# 총 페이지 수는 5 개 입니다.
# 전체 5 중 1 페이지
# 공시 날짜 수:12735 문서 코드 수:12735
# 전체 5 중 2 페이지
# 공시 날짜 수:12835 문서 코드 수:12835
# 전체 5 중 3 페이지
# 공시 날짜 수:12935 문서 코드 수:12935
# 전체 5 중 4 페이지
# 공시 날짜 수:13035 문서 코드 수:13035
# 전체 5 중 5 페이지
# 남은 건 수는 5입니다. 수고했어
# 공시 날짜 수:13040 문서 코드 수:13040
#  62%|██████▏   | 13/21 [38:46<19:38, 147.32s/it]
# 2013 년 의
# 총 건수는 487 개 입니다
# 총 페이지 수는 5 개 입니다.
# 전체 5 중 1 페이지
# 공시 날짜 수:13140 문서 코드 수:13140
# 전체 5 중 2 페이지
# 공시 날짜 수:13240 문서 코드 수:13240
# 전체 5 중 3 페이지
# 공시 날짜 수:13340 문서 코드 수:13340
# 전체 5 중 4 페이지
# 공시 날짜 수:13440 문서 코드 수:13440
# 전체 5 중 5 페이지
# 남은 건 수는 87입니다. 수고했어
# 공시 날짜 수:13527 문서 코드 수:13527
#  67%|██████▋   | 14/21 [40:41<16:03, 137.61s/it]
# 2014 년 의
# 총 건수는 323 개 입니다
# 총 페이지 수는 4 개 입니다.
# 전체 4 중 1 페이지
# 공시 날짜 수:13627 문서 코드 수:13627
# 전체 4 중 2 페이지
# 공시 날짜 수:13727 문서 코드 수:13727
# 전체 4 중 3 페이지
# 공시 날짜 수:13827 문서 코드 수:13827
# 전체 4 중 4 페이지
# 남은 건 수는 23입니다. 수고했어
# 공시 날짜 수:13850 문서 코드 수:13850
#  71%|███████▏  | 15/21 [42:06<12:10, 121.75s/it]
# 2015 년 의
# 총 건수는 466 개 입니다
# 총 페이지 수는 5 개 입니다.
# 전체 5 중 1 페이지
# 공시 날짜 수:13950 문서 코드 수:13950
# 전체 5 중 2 페이지
# 공시 날짜 수:14050 문서 코드 수:14050
# 전체 5 중 3 페이지
# 공시 날짜 수:14150 문서 코드 수:14150
# 전체 5 중 4 페이지
# 공시 날짜 수:14250 문서 코드 수:14250
# 전체 5 중 5 페이지
# 남은 건 수는 66입니다. 수고했어
# 공시 날짜 수:14316 문서 코드 수:14316
#  76%|███████▌  | 16/21 [43:57<09:53, 118.61s/it]
# 2016 년 의
# 총 건수는 896 개 입니다
# 총 페이지 수는 9 개 입니다.
# 전체 9 중 1 페이지
# 공시 날짜 수:14416 문서 코드 수:14416
# 전체 9 중 2 페이지
# 공시 날짜 수:14516 문서 코드 수:14516
# 전체 9 중 3 페이지
# 공시 날짜 수:14616 문서 코드 수:14616
# 전체 9 중 4 페이지
# 공시 날짜 수:14716 문서 코드 수:14716
# 전체 9 중 5 페이지
# 공시 날짜 수:14816 문서 코드 수:14816
# 전체 9 중 6 페이지
# 공시 날짜 수:14916 문서 코드 수:14916
# 전체 9 중 7 페이지
# 공시 날짜 수:15016 문서 코드 수:15016
# 전체 9 중 8 페이지
# 공시 날짜 수:15116 문서 코드 수:15116
# 전체 9 중 9 페이지
# 남은 건 수는 96입니다. 수고했어
# 공시 날짜 수:15212 문서 코드 수:15212
#  81%|████████  | 17/21 [47:18<09:33, 143.26s/it]
# 2017 년 의
# 총 건수는 949 개 입니다
# 총 페이지 수는 10 개 입니다.
# 전체 10 중 1 페이지
# 공시 날짜 수:15312 문서 코드 수:15312
# 전체 10 중 2 페이지
# 공시 날짜 수:15412 문서 코드 수:15412
# 전체 10 중 3 페이지
# 공시 날짜 수:15512 문서 코드 수:15512
# 전체 10 중 4 페이지
# 공시 날짜 수:15612 문서 코드 수:15612
# 전체 10 중 5 페이지
# 공시 날짜 수:15712 문서 코드 수:15712
# 전체 10 중 6 페이지
# 공시 날짜 수:15812 문서 코드 수:15812
# 전체 10 중 7 페이지
# 공시 날짜 수:15912 문서 코드 수:15912
# 전체 10 중 8 페이지
# 공시 날짜 수:16012 문서 코드 수:16012
# 전체 10 중 9 페이지
# 공시 날짜 수:16112 문서 코드 수:16112
# 전체 10 중 10 페이지
# 남은 건 수는 49입니다. 수고했어
# 공시 날짜 수:16161 문서 코드 수:16161
#  86%|████████▌ | 18/21 [51:09<08:28, 169.60s/it]
# 2018 년 의
# 총 건수는 1313 개 입니다
# 총 페이지 수는 14 개 입니다.
# 전체 14 중 1 페이지
# 공시 날짜 수:16261 문서 코드 수:16261
# 전체 14 중 2 페이지
# 공시 날짜 수:16361 문서 코드 수:16361
# 전체 14 중 3 페이지
# 공시 날짜 수:16461 문서 코드 수:16461
# 전체 14 중 4 페이지
# 공시 날짜 수:16561 문서 코드 수:16561
# 전체 14 중 5 페이지
# 공시 날짜 수:16661 문서 코드 수:16661
# 전체 14 중 6 페이지
# 공시 날짜 수:16761 문서 코드 수:16761
# 전체 14 중 7 페이지
# 공시 날짜 수:16861 문서 코드 수:16861
# 전체 14 중 8 페이지
# 공시 날짜 수:16961 문서 코드 수:16961
# 전체 14 중 9 페이지
# 공시 날짜 수:17061 문서 코드 수:17061
# 전체 14 중 10 페이지
# 공시 날짜 수:17161 문서 코드 수:17161
# 10미만 나머지 페이지 4 중 1 페이지
# 공시 날짜 수:17261 문서 코드 수:17261
# 10미만 나머지 페이지 4 중 2 페이지
# 공시 날짜 수:17361 문서 코드 수:17361
# 10미만 나머지 페이지 4 중 3 페이지
# 공시 날짜 수:17461 문서 코드 수:17461
# 10미만 나머지 페이지 4 중 4 페이지
# 남은 건 수는 13입니다. 수고했어
# 공시 날짜 수:17474 문서 코드 수:17474
#  90%|█████████ | 19/21 [56:24<07:06, 213.49s/it]
# 2019 년 의
# 총 건수는 1417 개 입니다
# 총 페이지 수는 15 개 입니다.
# 전체 15 중 1 페이지
# 공시 날짜 수:17574 문서 코드 수:17574
# 전체 15 중 2 페이지
# 공시 날짜 수:17674 문서 코드 수:17674
# 전체 15 중 3 페이지
# 공시 날짜 수:17774 문서 코드 수:17774
# 전체 15 중 4 페이지
# 공시 날짜 수:17874 문서 코드 수:17874
# 전체 15 중 5 페이지
# 공시 날짜 수:17974 문서 코드 수:17974
# 전체 15 중 6 페이지
# 공시 날짜 수:18074 문서 코드 수:18074
# 전체 15 중 7 페이지
# 공시 날짜 수:18174 문서 코드 수:18174
# 전체 15 중 8 페이지
# 공시 날짜 수:18274 문서 코드 수:18274
# 전체 15 중 9 페이지
# 공시 날짜 수:18374 문서 코드 수:18374
# 전체 15 중 10 페이지
# 공시 날짜 수:18474 문서 코드 수:18474
# 10미만 나머지 페이지 5 중 1 페이지
# 공시 날짜 수:18574 문서 코드 수:18574
# 10미만 나머지 페이지 5 중 2 페이지
# 공시 날짜 수:18674 문서 코드 수:18674
# 10미만 나머지 페이지 5 중 3 페이지
# 공시 날짜 수:18774 문서 코드 수:18774
# 10미만 나머지 페이지 5 중 4 페이지
# 공시 날짜 수:18874 문서 코드 수:18874
# 10미만 나머지 페이지 5 중 5 페이지
# 남은 건 수는 17입니다. 수고했어
# 공시 날짜 수:18891 문서 코드 수:18891
#  95%|█████████▌| 20/21 [1:01:22<03:58, 238.65s/it]
# 2020 년 의
# 총 건수는 1131 개 입니다
# 총 페이지 수는 12 개 입니다.
# 전체 12 중 1 페이지
# 공시 날짜 수:18991 문서 코드 수:18991
# 전체 12 중 2 페이지
# 공시 날짜 수:19091 문서 코드 수:19091
# 전체 12 중 3 페이지
# 공시 날짜 수:19191 문서 코드 수:19191
# 전체 12 중 4 페이지
# 공시 날짜 수:19291 문서 코드 수:19291
# 전체 12 중 5 페이지
# 공시 날짜 수:19391 문서 코드 수:19391
# 전체 12 중 6 페이지
# 공시 날짜 수:19491 문서 코드 수:19491
# 전체 12 중 7 페이지
# 공시 날짜 수:19591 문서 코드 수:19591
# 전체 12 중 8 페이지
# 공시 날짜 수:19691 문서 코드 수:19691
# 전체 12 중 9 페이지
# 공시 날짜 수:19791 문서 코드 수:19791
# 전체 12 중 10 페이지
# 공시 날짜 수:19891 문서 코드 수:19891
# 10미만 나머지 페이지 2 중 1 페이지
# 공시 날짜 수:19991 문서 코드 수:19991
# 10미만 나머지 페이지 2 중 2 페이지
# 남은 건 수는 31입니다. 수고했어
# 공시 날짜 수:20022 문서 코드 수:20022
# 100%|██████████| 21/21 [1:05:17<00:00, 186.53s/it]

# %% [markdown]
# ## **step two - 해당 공시문서가 발생한 회사명, 종목코드 추출**

# %%
dftcodebox = []
driver = webdriver.Chrome(r'C:\Users\sally\OneDrive\바탕 화면\chromedriver.exe')
for j in range(len(docscode_2)):
        try:
                url = 'https://kind.krx.co.kr/common/disclsviewer.do?method=search&acptno={0}&docno=&viewerhost=&viewerport='.format(docscode_2[j])
                driver.get(url)
                time.sleep(0.3)
                cpy_nameAndcode = driver.find_element_by_xpath('//*[@id="frm"]/header/h1').text
                cpy_info.append(cpy_nameAndcode)
        except ValueError as er:
                print(er,'문서코드와 url주소 매칭에 실패하였습니다. 임시 코드 리스트에 해당 코드를 보관합니다.')
                dftcodebox.append(docscode_2[j])
driver.close()

# %% [markdown]
# # **공시문서 텍스트 수집**

# %%
link_box=[]
driver = webdriver.Chrome(r'C:\Users\sally\OneDrive\바탕 화면\chromedriver.exe')
for i in range(int(len(docscode_2)/3)): # 텍스트 링크 추출
    url = 'https://kind.krx.co.kr/common/disclsviewer.do?method=search&acptno={0}&docno=&viewerhost=&viewerport='.format(docscode_2[i])
    driver.get(url)
    time.sleep(0.5)
    link = driver.find_element_by_id('docLocPath').get_attribute('value')
    link_box.append(link)

time.sleep(1)

for i in range(int(len(docscode_2)/3), int(len(docscode_2)/3*2)):
    url = 'https://kind.krx.co.kr/common/disclsviewer.do?method=search&acptno={0}&docno=&viewerhost=&viewerport='.format(docscode_2[i])
    driver.get(url)
    time.sleep(0.5)
    link = driver.find_element_by_id('docLocPath').get_attribute('value')
    link_box.append(link)    

time.sleep(1)

for i in range(int(len(docscode_2)/3*2), len(docscode_2)):
    url = 'https://kind.krx.co.kr/common/disclsviewer.do?method=search&acptno={0}&docno=&viewerhost=&viewerport='.format(docscode_2[i])
    driver.get(url)
    time.sleep(0.5)
    link = driver.find_element_by_id('docLocPath').get_attribute('value')
    link_box.append(link)   

driver.close()
len(link_box)
# Out:
# 20022

# %% [markdown]
# ## **공시 문서 URL 리스트에 결측치 유무 확인**

# %%
cnt = 0
dftbox = []
for i in range(len(link_box)):
    
    if link_box[i] == '':
        print('index:{num} 주소값에는 결측치가 전달되었습니다.'.format(num = i))
        dftbox.append(i)
        cnt += 1
print('총 결측치는 {num}개 입니다.'.format(num = cnt))
# Out:
# index:14006 주소값에는 결측치가 전달되었습니다.
# index:14016 주소값에는 결측치가 전달되었습니다.
# index:14056 주소값에는 결측치가 전달되었습니다.
# index:16222 주소값에는 결측치가 전달되었습니다.
# index:17231 주소값에는 결측치가 전달되었습니다.
# index:17239 주소값에는 결측치가 전달되었습니다.
# index:18557 주소값에는 결측치가 전달되었습니다.
# index:18668 주소값에는 결측치가 전달되었습니다.
# index:18694 주소값에는 결측치가 전달되었습니다.
# 총 결측치는 9개 입니다.

# %%
driver = webdriver.Chrome(r'C:\Users\sally\OneDrive\바탕 화면\chromedriver.exe')

for i in dftbox:
    url = 'https://kind.krx.co.kr/common/disclsviewer.do?method=search&acptno={num}&docno=&viewerhost=&viewerport='.format(num = docscode_2[i])
    driver.get(url)
    time.sleep(0.5)
    link_box[i] = driver.find_element_by_id('docLocPath').get_attribute('value')

driver.close()

# %% [markdown]
# ## **결측치 재확인**

# %%
cnt_ = 0
for i in range(len(link_box)):
    
    if link_box[i] == '':
        print('index:{num} 주소값에는 결측지가 전달되었습니다.'.format(num = i))
        cnt_ += 1
print('총 결측지는 {num}개 입니다.'.format(num = cnt_))
# Out:
# 총 결측지는 0개 입니다.

# %% [markdown]
# ## **공시 text 추출**

# %%
from bs4 import BeautifulSoup
import urllib.request

textbox = []

for i in tqdm(range(len(link_box))):
    html = urllib.request.urlopen(link_box[i])

    soup = BeautifulSoup(html, 'html.parser').text
    textbox.append(soup)

print(len(link_box))
# Out:
# 100%|██████████| 20022/20022 [39:15<00:00,  8.50it/s]
# 20022

# %% [markdown]
# # **회사명, 코드 및 텍스트 DF, csv로 만들기**

# %%
from collections import OrderedDict

cpyname = []
cpycode = []

def replace_all(text, dic):
    for i, j in dic.items():
        text = text.replace(i, j)
    return text

con1 = OrderedDict([("(", ""), (")", "")])

# %%
for i in range(len(cpy_info)):
    infm = cpy_info[i].split(' ')
    cpyname.append(infm[0])

    cpycode.append(replace_all(infm[1] , con1))

# %%
import pandas as pd

text_df = pd.DataFrame({'회사명': cpyname,
                        '거래소코드' : cpycode,
                        '공시발생일' : date,
                        '공시제목' : topic,
                        'text' : textbox, 
                        'link' : link_box})
text_df
# Out:
#            회사명   거래소코드             공시발생일  \
# 0        울트라건설  004320  2000-12-30 14:14
# 1         네스테크  037540  2000-12-30 09:40
# 2        울트라건설  004320  2000-12-30 00:00
# 3         대백쇼핑  027700  2000-12-30 00:00
# 4        넥서스투자  019430  2000-12-29 14:55
# ...        ...     ...               ...
# 20017   에이아이비트  039230  2020-01-06 17:32
# 20018     아이톡시  052770  2020-01-06 11:06
# 20019     아이톡시  052770  2020-01-06 11:06
# 20020    넥스트BT  065170  2020-01-03 16:33
# 20021  수성이노베이션  084180  2020-01-03 16:25
#
#                                              공시제목  \
# 0                                        전환사채발행결정
# 1                                         전환청구권행사
# 2                            전환사채발행결정(유원건설(주) -2)
# 3      모집이외의방법(사모)에의한사채발행결의((주)대백쇼핑 사모사채 기간연장 결의)
# 4                                         신주인수권행사
# ...                                           ...
# 20017                            전환사채권발행결정(제16회차)
# 20018                         [정정]전환사채권발행결정(제9회차)
# 20019                         [정정]전환사채권발행결정(제8회차)
# 20020                            전환사채권발행결정(제16회차)
# 20021                            전환사채권발행결정(제12회차)
#
#                                                     text  \
# 0      \n\n\n\n\n\n\n\n\n전환사채발행 결의\n\n\n\n\n1. 사채의 종류...
# 1      \n\n\n\n\n\n\n\n\n전환청구권 행사\n\n\n\n\n【주식수 및 자본금...
# 2      유원건설(주) 전환사채발행결의-2\n\n\n   시작일 : -,   종료일 : -\...
# 3      (주)대백쇼핑 사모사채 기간연장 결의\n\n\n1. 사채의 종류 : 제5회 사모사채...
# 4      \n\n\n\n\n\n\n\n\n\n신주인수권 행사\n\n\n\n\n【주식수 및 자...
# ...                                                  ...
# 20017  \n\n\n\n\n\n\n\n\n\n주요사항보고서 / 거래소 신고의무 사항\n\n\...
# 20018  \n\n\n\n\n\n\n\n\n\n정 정 신 고 (보고)\n\n\n\n\n\n\n...
# 20019  \n\n\n\n\n\n\n\n\n\n정 정 신 고 (보고)\n\n\n\n\n\n\n...
# 20020  \n\n\n\n\n\n\n\n\n\n주요사항보고서 / 거래소 신고의무 사항\n\n\...
# 20021  \n\n\n\n\n\n\n\n\n\n주요사항보고서 / 거래소 신고의무 사항\n\n\...
#
#                                                     link
# 0      https://kind.krx.co.kr/external/2000/12/30/K00...
# 1      https://kind.krx.co.kr/external/2000/12/30/K00...
# 2      https://kind.krx.co.kr/external/2000/12/30/M00...
# 3      https://kind.krx.co.kr/external/2000/12/30/M00...
# 4      https://kind.krx.co.kr/external/2000/12/29/K00...
# ...                                                  ...
# 20017  https://kind.krx.co.kr/external/2020/01/06/000...
# 20018  https://kind.krx.co.kr/external/2020/01/06/000...
# 20019  https://kind.krx.co.kr/external/2020/01/06/000...
# 20020  https://kind.krx.co.kr/external/2020/01/03/000...
# 20021  https://kind.krx.co.kr/external/2020/01/03/000...
#
# [20022 rows x 6 columns]

# %% [markdown]
# ---

# %% [markdown]
# ## **텍스트 정보 CSV**

# %%
checkbox
# Out:
# [44]

# %%
text_df.to_csv(r'C:\apps\Ubion-CorporateBankruptcyAnalysis\Code\HJ\Preprocessing\0020공시44.csv', encoding='utf-8-sig')

# %%
wordbox = []

for i in tqdm(range(len(textbox))):
    wordbox.append(word_tokenize(textbox[i]))

wordbox

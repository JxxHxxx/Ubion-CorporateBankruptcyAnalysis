# %% [markdown]
# # 특수문자 제외 데이터프레임 생성

# %%
import pandas as pd

# %%
df_full = pd.read_csv('..\..\Data\데이터정리중\재무변수_부도사유_Final.csv', index_col=0)

# %%
df = df_full
df
# Out:
#             회사명    거래소코드     회계년도  소속코드 상장폐지일 감사의견코드  자산총계(요약)  유동자산(요약)  \
# 0      (주)CMG제약  58820.0  2000/12   5.0   NaN     UQ   28990.0   21169.0
# 1      (주)CMG제약  58820.0  2001/12   5.0   NaN     UQ   20908.0   16359.0
# 2      (주)CMG제약  58820.0  2002/12   5.0   NaN     UQ   15401.0    9880.0
# 3      (주)CMG제약  58820.0  2003/12   5.0   NaN     UQ   11063.0    8534.0
# 4      (주)CMG제약  58820.0  2004/12   5.0   NaN     UQ    5179.0    3893.0
# ...         ...      ...      ...   ...   ...    ...       ...       ...
# 27352   흥구석유(주)  24060.0  2016/12   5.0   NaN     UQ   79137.0   14794.0
# 27353   흥구석유(주)  24060.0  2017/12   5.0   NaN     UQ   79912.0   15880.0
# 27354   흥구석유(주)  24060.0  2018/12   5.0   NaN     UQ   75206.0   12515.0
# 27355   흥구석유(주)  24060.0  2019/12   5.0   NaN     UQ   83661.0   22620.0
# 27356   흥구석유(주)  24060.0  2020/12   5.0   NaN     UQ   83721.0   27688.0
#
#        당좌자산(요약)  현금 및 현금성자산(요약)  ...   기업가치(EV)   EBITDA  EBITDA/매출액  \
# 0       10541.0          4330.0  ...        NaN      NaN         NaN
# 1        2307.0          1829.0  ...        NaN      NaN         NaN
# 2        1436.0           355.0  ...        NaN      NaN         NaN
# 3        1083.0             2.0  ...        NaN      NaN         NaN
# 4         445.0            11.0  ...        NaN      NaN         NaN
# ...         ...             ...  ...        ...      ...         ...
# 27352   12274.0          1440.0  ...   55934.79  1348.52        0.94
# 27353   13124.0          1588.0  ...   46036.63  1147.56        0.74
# 27354   11029.0          4017.0  ...   36557.57  1451.79        0.87
# 27355   19701.0          2318.0  ...   78081.78  1009.25        0.67
# 27356   25313.0          1413.0  ...  107308.51    16.31        0.01
#
#        EBITDA/금융비용  EBITDA/평균발행주식수  EV/EBITDA       년        key  공시제목   부도
# 0              NaN             NaN        NaN  2001.0  588202001   NaN  1.0
# 1              NaN             NaN        NaN  2002.0  588202002   NaN  1.0
# 2              NaN             NaN        NaN  2003.0  588202003   NaN  1.0
# 3              NaN             NaN        NaN  2004.0  588202004   NaN  1.0
# 4              NaN             NaN        NaN  2005.0  588202005   NaN  1.0
# ...            ...             ...        ...     ...        ...   ...  ...
# 27352        10.71           89.90      41.48  2017.0  240602017   NaN  1.0
# 27353         9.02           76.50      40.12  2018.0  240602018   NaN  1.0
# 27354        16.83           96.79      25.18  2019.0  240602019   NaN  1.0
# 27355       507.93           67.28      77.37  2020.0  240602020   NaN  1.0
# 27356         0.00            1.09    6579.47  2021.0  240602021   NaN  1.0
#
# [27357 rows x 271 columns]

# %%
#특수문자 _로 변경
col_list = list(df.columns)

import re
for k in range(len(col_list)):
    filtered_col = re.sub(r'[^\d\w]', '_',col_list[k])
    col_list[k] = filtered_col

df.columns = col_list

# %%
#첫글자가 숫자인 칼럼 _로 변경
col_list = list(df.columns)

for i in range(len(col_list)):

    if col_list[i][0] == '1':
        col_list[i] = '_'+ col_list[i]
    else :
        pass
    
df.columns = col_list

# %%
df
# Out:
#             회사명    거래소코드     회계년도  소속코드 상장폐지일 감사의견코드  자산총계_요약_  유동자산_요약_  \
# 0      (주)CMG제약  58820.0  2000/12   5.0   NaN     UQ   28990.0   21169.0
# 1      (주)CMG제약  58820.0  2001/12   5.0   NaN     UQ   20908.0   16359.0
# 2      (주)CMG제약  58820.0  2002/12   5.0   NaN     UQ   15401.0    9880.0
# 3      (주)CMG제약  58820.0  2003/12   5.0   NaN     UQ   11063.0    8534.0
# 4      (주)CMG제약  58820.0  2004/12   5.0   NaN     UQ    5179.0    3893.0
# ...         ...      ...      ...   ...   ...    ...       ...       ...
# 27352   흥구석유(주)  24060.0  2016/12   5.0   NaN     UQ   79137.0   14794.0
# 27353   흥구석유(주)  24060.0  2017/12   5.0   NaN     UQ   79912.0   15880.0
# 27354   흥구석유(주)  24060.0  2018/12   5.0   NaN     UQ   75206.0   12515.0
# 27355   흥구석유(주)  24060.0  2019/12   5.0   NaN     UQ   83661.0   22620.0
# 27356   흥구석유(주)  24060.0  2020/12   5.0   NaN     UQ   83721.0   27688.0
#
#        당좌자산_요약_  현금_및_현금성자산_요약_  ...   기업가치_EV_   EBITDA  EBITDA_매출액  \
# 0       10541.0          4330.0  ...        NaN      NaN         NaN
# 1        2307.0          1829.0  ...        NaN      NaN         NaN
# 2        1436.0           355.0  ...        NaN      NaN         NaN
# 3        1083.0             2.0  ...        NaN      NaN         NaN
# 4         445.0            11.0  ...        NaN      NaN         NaN
# ...         ...             ...  ...        ...      ...         ...
# 27352   12274.0          1440.0  ...   55934.79  1348.52        0.94
# 27353   13124.0          1588.0  ...   46036.63  1147.56        0.74
# 27354   11029.0          4017.0  ...   36557.57  1451.79        0.87
# 27355   19701.0          2318.0  ...   78081.78  1009.25        0.67
# 27356   25313.0          1413.0  ...  107308.51    16.31        0.01
#
#        EBITDA_금융비용  EBITDA_평균발행주식수  EV_EBITDA       년        key  공시제목   부도
# 0              NaN             NaN        NaN  2001.0  588202001   NaN  1.0
# 1              NaN             NaN        NaN  2002.0  588202002   NaN  1.0
# 2              NaN             NaN        NaN  2003.0  588202003   NaN  1.0
# 3              NaN             NaN        NaN  2004.0  588202004   NaN  1.0
# 4              NaN             NaN        NaN  2005.0  588202005   NaN  1.0
# ...            ...             ...        ...     ...        ...   ...  ...
# 27352        10.71           89.90      41.48  2017.0  240602017   NaN  1.0
# 27353         9.02           76.50      40.12  2018.0  240602018   NaN  1.0
# 27354        16.83           96.79      25.18  2019.0  240602019   NaN  1.0
# 27355       507.93           67.28      77.37  2020.0  240602020   NaN  1.0
# 27356         0.00            1.09    6579.47  2021.0  240602021   NaN  1.0
#
# [27357 rows x 271 columns]

# %%
#데이터프레임 저장
df.to_csv('변수명_특수문자제외_Final.csv')

# %% [markdown]
# # Padding 가장 최근값으로 지정
#
# 직전값 .fillna(method='pad') <br>
# 직후값 .fillna(method='bfill)

# %%
df_front = df

# %%
cpylist = dataset['회사명'].unique()

for i in tqdm(range(len(cpylist))):
    dataset.loc[dataset['회사명'] == cpylist[i]] = dataset.loc[dataset['회사명'] == cpylist[i]].fillna(method='pad') # 전년 데이터로 대체
    dataset.loc[dataset['회사명'] == cpylist[i]] = dataset.loc[dataset['회사명'] == cpylist[i]].fillna(method='bfill') # 후년 데이터로 대체
    dataset.loc[dataset['회사명'] == cpylist[i]] = dataset.loc[dataset['회사명'] == cpylist[i]].fillna(0) # 그래도 처리못하는 데이터는 없으면 0으로 대체

# %%
df_front.fillna(method='pad')
# Out:
#             회사명    거래소코드     회계년도  소속코드       상장폐지일 감사의견코드  자산총계_요약_  \
# 0      (주)CMG제약  58820.0  2000/12   5.0         NaN     UQ   28990.0
# 1      (주)CMG제약  58820.0  2001/12   5.0         NaN     UQ   20908.0
# 2      (주)CMG제약  58820.0  2002/12   5.0         NaN     UQ   15401.0
# 3      (주)CMG제약  58820.0  2003/12   5.0         NaN     UQ   11063.0
# 4      (주)CMG제약  58820.0  2004/12   5.0         NaN     UQ    5179.0
# ...         ...      ...      ...   ...         ...    ...       ...
# 27352   흥구석유(주)  24060.0  2016/12   5.0  2005/04/26     UQ   79137.0
# 27353   흥구석유(주)  24060.0  2017/12   5.0  2005/04/26     UQ   79912.0
# 27354   흥구석유(주)  24060.0  2018/12   5.0  2005/04/26     UQ   75206.0
# 27355   흥구석유(주)  24060.0  2019/12   5.0  2005/04/26     UQ   83661.0
# 27356   흥구석유(주)  24060.0  2020/12   5.0  2005/04/26     UQ   83721.0
#
#        유동자산_요약_  당좌자산_요약_  현금_및_현금성자산_요약_  ...   기업가치_EV_   EBITDA  \
# 0       21169.0   10541.0          4330.0  ...        NaN      NaN
# 1       16359.0    2307.0          1829.0  ...        NaN      NaN
# 2        9880.0    1436.0           355.0  ...        NaN      NaN
# 3        8534.0    1083.0             2.0  ...        NaN      NaN
# 4        3893.0     445.0            11.0  ...        NaN      NaN
# ...         ...       ...             ...  ...        ...      ...
# 27352   14794.0   12274.0          1440.0  ...   55934.79  1348.52
# 27353   15880.0   13124.0          1588.0  ...   46036.63  1147.56
# 27354   12515.0   11029.0          4017.0  ...   36557.57  1451.79
# 27355   22620.0   19701.0          2318.0  ...   78081.78  1009.25
# 27356   27688.0   25313.0          1413.0  ...  107308.51    16.31
#
#        EBITDA_매출액  EBITDA_금융비용  EBITDA_평균발행주식수  EV_EBITDA       년        key  \
# 0             NaN          NaN             NaN        NaN  2001.0  588202001
# 1             NaN          NaN             NaN        NaN  2002.0  588202002
# 2             NaN          NaN             NaN        NaN  2003.0  588202003
# 3             NaN          NaN             NaN        NaN  2004.0  588202004
# 4             NaN          NaN             NaN        NaN  2005.0  588202005
# ...           ...          ...             ...        ...     ...        ...
# 27352        0.94        10.71           89.90      41.48  2017.0  240602017
# 27353        0.74         9.02           76.50      40.12  2018.0  240602018
# 27354        0.87        16.83           96.79      25.18  2019.0  240602019
# 27355        0.67       507.93           67.28      77.37  2020.0  240602020
# 27356        0.01         0.00            1.09    6579.47  2021.0  240602021
#
#                                공시제목   부도
# 0                               NaN  1.0
# 1                               NaN  1.0
# 2                               NaN  1.0
# 3                               NaN  1.0
# 4                               NaN  1.0
# ...                             ...  ...
# 27352  내부결산시점 관리종목 지정 또는 상장폐지 사유 발생  1.0
# 27353  내부결산시점 관리종목 지정 또는 상장폐지 사유 발생  1.0
# 27354  내부결산시점 관리종목 지정 또는 상장폐지 사유 발생  1.0
# 27355  내부결산시점 관리종목 지정 또는 상장폐지 사유 발생  1.0
# 27356  내부결산시점 관리종목 지정 또는 상장폐지 사유 발생  1.0
#
# [27357 rows x 271 columns]

# %%
df_back = df

# %%
df_back.fillna(method='bfill').isna().sum()
# Out:
# 회사명            0
# 거래소코드          0
# 회계년도           0
# 소속코드           0
# 상장폐지일         56
#             ...
# EV_EBITDA      0
# 년              0
# key            0
# 공시제목         123
# 부도             0
# Length: 271, dtype: int64

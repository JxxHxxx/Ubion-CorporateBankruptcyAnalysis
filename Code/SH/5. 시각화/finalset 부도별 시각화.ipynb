# %% [markdown]
# # 커널밀도함수

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler

import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings(action='ignore')
# Out:
# C:\Users\user\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# C:\Users\user\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\.libs\libopenblas.QVLO2T66WEPI7JZ63PS3HMOHFEY472BC.gfortran-win_amd64.dll
# C:\Users\user\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\.libs\libopenblas.XWYDX2IKJW2NMTWSFYNGFUWKQU3LYTCZ.gfortran-win_amd64.dll
#   warnings.warn("loaded more than 1 DLL from .libs:"

# %%
col_head = ['회사명', '거래소코드', '회계년도']
col_finance = ['경영자산비율', '총자본순이익률', '자기자본배율', '유동비율', '총자본투자효율', '경영자본영업이익률', 
           '부채구성비율', '매출액증가율', '자기자본영업이익률', '유형자산회전율','매출채권회수기간','영업이익증가율',  '부도']
col_text = [ '대표이사_변경', '최대주주_변경', '회계처리위반', '횡령배임', '신종채권', '영업조업중단', '출자목적_투자',
       '출자목적_경영권', '출자목적_영업이익', '기타', '신종채권_운영', '신종채권_시설', '신종채권_기타', '종가변동률']
col_tail = ['key', '부도']

# %%
dataset_ = pd.read_csv(r'..\..\..\Code\SH\csv\finalset.csv', index_col=0)
dataset = dataset_[col_finance]
scaler = StandardScaler()
dataset[['경영자산비율', '총자본순이익률', '자기자본배율', '유동비율', '총자본투자효율', '경영자본영업이익률', 
           '부채구성비율', '매출액증가율', '자기자본영업이익률', '유형자산회전율','매출채권회수기간','영업이익증가율']] = scaler.fit_transform(dataset
       [['경영자산비율', '총자본순이익률', '자기자본배율', '유동비율', '총자본투자효율', '경영자본영업이익률', 
           '부채구성비율', '매출액증가율', '자기자본영업이익률', '유형자산회전율','매출채권회수기간','영업이익증가율']])

# %%
dataset
# Out:
#          경영자산비율   총자본순이익률    자기자본배율      유동비율   총자본투자효율  경영자본영업이익률    부채구성비율  \
# 0      0.739988  0.077033 -0.025536 -0.019465 -0.018438  -0.126193  0.387027
# 1      0.889718  0.077033 -0.025536 -0.019465 -0.018438  -0.126193  0.461747
# 2      0.227801 -0.351437 -0.026124 -0.020676 -0.126136  -1.319969  0.449848
# 3      0.071144  0.086958 -0.026150 -0.017447  0.090206  -0.567440 -0.030785
# 4      0.149486 -1.518397 -0.027160 -0.019070 -0.649491  -2.034244  0.235726
# ...         ...       ...       ...       ...       ...        ...       ...
# 26786 -0.825038  0.151146  0.031108 -0.007229 -0.017357  -0.106280 -0.925394
# 26787 -0.800460  0.145522  0.031599 -0.017815 -0.017897  -0.127241 -0.921551
# 26788 -0.825199  0.160741  0.032185 -0.010958 -0.004385  -0.091606 -1.116525
# 26789 -0.704652  0.404919  0.037773 -0.003895  0.106692  -0.152396 -1.066777
# 26790 -0.694842  0.249082  0.039987  0.024257  0.028992  -0.245152 -1.159657
#
# ...

# %%
dataset.max()
# Out:
# 경영자산비율         1.020952
# 총자본순이익률        7.325286
# 자기자본배율        80.052376
# 유동비율          94.374023
# 총자본투자효율       92.005943
# 경영자본영업이익률     35.038318
# 부채구성비율        47.131155
# 매출액증가율        99.300888
# 자기자본영업이익률     27.234498
# 유형자산회전율      140.317302
# 매출채권회수기간     119.001873
# 영업이익증가율       62.390160
# 부도             1.000000
# dtype: float64

# %%
dataset.columns
# Out:
# Index(['경영자산비율', '총자본순이익률', '자기자본배율', '유동비율', '총자본투자효율', '경영자본영업이익률', '부채구성비율',
#        '매출액증가율', '자기자본영업이익률', '유형자산회전율', '매출채권회수기간', '영업이익증가율', '부도'],
#       dtype='object')

# %%
t0 = dataset.loc[dataset['부도'] == 0]
t1 = dataset.loc[dataset['부도'] == 1]

# %%
plt.rcParams['font.family'] = 'malgun gothic'
sns.heatmap(dataset.corr(),annot=True,cmap='RdYlGn',linewidths=0.2)
fig=plt.gcf()
fig.set_size_inches(10,8)
plt.show()

# %%
""" scaler = StandardScaler()
t0[['설비투자효율', '총자본투자효율', '부채구성비율', '순운전자본비율', '재고자산보유기간', '매출채권회수기간',
       '매입채무회전률', '경영자본회전률', '경영자본순이익률', '총자본순이익률', '자기자본증가율']] = scaler.fit_transform(t0)
t1[['설비투자효율', '총자본투자효율', '부채구성비율', '순운전자본비율', '재고자산보유기간', '매출채권회수기간',
       '매입채무회전률', '경영자본회전률', '경영자본순이익률', '총자본순이익률', '자기자본증가율']] = scaler.fit_transform(t1) """

# %% [markdown]
# ## 함수

# %%
def plot_new_feature_distribution(df1, df2, label1, label2, features, k):
    i = 0
    
    sns.set(font="malgun gothic", 
        rc={"axes.unicode_minus":False},
        style='whitegrid')
        
    plt.figure()
    fig, ax = plt.subplots(1,k,figsize=(20,5))

    for feature in features:
        plt.legend()
        i += 1
        plt.subplot(1,k,i)
        plt.xlim([-8, 8])
        sns.kdeplot(df1[feature], bw=0.5,label=label1)
        sns.kdeplot(df2[feature], bw=0.5,label=label2)
        plt.xlabel(feature, fontsize=11)
        locs, labels = plt.xticks()
        plt.tick_params(axis='x', which='major', labelsize=8)
        plt.tick_params(axis='y', which='major', labelsize=8)
    plt.legend()   
    plt.show()

# %%
def plot_new_feature_distribution_narraw(df1, df2, label1, label2, features, k):
    i = 0
    
    sns.set(font="malgun gothic", 
        rc={"axes.unicode_minus":False},
        style='whitegrid')
        
    plt.figure()
    fig, ax = plt.subplots(1,k,figsize=(20,5))

    for feature in features:
        plt.legend()
        i += 1
        plt.subplot(1,k,i)
        plt.xlim([-1, 1])
        sns.kdeplot(df1[feature], bw=0.5,label=label1)
        sns.kdeplot(df2[feature], bw=0.5,label=label2)
        plt.xlabel(feature, fontsize=11)
        locs, labels = plt.xticks()
        plt.tick_params(axis='x', which='major', labelsize=8)
        plt.tick_params(axis='y', which='major', labelsize=8)
    plt.legend()   
    plt.show()

# %%
features = t0.columns.values[0:2]
plot_new_feature_distribution(t0, t1, '부도: 0', '부도: 1', features, 2)
# Out:
# No handles with labels found to put in legend.

# %%
features = t0.columns.values[2:4]
plot_new_feature_distribution_narraw(t0, t1, '부도: 0', '부도: 1', features, 2)
# Out:
# No handles with labels found to put in legend.

# %%
features = t0.columns.values[4:6]
plot_new_feature_distribution(t0, t1, '부도: 0', '부도: 1', features, 2)
# Out:
# No handles with labels found to put in legend.

# %%
features = t0.columns.values[6:8]
plot_new_feature_distribution(t0, t1, '부도: 0', '부도: 1', features, 2)
# Out:
# No handles with labels found to put in legend.

# %%
features = t0.columns.values[8:10]
plot_new_feature_distribution(t0, t1, '부도: 0', '부도: 1', features, 2)
# Out:
# No handles with labels found to put in legend.

# %%
features = t0.columns.values[10:12]
plot_new_feature_distribution(t0, t1, '부도: 0', '부도: 1', features, 2)
# Out:
# No handles with labels found to put in legend.

# %%
dataset.loc[dataset['부도'] == 1, '경영자본순이익률']
# Out:
# 119     -4.237857
# 174     -1.531466
# 352     -5.904966
# 572     -0.223029
# 581     -1.299243
#            ...
# 26320    0.078038
# 26341   -0.392630
# 26581    0.197261
# 26688   -0.797264
# 26775   -6.231724
# Name: 경영자본순이익률, Length: 402, dtype: float64

# %%
dataset_2 = pd.read_csv(r'..\..\..\Code\SH\1. 데이터생성\최종\merge+7.6.2_.csv', usecols = ['경영자본영업이익률', '순운전자본비율'])
scaler = StandardScaler()
dataset_2[['경영자본영업이익률', '순운전자본비율']] = scaler.fit_transform(dataset_2[['경영자본영업이익률', '순운전자본비율']])
dataset_2
# Out:
#         순운전자본비율  경영자본영업이익률
# 0      0.061773  -0.126193
# 1      0.061773  -0.126193
# 2     -0.360555  -1.319969
# 3      0.428095  -0.567440
# 4      0.124922  -2.034244
# ...         ...        ...
# 26786 -0.184252  -0.106280
# 26787 -0.340553  -0.127241
# 26788 -0.257402  -0.091606
# 26789  0.024912  -0.152396
# 26790  0.271223  -0.245152
#
# [26791 rows x 2 columns]

# %%
fuck = ['경영자본영업이익률']
si = ['순운전자본비율']

# %%
a1 = a[0:26791]
a2 = a[26791:]
a2
# Out:
# 0        0.061773
# 1        0.061773
# 2       -0.360555
# 3        0.428095
# 4        0.124922
#            ...
# 26786   -0.184252
# 26787   -0.340553
# 26788   -0.257402
# 26789    0.024912
# 26790    0.271223
# Length: 26791, dtype: float64

# %%
t0_ = dataset_2.loc[dataset['부도'] == 0]
t1_ = dataset_2.loc[dataset['부도'] == 1]

# %%
features = dataset_2.columns.values[0:2]
plot_new_feature_distribution(a1, a2, '부도: 0', '부도: 1', features, 2)
# Out:
# No handles with labels found to put in legend.
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1420/956183534.py in <module>
#       1 features = dataset_2.columns
# ----> 2 plot_new_feature_distribution(a1, a2, '부도: 0', '부도: 1', features, 2)
#
# ~\AppData\Local\Temp/ipykernel_1420/116893102.py in plot_new_feature_distribution(df1, df2, label1, label2, features, k)
#      14         plt.subplot(1,k,i)
#      15         plt.xlim([-8, 8])
# ---> 16         sns.kdeplot(df1[feature], bw=0.5,label=label1)
#      17         sns.kdeplot(df2[feature], bw=0.5,label=label2)
#      18         plt.xlabel(feature, fontsize=11)
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices

# %%
def plot_new_feature_distribution_(df1, df2, label1, label2, k):
    i = 0
    
    sns.set(font="malgun gothic", 
        rc={"axes.unicode_minus":False},
        style='whitegrid')
        
    plt.figure()
    fig, ax = plt.subplots(1,k,figsize=(20,5))

    for feature in features:
        plt.legend()
        i += 1
        plt.subplot(1,k,i)
        plt.xlim([-1, 1])
        sns.kdeplot(df1[feature], bw=0.5,label=label1)
        sns.kdeplot(df2[feature], bw=0.5,label=label2)
        plt.xlabel(feature, fontsize=11)
        locs, labels = plt.xticks()
        plt.tick_params(axis='x', which='major', labelsize=8)
        plt.tick_params(axis='y', which='major', labelsize=8)
    plt.legend()   
    plt.show()

# %%
features = dataset_2.columns.values[0:2]
plot_new_feature_distribution_(t0_, t1_, '부도: 0', '부도: 1', features, 2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1420/1271038645.py in <module>
#       1 features = dataset_2.columns.values[0:2]
# ----> 2 plot_new_feature_distribution_(t0_, t1_, '부도: 0', '부도: 1', features, 2)
#
# TypeError: plot_new_feature_distribution_() takes 5 positional arguments but 6 were given

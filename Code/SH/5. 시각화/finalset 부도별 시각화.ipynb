# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler

import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings(action='ignore')
# Out:
# C:\Users\user\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# C:\Users\user\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\.libs\libopenblas.QVLO2T66WEPI7JZ63PS3HMOHFEY472BC.gfortran-win_amd64.dll
# C:\Users\user\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\.libs\libopenblas.XWYDX2IKJW2NMTWSFYNGFUWKQU3LYTCZ.gfortran-win_amd64.dll
#   warnings.warn("loaded more than 1 DLL from .libs:"

# %%
dataset = pd.read_csv(r'..\..\..\Code\SH\5. 시각화\df_finance.csv', index_col=0)
dataset = dataset.drop(['회사명','거래소코드','회계년도','년','key'], axis=1)

scaler = StandardScaler()
dataset[['설비투자효율', '총자본투자효율', '부채구성비율', '비유동장기적합률', '재고자산보유기간', '매출채권회수기간',
       '매입채무회전률', '경영자본회전률', '경영자본순이익률', '자기자본순이익률', '자기자본증가율']] = scaler.fit_transform(dataset
       [['설비투자효율', '총자본투자효율', '부채구성비율', '비유동장기적합률', '재고자산보유기간', '매출채권회수기간',
       '매입채무회전률', '경영자본회전률', '경영자본순이익률', '자기자본순이익률', '자기자본증가율']])

# %%
dataset
# Out:
#          설비투자효율   총자본투자효율    부채구성비율  비유동장기적합률  재고자산보유기간  매출채권회수기간    매입채무회전률  \
# 0      0.006987 -0.128035  0.391413 -1.055677 -0.194368 -0.267918  -0.028716
# 1      0.007016 -0.003268  0.465694 -0.343423  1.034020 -0.266836  -0.024963
# 2      0.006989 -0.116783  0.453865  0.136124  0.396304 -0.267000  -0.019819
# 3      0.007161  0.111243 -0.023948 -0.485641  0.439458 -0.264558  -0.024698
# 4      0.006737 -0.668403  0.240999 -0.329143  0.383998 -0.263131  -0.025065
# ...         ...       ...       ...       ...       ...       ...        ...
# 26827  0.006998 -0.002129 -0.913309  0.185376 -0.174240 -0.227731  27.108434
# 26828  0.006998 -0.002699 -0.909489  0.259108 -0.170826 -0.223862   0.733557
# 26829  0.006998  0.011544 -1.103319  0.223699 -0.176652 -0.229403   0.746319
# 26830  0.007012  0.128619 -1.053863  0.070261 -0.174078 -0.230014   3.522229
# 26831  0.007007  0.046724 -1.146198 -0.050391 -0.162378 -0.225535   1.457719
#
#         경영자본회전률  경영자본순이익률  자기자본순이익률   자기자본증가율   부도
# 0     -1.369200  0.078038  0.046386 -0.089538  0.0
# 1     -0.378960  0.088676  0.058931 -0.089538  0.0
# 2      0.534119 -0.175059 -0.246627 -0.176891  0.0
# 3      0.341215  0.094898  0.063312 -0.094817  0.0
# 4      0.701302 -0.880158 -0.811148 -0.294553  0.0
# ...         ...       ...       ...       ...  ...
# 26827  2.077350  0.159527  0.077948 -0.084805  0.0
# 26828  2.373136  0.155513  0.075956 -0.086712  0.0
# 26829  2.707503  0.168760  0.080039 -0.086167  0.0
# 26830  2.180232  0.382919  0.158394 -0.057833  0.0
# 26831  1.164272  0.243023  0.107319 -0.078028  0.0
#
# [26832 rows x 12 columns]

# %%
dataset.max()
# Out:
# 설비투자효율       20.189585
# 총자본투자효율      96.991212
# 부채구성비율       46.861329
# 비유동장기적합률     50.886994
# 재고자산보유기간    138.613568
# 매출채권회수기간    119.168177
# 매입채무회전률     102.503794
# 경영자본회전률      19.914531
# 경영자본순이익률     41.379812
# 자기자본순이익률     21.014508
# 자기자본증가율     116.703233
# 부도            1.000000
# dtype: float64

# %%
dataset.columns
# Out:
# Index(['설비투자효율', '총자본투자효율', '부채구성비율', '비유동장기적합률', '재고자산보유기간', '매출채권회수기간',
#        '매입채무회전률', '경영자본회전률', '경영자본순이익률', '자기자본순이익률', '자기자본증가율', '부도'],
#       dtype='object')

# %%
t0 = dataset.loc[dataset['부도'] == 0]
t1 = dataset.loc[dataset['부도'] == 1]

# %% [markdown]
# # **상관관계**

# %%
sns.heatmap(dataset.corr(),annot=True,cmap='RdYlGn',linewidths=0.2)
fig=plt.gcf()
fig.set_size_inches(10,8)
plt.rcParams['font.family'] = 'malgun gothic'
plt.show()

# %%
""" scaler = StandardScaler()
t0[['설비투자효율', '총자본투자효율', '부채구성비율', '순운전자본비율', '재고자산보유기간', '매출채권회수기간',
       '매입채무회전률', '경영자본회전률', '경영자본순이익률', '총자본순이익률', '자기자본증가율']] = scaler.fit_transform(t0)
t1[['설비투자효율', '총자본투자효율', '부채구성비율', '순운전자본비율', '재고자산보유기간', '매출채권회수기간',
       '매입채무회전률', '경영자본회전률', '경영자본순이익률', '총자본순이익률', '자기자본증가율']] = scaler.fit_transform(t1) """

# %%
def plot_new_feature_distribution(df1, df2, label1, label2, features, k):
    i = 0
    
    sns.set(font="malgun gothic", 
        rc={"axes.unicode_minus":False},
        style='whitegrid')
        
    plt.figure()
    fig, ax = plt.subplots(1,k,figsize=(20,5))

    for feature in features:
        plt.legend()
        i += 1
        plt.subplot(1,k,i)
        plt.xlim([-8, 8])
        sns.kdeplot(df1[feature], bw=0.5,label=label1)
        sns.kdeplot(df2[feature], bw=0.5,label=label2)
        plt.xlabel(feature, fontsize=11)
        locs, labels = plt.xticks()
        plt.tick_params(axis='x', which='major', labelsize=8)
        plt.tick_params(axis='y', which='major', labelsize=8)
    plt.legend()   
    plt.show()

# %%
features = t0.columns.values[0:2]
plot_new_feature_distribution(t0, t1, '부도: 0', '부도: 1', features, 2)
# Out:
# No handles with labels found to put in legend.

# %%
features = t0.columns.values[2:4]
plot_new_feature_distribution(t0, t1, '부도: 0', '부도: 1', features, 2)
# Out:
# No handles with labels found to put in legend.

# %%
features = t0.columns.values[4:6]
plot_new_feature_distribution(t0, t1, '부도: 0', '부도: 1', features, 2)
# Out:
# No handles with labels found to put in legend.

# %%
features = t0.columns.values[6:8]
plot_new_feature_distribution(t0, t1, '부도: 0', '부도: 1', features, 2)
# Out:
# No handles with labels found to put in legend.

# %%
features = t0.columns.values[8:10]
plot_new_feature_distribution(t0, t1, '부도: 0', '부도: 1', features, 2)
# Out:
# No handles with labels found to put in legend.

# %%
features = t0.columns.values[10:11]
plot_new_feature_distribution(t0, t1, '부도: 0', '부도: 1', features, 2)
# Out:
# No handles with labels found to put in legend.

# %%
dataset.loc[dataset['부도'] == 1, '경영자본순이익률']
# Out:
# 119     -4.237857
# 174     -1.531466
# 352     -5.904966
# 572     -0.223029
# 581     -1.299243
#            ...
# 26320    0.078038
# 26341   -0.392630
# 26581    0.197261
# 26688   -0.797264
# 26775   -6.231724
# Name: 경영자본순이익률, Length: 402, dtype: float64

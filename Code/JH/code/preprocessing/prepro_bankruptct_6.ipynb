# %%
import pandas as pd

# %%
dataset = pd.read_csv(r'C:\Users\JH\Desktop\Final\CBA\Data\최종데이터셋\Finaldataset_ver5sp.csv')

# %% [markdown]
# # **EDA**

# %%
dftcpy = len(dataset.loc[dataset['부도'] == 0]['회사명'].unique())
print('부도로 판정된 기업수: {num}'.format(num=dftcpy))
# Out:
# 부도로 판정된 기업수: 434

# %%
dataset['부도'].value_counts()
# Out:
# 1.0    26339
# 0.0      512
# Name: 부도, dtype: int64

# %% [markdown]
# # **잡음 처리**

# %%
print('부도 value 0 잡음 수 {num}'.format(num = dataset['부도'].value_counts()[0] - dftcpy))
# Out:
# 부도 value 0 잡음 수 78

# %% [markdown]
# ## **부도인데 상장폐지일이 없는 경우**

# %%
dataset.loc[(dataset['부도'] == 0) & (dataset['상장폐지일'] == '0'), '부도'] = 1

# %%
dataset['부도'].value_counts()
# Out:
# 1.0    26370
# 0.0      481
# Name: 부도, dtype: int64

# %%
print('남은 부도 value 0 잡음 수 {num}'.format(num = dataset['부도'].value_counts()[0] - dftcpy))
# Out:
# 남은 부도 value 0 잡음 수 47

# %% [markdown]
# ## **어떤 부도 사유에도 걸리지 않는 경우**

# %%
dataset.loc[(dataset['부도'] == 0) & 
((dataset['수시공시제목'] == '0') & (dataset['정기공시제목'] == '0') & (dataset['감사의견코드'] != 'DS') & (dataset['감사의견코드'] != 'DU') & (dataset['감사의견코드'] != 'DI')
& (dataset['감사의견코드'] != 'QS') & (dataset['감사의견코드'] != 'AG'))]
# Out:
# Empty DataFrame
# Columns: [회사명, 거래소코드, 회계년도, 소속코드, 상장폐지일, 감사의견코드, 자기자본배당률, 금융비용 대 부채비율, 자기자본배율, 유동부채비율, 매입채무회전률, 유동자산회전률, 총자본투자효율, 순운전자본비율, 누적수익성비율, 총자산영업이익률, 총자산회전율, 년, key, 부도, 공시발생일, 정기공시제목, 수시공시제목, 대표이사 변경, 최대주주 변경, 회계처리위반, 횡령배임, 폐지사유요약합본]
# Index: []
#
# [0 rows x 28 columns]

# %%
print('남은 부도 value 0 잡음 수 {num}'.format(num = dataset['부도'].value_counts()[0] - dftcpy))
# Out:
# 남은 부도 value 0 잡음 수 47

# %% [markdown]
# ## 사유3

# %%
dataset.loc[dataset['부도'] == 0]['회사명'].values[1]
# Out:
# '(주)골드카운티'

# %%
cpyname = []
for i in range(len(dataset.loc[dataset['부도'] == 0]['회사명'])):
    cpyname.append(dataset.loc[dataset['부도'] == 0]['회사명'].values[i])

# %%
dpt_list = []
for i in range(len(cpyname)-1):
    if cpyname[i] == cpyname[i+1]:
        print(cpyname[i])
        dpt_list.append(cpyname[i])
    else:
        pass
# Out:
# (주)나리지*온
# (주)단성일렉트론
# (주)도움
# (주)드림티엔터테인먼트
# (주)디에스피이엔티
# (주)레이더스컴퍼니
# (주)미성포리테크
# (주)블루스톤디앤아이
# (주)블루젬디앤씨
# (주)삼우이엠씨
# (주)세븐코스프
# (주)스틸플라워
# (주)스틸플라워
# (주)스페이스솔루션
# (주)시스컴
# (주)신양오라컴디스플레이
# (주)쌈지
# (주)쓰리소프트
# (주)씨그널엔터테인먼트그룹
# (주)씨모텍
# (주)씨앤케이인터내셔널
# (주)씨티앤티
# (주)아라온테크
# (주)아이디에스
# (주)아이디에이치
# (주)아이엠텍
# (주)아이팩토리
# (주)아이팩토리
# (주)아큐텍
# (주)애드모바일
# (주)에스마크
# (주)에스에스컴텍
# (주)에스에프씨
# (주)에피밸리
# (주)엔에스브이
# (주)엔케이바이오
# (주)엘앤씨피
# (주)영진코퍼레이션
# (주)와이즈파워
# (주)와이즈파워
# (주)우전
# (주)유니드코리아
# (주)유아이에너지
# (주)이노블루
# (주)이엠네트웍스
# (주)제낙스
# (주)제너시스템즈
# (주)주노콜렉션
# (주)중앙디자인
# (주)케이알
# (주)택산아이엔씨
# (주)트레이스
# (주)트레이스
# (주)플러스프로핏
# (주)피앤텔
# (주)피앤텔
# (주)한신코퍼레이션
# (주)화진
# (주)화진
# (주)화진
# 디브이에스코리아(주)
# 디에스티(주)
# 디에스티(주)
# 디에스티(주)
# 레이젠(주)
# 미리넷(주)
# 미리넷(주)
# 에이스하이텍(주)
# 엠텍비젼(주)
# 우경(주)
# 이엘케이(주)
# 잘만테크(주)
# 잘만테크(주)
# 태산엘시디(주)
# 태산엘시디(주)
# 텔슨정보통신(주)

# %%
dpt_list
# Out:
# ['(주)나리지*온',
#  '(주)단성일렉트론',
#  '(주)도움',
#  '(주)드림티엔터테인먼트',
#  '(주)디에스피이엔티',
#  '(주)레이더스컴퍼니',
#  '(주)미성포리테크',
#  '(주)블루스톤디앤아이',
#  '(주)블루젬디앤씨',
#  '(주)삼우이엠씨',
#  '(주)세븐코스프',
#  '(주)스틸플라워',
#  '(주)스틸플라워',
#  '(주)스페이스솔루션',
#  '(주)시스컴',
#  '(주)신양오라컴디스플레이',
#  '(주)쌈지',
#  '(주)쓰리소프트',
#  '(주)씨그널엔터테인먼트그룹',
#  '(주)씨모텍',
#  '(주)씨앤케이인터내셔널',
#  '(주)씨티앤티',
#  '(주)아라온테크',
#  '(주)아이디에스',
#  '(주)아이디에이치',
#  '(주)아이엠텍',
#  '(주)아이팩토리',
#  '(주)아이팩토리',
#  '(주)아큐텍',
#  '(주)애드모바일',
#  '(주)에스마크',
#  '(주)에스에스컴텍',
#  '(주)에스에프씨',
#  '(주)에피밸리',
#  '(주)엔에스브이',
#  '(주)엔케이바이오',
#  '(주)엘앤씨피',
#  '(주)영진코퍼레이션',
#  '(주)와이즈파워',
#  '(주)와이즈파워',
#  '(주)우전',
#  '(주)유니드코리아',
#  '(주)유아이에너지',
#  '(주)이노블루',
#  '(주)이엠네트웍스',
#  '(주)제낙스',
#  '(주)제너시스템즈',
#  '(주)주노콜렉션',
#  '(주)중앙디자인',
#  '(주)케이알',
#  '(주)택산아이엔씨',
#  '(주)트레이스',
#  '(주)트레이스',
#  '(주)플러스프로핏',
#  '(주)피앤텔',
#  '(주)피앤텔',
#  '(주)한신코퍼레이션',
#  '(주)화진',
#  '(주)화진',
#  '(주)화진',
#  '디브이에스코리아(주)',
#  '디에스티(주)',
#  '디에스티(주)',
#  '디에스티(주)',
#  '레이젠(주)',
#  '미리넷(주)',
# ...

# %% [markdown]
# # **킹가다 시작**
#
# 1. 회계첫년도가 부도 0 일때는 1로 대체

# %% [markdown]
# ## **(주)나리지*온**
#
# - 나라지온 상폐사유 - 피인수합병
# - 정상 기업으로 인식

# %%
dataset.loc[dataset['회사명'] == '(주)나리지*온','부도'] = 1

# %% [markdown]
# ## **(주)단성일렉트론**
#
# - 단성일렉트론

# %%
dataset.loc[dataset['회사명'] == '(주)단성일렉트론']
# Out:
#             회사명    거래소코드     회계년도  소속코드       상장폐지일 감사의견코드  자기자본배당률  \
# 1372  (주)단성일렉트론  85990.0  2003/12   4.0  2010/05/08     QS      0.0
# 1373  (주)단성일렉트론  85990.0  2004/12   4.0  2010/05/08     UQ      0.0
# 1374  (주)단성일렉트론  85990.0  2005/12   4.0  2010/05/08     UQ      0.0
# 1375  (주)단성일렉트론  85990.0  2006/12   4.0  2010/05/08     UQ      0.0
# 1376  (주)단성일렉트론  85990.0  2007/12   4.0  2010/05/08     UQ      0.0
# 1377  (주)단성일렉트론  85990.0  2008/12   4.0  2010/05/08     UQ      0.0
# 1378  (주)단성일렉트론  85990.0  2009/12   4.0  2010/05/08     DS      0.0
#
#       금융비용 대 부채비율  자기자본배율  유동부채비율  ...        key   부도             공시발생일  \
# 1372     0.029144  274.08   60.32  ...  859902004  0.0                 0
# 1373     0.025842  274.08   60.32  ...  859902005  1.0                 0
# 1374     0.039066  474.43   38.48  ...  859902006  1.0                 0
# 1375     0.028542  889.10   19.06  ...  859902007  1.0                 0
# ...

# %%
dataset.at[1372,'부도'] = 1

# %% [markdown]
# ## **(주)도움**

# %%
dataset.loc[dataset['회사명'] == dpt_list[2]]
# Out:
#         회사명    거래소코드     회계년도  소속코드       상장폐지일 감사의견코드  자기자본배당률  금융비용 대 부채비율  \
# 1839  (주)도움  78610.0  2002/12   4.0  2009/04/11     QS     0.00     0.012630
# 1840  (주)도움  78610.0  2003/12   4.0  2009/04/11     UQ     0.00     0.028399
# 1841  (주)도움  78610.0  2004/12   4.0  2009/04/11     UQ     0.00     0.030513
# 1842  (주)도움  78610.0  2005/12   4.0  2009/04/11     UQ     4.37     0.015891
# 1843  (주)도움  78610.0  2006/12   4.0  2009/04/11     UQ     0.00     0.013039
# 1844  (주)도움  78610.0  2007/12   4.0  2009/04/11     UQ     0.00     0.031413
# 1845  (주)도움  78610.0  2008/12   4.0  2009/04/11     DU     0.00     0.061341
#
#       자기자본배율  유동부채비율  ...        key   부도             공시발생일  정기공시제목  수시공시제목  \
# 1839  612.97   98.66  ...  786102003  0.0                 0       0       0
# 1840  612.97   98.66  ...  786102004  1.0                 0       0       0
# 1841  825.10   69.72  ...  786102005  1.0                 0       0       0
# ...

# %%
dataset.at[1839,'부도'] = 1

# %% [markdown]
# ## **(주)드림티엔터테인먼트**
#     - 부도인식 시점 2018년
#     - why? 상폐사유 감사의견코드 DS가 18년에 발생

# %%
dataset.loc[dataset['회사명'] == dpt_list[3]]
# Out:
#                회사명     거래소코드     회계년도  소속코드       상장폐지일 감사의견코드  자기자본배당률  \
# 2204  (주)드림티엔터테인먼트  220110.0  2014/12   4.0  2020/04/10     UQ      0.0
# 2205  (주)드림티엔터테인먼트  220110.0  2015/12   4.0  2020/04/10     UQ      0.0
# 2206  (주)드림티엔터테인먼트  220110.0  2016/12   4.0  2020/04/10     UQ      0.0
# 2207  (주)드림티엔터테인먼트  220110.0  2017/12   4.0  2020/04/10     UQ      0.0
# 2208  (주)드림티엔터테인먼트  220110.0  2018/12   4.0  2020/04/10     DS      0.0
# 2209  (주)드림티엔터테인먼트  220110.0  2019/12   4.0  2020/04/10     DS      0.0
#
#       금융비용 대 부채비율  자기자본배율   유동부채비율  ...         key   부도  공시발생일  정기공시제목  \
# 2204     0.019723  344.80   203.38  ...  2201102015  1.0      0       0
# 2205     0.023678  344.80   203.38  ...  2201102016  1.0      0       0
# 2206     0.069367  534.54    46.63  ...  2201102017  1.0      0       0
# 2207     0.003958  464.97    30.06  ...  2201102018  1.0      0       0
# 2208     0.011390   30.41  1167.12  ...  2201102019  0.0      0       0
# ...

# %%
dataset.iloc[2208:2210][dataset.columns[:-8]]
# Out:
#                회사명     거래소코드     회계년도  소속코드       상장폐지일 감사의견코드  자기자본배당률  \
# 2208  (주)드림티엔터테인먼트  220110.0  2018/12   4.0  2020/04/10     DS      0.0
# 2209  (주)드림티엔터테인먼트  220110.0  2019/12   4.0  2020/04/10     DS      0.0
#
#       금융비용 대 부채비율  자기자본배율   유동부채비율  매입채무회전률  유동자산회전률  총자본투자효율  순운전자본비율  \
# 2208      0.01139   30.41  1167.12      0.0     3.43  -103.14   -76.41
# 2209      0.03022   70.92    71.90      0.0     2.69    66.13    31.27
#
#        누적수익성비율  총자산영업이익률    총자산회전율       년         key   부도
# 2208 -1.321803  0.004098  0.881803  2019.0  2201102019  0.0
# 2209 -3.011132  0.201919  1.474472  2020.0  2201102020  0.0

# %%
dataset.drop(index=2209, inplace=True)

# %%
dataset.reset_index(inplace=True, drop=True)

# %% [markdown]
# ## **(주)디에스피이엔티**

# %%
dataset.loc[dataset['회사명'] == dpt_list[4]]
# Out:
#              회사명    거래소코드     회계년도  소속코드       상장폐지일 감사의견코드  자기자본배당률  \
# 2335  (주)디에스피이엔티  16040.0  2000/12   4.0  2009/04/11     UQ     0.00
# 2336  (주)디에스피이엔티  16040.0  2001/12   4.0  2009/04/11     UQ     0.87
# 2337  (주)디에스피이엔티  16040.0  2002/12   4.0  2009/04/11     UQ     0.86
# 2338  (주)디에스피이엔티  16040.0  2003/12   4.0  2009/04/11     UQ     0.00
# 2339  (주)디에스피이엔티  16040.0  2004/12   4.0  2009/04/11     UQ     0.00
# 2340  (주)디에스피이엔티  16040.0  2005/12   4.0  2009/04/11     UQ     0.00
# 2341  (주)디에스피이엔티  16040.0  2006/12   4.0  2009/04/11     UQ     0.00
# 2342  (주)디에스피이엔티  16040.0  2007/12   4.0  2009/04/11     UQ     0.00
# 2343  (주)디에스피이엔티  16040.0  2008/12   4.0  2009/04/11     DU     0.00
#
#       금융비용 대 부채비율   자기자본배율  유동부채비율  ...        key   부도             공시발생일  \
# 2335     0.054773   965.21   50.86  ...  160402001  1.0                 0
# 2336     0.040659  1150.09   41.03  ...  160402002  1.0                 0
# ...

# %%
dataset.drop(index=2343, inplace = True)
dataset.reset_index(inplace=True, drop=True)

# %% [markdown]
# ## **레이더스컴퍼니**

# %%
dataset.loc[dataset['회사명'] == dpt_list[5], dataset.columns[:-8]]
# Out:
#              회사명    거래소코드     회계년도  소속코드       상장폐지일 감사의견코드  자기자본배당률  \
# 2826  (주)레이더스컴퍼니  47420.0  2000/03   4.0  2006/07/13     UQ      0.0
# 2827  (주)레이더스컴퍼니  47420.0  2001/03   4.0  2006/07/13     UQ      0.0
# 2828  (주)레이더스컴퍼니  47420.0  2002/03   4.0  2006/07/13     UQ      0.0
# 2829  (주)레이더스컴퍼니  47420.0  2003/03   4.0  2006/07/13     UQ      0.0
# 2830  (주)레이더스컴퍼니  47420.0  2004/03   4.0  2006/07/13     UQ      0.0
# 2831  (주)레이더스컴퍼니  47420.0  2005/03   4.0  2006/07/13     UQ      0.0
# 2832  (주)레이더스컴퍼니  47420.0  2006/03   4.0  2006/07/13     DU      0.0
#
#       금융비용 대 부채비율  자기자본배율  유동부채비율  매입채무회전률  유동자산회전률  총자본투자효율  순운전자본비율  \
# 2826     0.016393  154.49   76.76     6.86     2.22    31.99    22.44
# 2827     0.005173  154.49   76.76     6.86     2.22    31.99    22.44
# 2828     0.036522  194.51   57.44    10.48     2.77    68.66    22.91
# 2829     0.018142  212.38   23.63     9.47     2.00     8.05    40.56
# ...

# %%
dataset.drop(index=2832,inplace=True)
dataset.reset_index(drop=True, inplace=True)

# %% [markdown]
# ## **(주)미성포리테크**

# %%
dataset.loc[dataset['회사명'] == dpt_list[6], dataset.columns[:-8]]
# Out:
#             회사명    거래소코드     회계년도  소속코드       상장폐지일 감사의견코드  자기자본배당률  \
# 3727  (주)미성포리테크  94700.0  2004/12   4.0  2012/04/13     UQ     0.00
# 3728  (주)미성포리테크  94700.0  2005/12   4.0  2012/04/13     UQ     0.00
# 3729  (주)미성포리테크  94700.0  2006/12   4.0  2012/04/13     UQ     0.00
# 3730  (주)미성포리테크  94700.0  2007/12   4.0  2012/04/13     UQ     2.38
# 3731  (주)미성포리테크  94700.0  2008/12   4.0  2012/04/13     UQ     0.00
# 3732  (주)미성포리테크  94700.0  2009/12   4.0  2012/04/13     UQ     0.00
# 3733  (주)미성포리테크  94700.0  2010/12   4.0  2012/04/13     UQ     0.00
# 3734  (주)미성포리테크  94700.0  2011/12   4.0  2012/04/13     DU     0.00
#
#       금융비용 대 부채비율   자기자본배율  유동부채비율  매입채무회전률  유동자산회전률  총자본투자효율  순운전자본비율  \
# 3727     0.009707   502.44  210.50     5.11     4.04    18.22   -12.27
# 3728     0.020644   502.44  210.50     5.11     4.04    18.22   -12.27
# 3729     0.021594   824.65  157.27     6.94     3.95    29.24    -0.99
# ...

# %%
dataset.drop(index=3734,inplace=True)
dataset.reset_index(drop=True, inplace=True)

# %% [markdown]
# ## **(주)블루스톤디앤아이**
#
# 1. kind에서 확인한 바 2003년에 상장폐지 없음

# %%
dataset.loc[dataset['회사명'] == dpt_list[7], dataset.columns[:-8]]
# Out:
#               회사명    거래소코드     회계년도  소속코드       상장폐지일 감사의견코드  자기자본배당률  \
# 4308  (주)블루스톤디앤아이  33720.0  2000/12   4.0  2009/05/15     UQ     1.19
# 4309  (주)블루스톤디앤아이  33720.0  2001/12   4.0  2009/05/15     UQ     0.00
# 4310  (주)블루스톤디앤아이  33720.0  2002/12   4.0  2009/05/15     UQ     0.00
# 4311  (주)블루스톤디앤아이  33720.0  2003/12   4.0  2009/05/15     QG     0.00
# 4312  (주)블루스톤디앤아이  33720.0  2004/12   4.0  2009/05/15     UQ     0.00
# 4313  (주)블루스톤디앤아이  33720.0  2005/12   4.0  2009/05/15     UQ     0.00
# 4314  (주)블루스톤디앤아이  33720.0  2006/12   4.0  2009/05/15     QU     0.00
# 4315  (주)블루스톤디앤아이  33720.0  2007/12   4.0  2009/05/15     UQ     0.00
# 4316  (주)블루스톤디앤아이  33720.0  2008/12   4.0  2009/05/15     DU     0.00
#
#       금융비용 대 부채비율   자기자본배율  유동부채비율  매입채무회전률  유동자산회전률  총자본투자효율  순운전자본비율  \
# 4308     0.045371   843.24   14.72    15.41     0.80    11.87    66.05
# 4309     0.049355   531.35   32.72    22.47     1.11   -25.68    53.58
# ...

# %%
dataset.at[4311,'부도'] = 1

# %% [markdown]
# ## **(주)블루젬디앤씨**
#
# 1. kind 공시 확인 시 상폐사유인 파산신청 확인은 2011/11/18에 발생
# - 이전 회계 기간인 2010년에 부도 시점

# %%
dataset.loc[dataset['회사명'] == dpt_list[8], dataset.columns[:]]
# Out:
#             회사명    거래소코드     회계년도  소속코드       상장폐지일 감사의견코드  자기자본배당률  \
# 4317  (주)블루젬디앤씨  53040.0  2000/12   4.0  2012/05/17     UQ     3.09
# 4318  (주)블루젬디앤씨  53040.0  2001/12   4.0  2012/05/17     UQ     3.09
# 4319  (주)블루젬디앤씨  53040.0  2002/12   4.0  2012/05/17     UQ     0.00
# 4320  (주)블루젬디앤씨  53040.0  2003/12   4.0  2012/05/17     UQ     0.00
# 4321  (주)블루젬디앤씨  53040.0  2004/12   4.0  2012/05/17     UQ     0.00
# 4322  (주)블루젬디앤씨  53040.0  2005/12   4.0  2012/05/17     UQ     0.00
# 4323  (주)블루젬디앤씨  53040.0  2006/12   4.0  2012/05/17     UQ     0.00
# 4324  (주)블루젬디앤씨  53040.0  2007/12   4.0  2012/05/17     UQ     0.00
# 4325  (주)블루젬디앤씨  53040.0  2008/12   4.0  2012/05/17     UQ     0.00
# 4326  (주)블루젬디앤씨  53040.0  2009/12   4.0  2012/05/17     UQ     0.00
# 4327  (주)블루젬디앤씨  53040.0  2010/12   4.0  2012/05/17     UQ     0.00
# 4328  (주)블루젬디앤씨  53040.0  2011/12   4.0  2012/05/17     DU     0.00
#
#       금융비용 대 부채비율  자기자본배율  유동부채비율  ...        key   부도             공시발생일  \
# ...

# %%
dataset.drop(index=4328,inplace=True)
dataset.reset_index(drop=True, inplace=True)

# %% [markdown]
# ## **(주)삼우이엠씨**

# %%
dataset.loc[dataset['회사명'] == dpt_list[9], dataset.columns[:]]
# Out:
#            회사명    거래소코드     회계년도  소속코드       상장폐지일 감사의견코드  자기자본배당률  \
# 4759  (주)삼우이엠씨  26250.0  2000/12   4.0  2013/04/12     UQ     1.03
# 4760  (주)삼우이엠씨  26250.0  2001/12   4.0  2013/04/12     UQ     1.80
# 4761  (주)삼우이엠씨  26250.0  2002/12   4.0  2013/04/12     UQ     1.44
# 4762  (주)삼우이엠씨  26250.0  2003/12   4.0  2013/04/12     UQ     2.58
# 4763  (주)삼우이엠씨  26250.0  2004/12   4.0  2013/04/12     UQ     2.24
# 4764  (주)삼우이엠씨  26250.0  2005/12   4.0  2013/04/12     UQ     2.89
# 4765  (주)삼우이엠씨  26250.0  2006/12   4.0  2013/04/12     UQ     2.62
# 4766  (주)삼우이엠씨  26250.0  2007/12   4.0  2013/04/12     UQ     2.96
# 4767  (주)삼우이엠씨  26250.0  2008/12   4.0  2013/04/12     UQ     0.00
# 4768  (주)삼우이엠씨  26250.0  2009/12   4.0  2013/04/12     UQ     0.00
# 4769  (주)삼우이엠씨  26250.0  2010/12   4.0  2013/04/12     UQ     0.00
# 4770  (주)삼우이엠씨  26250.0  2011/12   4.0  2013/04/12     UQ     0.00
# 4771  (주)삼우이엠씨  26250.0  2012/12   4.0  2013/04/12     DU     0.00
#
# ...

# %%
dataset.at[4770,'부도'] = 1

# %% [markdown]
# ## **(주)세븐코스프**

# %%
dataset.loc[dataset['회사명'] == dpt_list[10], dataset.columns[:]]
# Out:
#            회사명    거래소코드     회계년도  소속코드       상장폐지일 감사의견코드  자기자본배당률  \
# 5563  (주)세븐코스프  17160.0  2000/12   4.0  2011/04/29     UQ      0.0
# 5564  (주)세븐코스프  17160.0  2001/12   4.0  2011/04/29     UQ      0.0
# 5565  (주)세븐코스프  17160.0  2002/12   4.0  2011/04/29     UQ      0.0
# 5566  (주)세븐코스프  17160.0  2003/12   4.0  2011/04/29     UQ      0.0
# 5567  (주)세븐코스프  17160.0  2004/12   4.0  2011/04/29     UQ      0.0
# 5568  (주)세븐코스프  17160.0  2005/12   4.0  2011/04/29     UQ      0.0
# 5569  (주)세븐코스프  17160.0  2006/12   4.0  2011/04/29     UQ      0.0
# 5570  (주)세븐코스프  17160.0  2007/12   4.0  2011/04/29     UQ      0.0
# 5571  (주)세븐코스프  17160.0  2008/12   4.0  2011/04/29     UQ      0.0
# 5572  (주)세븐코스프  17160.0  2009/12   4.0  2011/04/29     UQ      0.0
# 5573  (주)세븐코스프  17160.0  2010/12   4.0  2011/04/29     DU      0.0
#
#       금융비용 대 부채비율  자기자본배율  유동부채비율  ...        key   부도             공시발생일  \
# 5563     0.068746  127.50   32.31  ...  171602001  0.0                 0
# ...

# %%
dataset.at[5563,'부도'] = 1

# %% [markdown]
# ## **(주)스틸플라워**
# - dpt_list 11 12

# %%
dataset.loc[dataset['회사명'] == dpt_list[12], dataset.columns[:]]
# Out:
#            회사명    거래소코드     회계년도  소속코드       상장폐지일 감사의견코드  자기자본배당률  \
# 6218  (주)스틸플라워  87220.0  2002/12   4.0  2018/05/08     UQ     0.00
# 6219  (주)스틸플라워  87220.0  2003/12   4.0  2018/05/08     QS     0.00
# 6220  (주)스틸플라워  87220.0  2004/12   4.0  2018/05/08     UQ     0.00
# 6221  (주)스틸플라워  87220.0  2005/12   4.0  2018/05/08     UQ     0.00
# 6222  (주)스틸플라워  87220.0  2006/12   4.0  2018/05/08     UQ     0.00
# 6223  (주)스틸플라워  87220.0  2007/12   4.0  2018/05/08     UQ     0.32
# 6224  (주)스틸플라워  87220.0  2008/12   4.0  2018/05/08     UQ     1.13
# 6225  (주)스틸플라워  87220.0  2009/12   4.0  2018/05/08     UQ     1.88
# 6226  (주)스틸플라워  87220.0  2010/12   4.0  2018/05/08     UQ     0.00
# 6227  (주)스틸플라워  87220.0  2011/12   4.0  2018/05/08     UQ     1.24
# 6228  (주)스틸플라워  87220.0  2012/12   4.0  2018/05/08     UQ     0.59
# 6229  (주)스틸플라워  87220.0  2013/12   4.0  2018/05/08     UQ     0.00
# 6230  (주)스틸플라워  87220.0  2014/12   4.0  2018/05/08     UQ     0.00
# ...

# %%
dataset.at[6219,'부도'] = 1

# %% [markdown]
# ## **(주)스페이스솔루션**
# - 회계년도 6년치 결측으로 해당 기업은 드랍하겠습니다.

# %%
dataset.loc[dataset['회사명'] == dpt_list[13], dataset.columns[:]]
# Out:
#              회사명     거래소코드     회계년도  소속코드       상장폐지일 감사의견코드  자기자본배당률  \
# 6234  (주)스페이스솔루션  245030.0  2007/12   4.0  2019/02/27      0     0.00
# 6235  (주)스페이스솔루션  245030.0  2008/12   4.0  2019/02/27     QS     0.00
# 6236  (주)스페이스솔루션  245030.0  2014/12   4.0  2019/02/27     QS     0.00
# 6237  (주)스페이스솔루션  245030.0  2015/12   4.0  2019/02/27     UQ     0.80
# 6238  (주)스페이스솔루션  245030.0  2016/12   4.0  2019/02/27     UQ     0.00
# 6239  (주)스페이스솔루션  245030.0  2017/12   4.0  2019/02/27     UQ     0.59
#
#       금융비용 대 부채비율   자기자본배율  유동부채비율  ...         key   부도  공시발생일  정기공시제목  \
# 6234     0.007536   571.41  160.49  ...  2450302008  1.0      0       0
# 6235     0.010424   571.41  160.49  ...  2450302009  0.0      0       0
# 6236     0.016275   917.64  157.07  ...  2450302015  0.0      0       0
# 6237     0.020316  1160.36   91.99  ...  2450302016  1.0      0       0
# 6238     0.021708   991.61  125.90  ...  2450302017  1.0      0       0
# ...

# %%
dftidx = [6234,6235,6236,6237,6238,6239]

# %%
dataset.drop(index=dftidx,inplace=True)
dataset.reset_index(drop=True, inplace=True)

# %% [markdown]
# ## **(주)시스컴**

# %%
dataset.loc[dataset['회사명'] == dpt_list[14], dataset.columns[:]]
# Out:
#          회사명    거래소코드     회계년도  소속코드       상장폐지일 감사의견코드  자기자본배당률  금융비용 대 부채비율  \
# 6385  (주)시스컴  37280.0  2000/12   4.0  2003/03/29     QS      0.0     0.037372
# 6386  (주)시스컴  37280.0  2001/12   4.0  2003/03/29     UQ      0.0     0.049240
# 6387  (주)시스컴  37280.0  2002/12   4.0  2003/03/29     NS      0.0     0.049240
#
#       자기자본배율  유동부채비율  ...        key   부도             공시발생일  정기공시제목  수시공시제목  \
# 6385   482.8  166.84  ...  372802001  0.0                 0       0       0
# 6386   482.8  166.84  ...  372802002  1.0                 0       0       0
# 6387   482.8  166.84  ...  372802003  0.0  2003-03-17 18:11       0    상장폐지
#
#       대표이사 변경  최대주주 변경  회계처리위반  횡령배임           폐지사유요약합본
# 6385      0.0      0.0     0.0   0.0              ['N']
# 6386      2.0      0.0     1.0   0.0              ['N']
# 6387      0.0      0.0     0.0   0.0  ['최종부도 및 은행거래정지']
#
# [3 rows x 28 columns]

# %%
dataset.at[6385,'부도'] = 1

# %% [markdown]
# ## **(주)신양오라컴디스플레이**

# %%
dataset.loc[dataset['회사명'] == dpt_list[15], dataset.columns[:]]
# Out:
#                 회사명    거래소코드     회계년도  소속코드       상장폐지일 감사의견코드  자기자본배당률  \
# 6450  (주)신양오라컴디스플레이  86830.0  2000/12   4.0  2017/05/08     UQ    22.60
# 6451  (주)신양오라컴디스플레이  86830.0  2001/12   4.0  2017/05/08     UQ     0.00
# 6452  (주)신양오라컴디스플레이  86830.0  2002/12   4.0  2017/05/08     UQ     0.00
# 6453  (주)신양오라컴디스플레이  86830.0  2003/12   4.0  2017/05/08     UQ     7.70
# 6454  (주)신양오라컴디스플레이  86830.0  2004/12   4.0  2017/05/08     UQ     2.43
# 6455  (주)신양오라컴디스플레이  86830.0  2005/12   4.0  2017/05/08     UQ     0.00
# 6456  (주)신양오라컴디스플레이  86830.0  2006/12   4.0  2017/05/08     UQ     0.00
# 6457  (주)신양오라컴디스플레이  86830.0  2007/12   4.0  2017/05/08     UQ     2.12
# 6458  (주)신양오라컴디스플레이  86830.0  2008/12   4.0  2017/05/08     UQ     0.00
# 6459  (주)신양오라컴디스플레이  86830.0  2009/12   4.0  2017/05/08     UQ     0.00
# 6460  (주)신양오라컴디스플레이  86830.0  2010/12   4.0  2017/05/08     UQ     0.00
# 6461  (주)신양오라컴디스플레이  86830.0  2011/12   4.0  2017/05/08     UQ     0.00
# ...

# %%
dataset.at[6465,'부도'] = 1

# %% [markdown]
# ## **(주)쌈지**

# %%
dataset.loc[dataset['회사명'] == dpt_list[16], dataset.columns[:]]
# Out:
#         회사명    거래소코드     회계년도  소속코드       상장폐지일 감사의견코드  자기자본배당률  금융비용 대 부채비율  \
# 6611  (주)쌈지  33260.0  2000/12   4.0  2010/04/17     QS     0.00     0.043339
# 6612  (주)쌈지  33260.0  2001/12   4.0  2010/04/17     UQ     1.61     0.043858
# 6613  (주)쌈지  33260.0  2002/12   4.0  2010/04/17     UQ     0.72     0.029037
# 6614  (주)쌈지  33260.0  2003/12   4.0  2010/04/17     UQ     0.00     0.036306
# 6615  (주)쌈지  33260.0  2004/12   4.0  2010/04/17     UQ     0.00     0.062537
# 6616  (주)쌈지  33260.0  2005/12   4.0  2010/04/17     UQ     0.00     0.033711
# 6617  (주)쌈지  33260.0  2006/12   4.0  2010/04/17     UQ     0.00     0.032824
# 6618  (주)쌈지  33260.0  2007/12   4.0  2010/04/17     UQ     0.00     0.036317
# 6619  (주)쌈지  33260.0  2008/12   4.0  2010/04/17     UQ     0.00     0.049961
# 6620  (주)쌈지  33260.0  2009/12   4.0  2010/04/17     DS     0.00     0.069599
#
#       자기자본배율  유동부채비율  ...        key   부도             공시발생일  정기공시제목  수시공시제목  \
# ...

# %%
dataset.at[6611,'부도'] = 1

# %% [markdown]
# ## **(주)쓰리소프트**

# %%
dataset.loc[dataset['회사명'] == dpt_list[17], dataset.columns[:]]
# Out:
#            회사명    거래소코드     회계년도  소속코드       상장폐지일 감사의견코드  자기자본배당률  \
# 6799  (주)쓰리소프트  36360.0  2000/12   4.0  2009/04/29     UQ      0.0
# 6800  (주)쓰리소프트  36360.0  2001/12   4.0  2009/04/29     UQ      0.0
# 6801  (주)쓰리소프트  36360.0  2002/12   4.0  2009/04/29     UQ      0.0
# 6802  (주)쓰리소프트  36360.0  2003/12   4.0  2009/04/29     UQ      0.0
# 6803  (주)쓰리소프트  36360.0  2004/12   4.0  2009/04/29     UQ      0.0
# 6804  (주)쓰리소프트  36360.0  2005/12   4.0  2009/04/29     UQ      0.0
# 6805  (주)쓰리소프트  36360.0  2006/12   4.0  2009/04/29     UQ      0.0
# 6806  (주)쓰리소프트  36360.0  2007/12   4.0  2009/04/29     UQ      0.0
# 6807  (주)쓰리소프트  36360.0  2008/12   4.0  2009/04/29     DU      0.0
#
#       금융비용 대 부채비율  자기자본배율  유동부채비율  ...        key   부도             공시발생일  \
# 6799     0.000621  374.26   13.01  ...  363602001  1.0                 0
# 6800     0.000291  337.85   33.57  ...  363602002  1.0                 0
# 6801     0.000000  246.24    6.97  ...  363602003  1.0                 0
# ...

# %%
dftidx = [6803,6804,6805,6806,6807]

# %%
dataset.drop(index=dftidx,inplace=True)
dataset.reset_index(drop=True, inplace=True)

# %% [markdown]
# ## **주)씨그널엔터테인먼트그룹**

# %%
dataset.loc[dataset['회사명'] == dpt_list[18], dataset.columns[:]]
# Out:
#                  회사명    거래소코드     회계년도  소속코드       상장폐지일 감사의견코드  자기자본배당률  \
# 6803  (주)씨그널엔터테인먼트그룹  99830.0  2001/12   4.0  2018/05/04     QS     6.46
# 6804  (주)씨그널엔터테인먼트그룹  99830.0  2002/12   4.0  2018/05/04     UQ     6.46
# 6805  (주)씨그널엔터테인먼트그룹  99830.0  2003/12   4.0  2018/05/04     UQ     2.87
# 6806  (주)씨그널엔터테인먼트그룹  99830.0  2004/12   4.0  2018/05/04     UQ     7.44
# 6807  (주)씨그널엔터테인먼트그룹  99830.0  2005/12   4.0  2018/05/04     UQ     5.91
# 6808  (주)씨그널엔터테인먼트그룹  99830.0  2006/12   4.0  2018/05/04     UQ     9.55
# 6809  (주)씨그널엔터테인먼트그룹  99830.0  2007/12   4.0  2018/05/04     UQ     6.68
# 6810  (주)씨그널엔터테인먼트그룹  99830.0  2008/12   4.0  2018/05/04     UQ     2.90
# 6811  (주)씨그널엔터테인먼트그룹  99830.0  2009/12   4.0  2018/05/04     UQ     3.86
# 6812  (주)씨그널엔터테인먼트그룹  99830.0  2010/12   4.0  2018/05/04     UQ     3.29
# 6813  (주)씨그널엔터테인먼트그룹  99830.0  2011/12   4.0  2018/05/04     UQ     1.23
# 6814  (주)씨그널엔터테인먼트그룹  99830.0  2012/12   4.0  2018/05/04     UQ     0.00
# ...

# %% [markdown]
# ## **(주)씨모텍**

# %%
dataset.loc[dataset['회사명'] == dpt_list[19], dataset.columns[:-8]]
# Out:
#          회사명    거래소코드     회계년도  소속코드       상장폐지일 감사의견코드  자기자본배당률  금융비용 대 부채비율  \
# 6831  (주)씨모텍  81090.0  2004/12   4.0  2011/09/23     QS     0.00     0.037838
# 6832  (주)씨모텍  81090.0  2005/12   4.0  2011/09/23     UQ     0.00     0.052516
# 6833  (주)씨모텍  81090.0  2006/12   4.0  2011/09/23     UQ     0.00     0.038959
# 6834  (주)씨모텍  81090.0  2007/12   4.0  2011/09/23     UQ     1.26     0.027968
# 6835  (주)씨모텍  81090.0  2008/12   4.0  2011/09/23     UQ     0.00     0.007265
# 6836  (주)씨모텍  81090.0  2009/12   4.0  2011/09/23     UQ     0.00     0.038055
# 6837  (주)씨모텍  81090.0  2010/12   4.0  2011/09/23     DS     0.00     0.084908
#
#        자기자본배율  유동부채비율  매입채무회전률  유동자산회전률  총자본투자효율  순운전자본비율   누적수익성비율  총자산영업이익률  \
# 6831   431.13   71.02    31.90     2.51    38.21    20.79  0.005156  0.069969
# 6832   431.13   71.02    31.90     2.51    38.21    20.79  0.204408  0.186814
# 6833   767.24   37.60    35.50     3.36    32.03    29.52  0.310983  0.229950
# ...

# %%
dataset.at[6831,'부도'] = 1

# %% [markdown]
# ## **(주)씨앤케이인터내셔널**

# %%
dataset.loc[dataset['회사명'] == dpt_list[20], dataset.columns[:-8]]
# Out:
#                회사명    거래소코드     회계년도  소속코드       상장폐지일 감사의견코드  자기자본배당률  \
# 6882  (주)씨앤케이인터내셔널  39530.0  2000/12   4.0  2015/05/19     UQ     7.74
# 6883  (주)씨앤케이인터내셔널  39530.0  2001/12   4.0  2015/05/19     UQ     6.00
# 6884  (주)씨앤케이인터내셔널  39530.0  2002/12   4.0  2015/05/19     UQ     0.00
# 6885  (주)씨앤케이인터내셔널  39530.0  2003/12   4.0  2015/05/19     UQ     0.00
# 6886  (주)씨앤케이인터내셔널  39530.0  2004/12   4.0  2015/05/19     UQ     0.00
# 6887  (주)씨앤케이인터내셔널  39530.0  2005/12   4.0  2015/05/19     UQ     0.00
# 6888  (주)씨앤케이인터내셔널  39530.0  2006/12   4.0  2015/05/19     UQ     0.00
# 6889  (주)씨앤케이인터내셔널  39530.0  2007/12   4.0  2015/05/19     UQ     0.00
# 6890  (주)씨앤케이인터내셔널  39530.0  2008/12   4.0  2015/05/19     UQ     0.00
# 6891  (주)씨앤케이인터내셔널  39530.0  2009/12   4.0  2015/05/19     UQ     0.00
# 6892  (주)씨앤케이인터내셔널  39530.0  2010/12   4.0  2015/05/19     UQ     0.00
# 6893  (주)씨앤케이인터내셔널  39530.0  2011/12   4.0  2015/05/19     UQ     0.00
# ...

# %%
dataset.at[6893, '부도'] = 1

# %% [markdown]
# ## **(주)씨티앤티**

# %%
dataset.loc[dataset['회사명'] == dpt_list[21], dataset.columns[:-8]]
# Out:
#           회사명    거래소코드     회계년도  소속코드       상장폐지일 감사의견코드  자기자본배당률  \
# 7120  (주)씨티앤티  50470.0  2001/12   4.0  2012/05/01     UQ      0.0
# 7121  (주)씨티앤티  50470.0  2002/12   4.0  2012/05/01     UQ      0.0
# 7122  (주)씨티앤티  50470.0  2003/12   4.0  2012/05/01     UQ      0.0
# 7123  (주)씨티앤티  50470.0  2004/12   4.0  2012/05/01     UQ      0.0
# 7124  (주)씨티앤티  50470.0  2005/12   4.0  2012/05/01     UQ      0.0
# 7125  (주)씨티앤티  50470.0  2006/12   4.0  2012/05/01     UQ      0.0
# 7126  (주)씨티앤티  50470.0  2007/12   4.0  2012/05/01     UQ      0.0
# 7127  (주)씨티앤티  50470.0  2008/12   4.0  2012/05/01     UQ      0.0
# 7128  (주)씨티앤티  50470.0  2009/12   4.0  2012/05/01     UQ      0.0
# 7129  (주)씨티앤티  50470.0  2010/12   4.0  2012/05/01     UQ      0.0
# 7130  (주)씨티앤티  50470.0  2011/12   4.0  2012/05/01     DS      0.0
#
#       금융비용 대 부채비율  자기자본배율   유동부채비율  매입채무회전률  유동자산회전률  총자본투자효율  순운전자본비율  \
# 7120     0.001569  289.84     5.29    57.96     1.17    22.51    49.74
# ...

# %%
dataset.at[7129, '부도'] = 1

# %% [markdown]
# ## **(주)아라온테크**

# %%
dataset.loc[dataset['회사명'] == dpt_list[22], dataset.columns[:-8]]
# Out:
#            회사명    거래소코드     회계년도  소속코드       상장폐지일 감사의견코드  자기자본배당률  \
# 7207  (주)아라온테크  41060.0  2000/12   4.0  2014/05/08     UQ     1.06
# 7208  (주)아라온테크  41060.0  2001/12   4.0  2014/05/08     UQ     1.00
# 7209  (주)아라온테크  41060.0  2002/12   4.0  2014/05/08     UQ     0.00
# 7210  (주)아라온테크  41060.0  2003/12   4.0  2014/05/08     UQ     0.00
# 7211  (주)아라온테크  41060.0  2004/12   4.0  2014/05/08     UQ     0.00
# 7212  (주)아라온테크  41060.0  2005/12   4.0  2014/05/08     UQ     0.00
# 7213  (주)아라온테크  41060.0  2006/12   4.0  2014/05/08     UQ     0.00
# 7214  (주)아라온테크  41060.0  2007/12   4.0  2014/05/08     UQ     0.00
# 7215  (주)아라온테크  41060.0  2008/12   4.0  2014/05/08     UQ     0.00
# 7216  (주)아라온테크  41060.0  2009/12   4.0  2014/05/08     UQ     0.00
# 7217  (주)아라온테크  41060.0  2010/12   4.0  2014/05/08     UQ     0.00
# 7218  (주)아라온테크  41060.0  2011/12   4.0  2014/05/08     UQ     0.00
# 7219  (주)아라온테크  41060.0  2012/12   4.0  2014/05/08     UQ     0.00
# ...

# %%
dataset.at[7219,'부도'] = 1

# %% [markdown]
# ## **(주)아이디에스**

# %%
dataset.loc[dataset['회사명'] == dpt_list[23], dataset.columns[:-8]]
# Out:
#            회사명    거래소코드     회계년도  소속코드       상장폐지일 감사의견코드  자기자본배당률  \
# 7466  (주)아이디에스  78780.0  2002/12   4.0  2016/04/28     UQ     0.00
# 7467  (주)아이디에스  78780.0  2003/12   4.0  2016/04/28     UQ     0.00
# 7468  (주)아이디에스  78780.0  2004/12   4.0  2016/04/28     UQ     0.00
# 7469  (주)아이디에스  78780.0  2005/12   4.0  2016/04/28     UQ     0.00
# 7470  (주)아이디에스  78780.0  2006/12   4.0  2016/04/28     UQ     0.00
# 7471  (주)아이디에스  78780.0  2007/12   4.0  2016/04/28     UQ     2.47
# 7472  (주)아이디에스  78780.0  2008/12   4.0  2016/04/28     UQ     2.35
# 7473  (주)아이디에스  78780.0  2009/12   4.0  2016/04/28     UQ     0.00
# 7474  (주)아이디에스  78780.0  2010/12   4.0  2016/04/28     UQ     0.00
# 7475  (주)아이디에스  78780.0  2011/12   4.0  2016/04/28     UQ     0.00
# 7476  (주)아이디에스  78780.0  2012/12   4.0  2016/04/28     UQ     0.00
# 7477  (주)아이디에스  78780.0  2013/12   4.0  2016/04/28     UQ     0.00
# 7478  (주)아이디에스  78780.0  2014/12   4.0  2016/04/28     UQ     0.00
# ...

# %%
dataset.at[7478,'부도'] = 1

# %% [markdown]
# ## **(주)아이디에이치**

# %%
dataset.loc[dataset['회사명'] == dpt_list[24], dataset.columns[:-8]]
# Out:
#             회사명    거래소코드     회계년도  소속코드       상장폐지일 감사의견코드  자기자본배당률  \
# 7480  (주)아이디에이치  26230.0  2000/12   4.0  2009/04/29     UQ      0.0
# 7481  (주)아이디에이치  26230.0  2001/12   4.0  2009/04/29     UQ      0.0
# 7482  (주)아이디에이치  26230.0  2002/12   4.0  2009/04/29     UQ      0.0
# 7483  (주)아이디에이치  26230.0  2003/12   4.0  2009/04/29     UQ      0.0
# 7484  (주)아이디에이치  26230.0  2004/12   4.0  2009/04/29     UQ      0.0
# 7485  (주)아이디에이치  26230.0  2005/12   4.0  2009/04/29     UQ      0.0
# 7486  (주)아이디에이치  26230.0  2006/12   4.0  2009/04/29     UQ      0.0
# 7487  (주)아이디에이치  26230.0  2007/12   4.0  2009/04/29     UQ      0.0
# 7488  (주)아이디에이치  26230.0  2008/12   4.0  2009/04/29     DU      0.0
#
#       금융비용 대 부채비율  자기자본배율  유동부채비율  매입채무회전률  유동자산회전률  총자본투자효율  순운전자본비율  \
# 7480     0.053931  318.25   65.19     3.82     0.96    12.49    43.42
# 7481     0.062647  341.91   88.28     5.12     0.91    14.24    40.49
# 7482     0.059582  219.01  123.78     5.26     1.04     4.86    29.15
# ...

# %%
dataset.at[7487, '부도'] = 1

# %% [markdown]
# ## **(주)아이엠텍**

# %%
dataset.loc[dataset['회사명'] == dpt_list[25], dataset.columns[:-8]]
# Out:
#           회사명     거래소코드     회계년도  소속코드       상장폐지일 감사의견코드  자기자본배당률  \
# 7698  (주)아이엠텍  226350.0  2009/12   4.0  2021/06/11      0      0.0
# 7699  (주)아이엠텍  226350.0  2010/12   4.0  2021/06/11     UQ      0.0
# 7700  (주)아이엠텍  226350.0  2011/12   4.0  2021/06/11     UQ      0.0
# 7701  (주)아이엠텍  226350.0  2012/12   4.0  2021/06/11     UQ      0.0
# 7702  (주)아이엠텍  226350.0  2013/12   4.0  2021/06/11     UQ      0.0
# 7703  (주)아이엠텍  226350.0  2014/12   4.0  2021/06/11     UQ      0.0
# 7704  (주)아이엠텍  226350.0  2015/12   4.0  2021/06/11     UQ      0.0
# 7705  (주)아이엠텍  226350.0  2016/12   4.0  2021/06/11     UQ      0.0
# 7706  (주)아이엠텍  226350.0  2017/12   4.0  2021/06/11     UQ      0.0
# 7707  (주)아이엠텍  226350.0  2018/12   4.0  2021/06/11     UQ      0.0
# 7708  (주)아이엠텍  226350.0  2019/12   4.0  2021/06/11     DU      0.0
# 7709  (주)아이엠텍  226350.0  2020/12   4.0  2021/06/11     DU      0.0
#
#       금융비용 대 부채비율  자기자본배율  유동부채비율  매입채무회전률  유동자산회전률  총자본투자효율  순운전자본비율  \
# ...

# %%
dataset.at[7708, '부도'] = 1

# %% [markdown]
# ## **(주)아이팩토리**

# %%
dataset.loc[dataset['회사명'] == dpt_list[26], dataset.columns[:-8]]
# Out:
#            회사명    거래소코드     회계년도  소속코드       상장폐지일 감사의견코드  자기자본배당률  \
# 7870  (주)아이팩토리  53810.0  2001/12   4.0  2016/09/19     UQ      0.0
# 7871  (주)아이팩토리  53810.0  2002/12   4.0  2016/09/19     UQ      0.0
# 7872  (주)아이팩토리  53810.0  2003/12   4.0  2016/09/19     UQ      0.0
# 7873  (주)아이팩토리  53810.0  2004/12   4.0  2016/09/19     UQ      0.0
# 7874  (주)아이팩토리  53810.0  2005/12   4.0  2016/09/19     UQ      0.0
# 7875  (주)아이팩토리  53810.0  2006/12   4.0  2016/09/19     UQ      0.0
# 7876  (주)아이팩토리  53810.0  2007/12   4.0  2016/09/19     UQ      0.0
# 7877  (주)아이팩토리  53810.0  2008/12   4.0  2016/09/19     UQ      0.0
# 7878  (주)아이팩토리  53810.0  2009/12   4.0  2016/09/19     UQ      0.0
# 7879  (주)아이팩토리  53810.0  2010/12   4.0  2016/09/19     UQ      0.0
# 7880  (주)아이팩토리  53810.0  2011/12   4.0  2016/09/19     UQ      0.0
# 7881  (주)아이팩토리  53810.0  2012/12   4.0  2016/09/19     UQ      0.0
# 7882  (주)아이팩토리  53810.0  2013/12   4.0  2016/09/19     UQ      0.0
# ...

# %%
dataset.at[[7881,7883], '부도'] = 1

# %% [markdown]
# ## **(주)아큐텍**

# %%
dataset.loc[dataset['회사명'] == dpt_list[28], dataset.columns[:-8]]
# Out:
#          회사명    거래소코드     회계년도  소속코드       상장폐지일 감사의견코드  자기자본배당률  금융비용 대 부채비율  \
# 7947  (주)아큐텍  13780.0  2000/12   4.0  2013/04/23     UQ      0.0     0.039915
# 7948  (주)아큐텍  13780.0  2001/12   4.0  2013/04/23     UQ      0.0     0.070618
# 7949  (주)아큐텍  13780.0  2002/12   4.0  2013/04/23     UQ      0.0     0.042428
# 7950  (주)아큐텍  13780.0  2003/12   4.0  2013/04/23     UQ      0.0     0.032725
# 7951  (주)아큐텍  13780.0  2004/12   4.0  2013/04/23     UQ      0.0     0.034314
# 7952  (주)아큐텍  13780.0  2005/12   4.0  2013/04/23     UQ      0.0     0.012705
# 7953  (주)아큐텍  13780.0  2006/12   4.0  2013/04/23     UQ      0.0     0.015759
# 7954  (주)아큐텍  13780.0  2007/12   4.0  2013/04/23     UQ      0.0     0.031510
# 7955  (주)아큐텍  13780.0  2008/12   4.0  2013/04/23     UQ      0.0     0.037587
# 7956  (주)아큐텍  13780.0  2009/12   4.0  2013/04/23     UQ      0.0     0.040547
# 7957  (주)아큐텍  13780.0  2010/12   4.0  2013/04/23     UQ      0.0     0.038364
# ...

# %% [markdown]
# ## **(주)애드모바일**
#
# - 에드모바일은 데이터가 5년 미만이기 때문에 드랍합니다.

# %%
dataset.at[7958,'부도'] = 1

# %%
dataset.loc[dataset['회사명'] == dpt_list[29], dataset.columns[:-8]]
# Out:
#            회사명    거래소코드     회계년도  소속코드       상장폐지일 감사의견코드  자기자본배당률  \
# 8163  (주)애드모바일  32600.0  2000/12   4.0  2003/10/30     DS      0.0
# 8164  (주)애드모바일  32600.0  2001/12   4.0  2003/10/30     UQ      0.0
# 8165  (주)애드모바일  32600.0  2002/12   4.0  2003/10/30     NS      0.0
#
#       금융비용 대 부채비율  자기자본배율  유동부채비율  매입채무회전률  유동자산회전률  총자본투자효율  순운전자본비율  \
# 8163     0.073016 -100.31     0.0     7.72     0.61  -881.34    -1.46
# 8164     0.001121 -425.36     0.0     0.72     0.04 -1678.17 -1120.24
# 8165     0.001121 -425.36     0.0     0.72     0.04 -1678.17 -1120.24
#
#         누적수익성비율  총자산영업이익률    총자산회전율       년        key   부도
# 8163  -9.734167 -1.365470  2.014522  2001.0  326002001  0.0
# 8164 -20.156868 -0.099313  0.020604  2002.0  326002002  0.0
# 8165 -20.156868 -0.099313  0.020604  2003.0  326002003  1.0

# %%
dataset.drop(index=[8163,8164,8165], inplace = True)
dataset.reset_index(inplace=True, drop=True)

# %% [markdown]
# ## **(주)에스마크**

# %%
dataset.loc[dataset['회사명'] == dpt_list[30], dataset.columns[:-8]]
# Out:
#           회사명    거래소코드     회계년도  소속코드       상장폐지일 감사의견코드  자기자본배당률  \
# 8394  (주)에스마크  30270.0  2000/12   4.0  2020/05/21     UQ     3.23
# 8395  (주)에스마크  30270.0  2001/12   4.0  2020/05/21     UQ     3.00
# 8396  (주)에스마크  30270.0  2002/12   4.0  2020/05/21     UQ     3.04
# 8397  (주)에스마크  30270.0  2003/12   4.0  2020/05/21     UQ     2.33
# 8398  (주)에스마크  30270.0  2004/12   4.0  2020/05/21     UQ     2.00
# 8399  (주)에스마크  30270.0  2005/12   4.0  2020/05/21     UQ     1.50
# 8400  (주)에스마크  30270.0  2006/12   4.0  2020/05/21     UQ     1.34
# 8401  (주)에스마크  30270.0  2007/12   4.0  2020/05/21     UQ     1.34
# 8402  (주)에스마크  30270.0  2008/12   4.0  2020/05/21     UQ     0.00
# 8403  (주)에스마크  30270.0  2009/12   4.0  2020/05/21     UQ     1.66
# 8404  (주)에스마크  30270.0  2010/12   4.0  2020/05/21     UQ     1.84
# 8405  (주)에스마크  30270.0  2011/12   4.0  2020/05/21     UQ     0.00
# 8406  (주)에스마크  30270.0  2012/12   4.0  2020/05/21     UQ     0.00
# ...

# %%
dataset.at[8412,'부도'] = 1

# %% [markdown]
# ## **(주)에스에스컴텍**

# %%
dataset.loc[dataset['회사명'] == dpt_list[31], dataset.columns[:-8]]
# Out:
#             회사명    거래소코드     회계년도  소속코드       상장폐지일 감사의견코드  자기자본배당률  \
# 8579  (주)에스에스컴텍  36500.0  2000/12   4.0  2017/05/11     UQ     3.58
# 8580  (주)에스에스컴텍  36500.0  2001/12   4.0  2017/05/11     UQ     1.69
# 8581  (주)에스에스컴텍  36500.0  2002/12   4.0  2017/05/11     UQ     0.00
# 8582  (주)에스에스컴텍  36500.0  2003/12   4.0  2017/05/11     UQ     0.00
# 8583  (주)에스에스컴텍  36500.0  2004/12   4.0  2017/05/11     UQ     1.74
# 8584  (주)에스에스컴텍  36500.0  2005/12   4.0  2017/05/11     UQ     2.21
# 8585  (주)에스에스컴텍  36500.0  2006/12   4.0  2017/05/11     UQ     0.00
# 8586  (주)에스에스컴텍  36500.0  2007/12   4.0  2017/05/11     UQ     0.00
# 8587  (주)에스에스컴텍  36500.0  2008/12   4.0  2017/05/11     UQ     0.00
# 8588  (주)에스에스컴텍  36500.0  2009/12   4.0  2017/05/11     UQ     0.00
# 8589  (주)에스에스컴텍  36500.0  2010/12   4.0  2017/05/11     UQ     0.00
# 8590  (주)에스에스컴텍  36500.0  2011/12   4.0  2017/05/11     UQ     0.00
# 8591  (주)에스에스컴텍  36500.0  2012/12   4.0  2017/05/11     UQ     0.00
# ...

# %%
dataset.at[8594,'부도'] = 1

# %% [markdown]
# ## **(주)에스에프씨**

# %%
dataset.loc[dataset['회사명'] == dpt_list[32], dataset.columns[:-8]]
# Out:
#            회사명     거래소코드     회계년도  소속코드       상장폐지일 감사의견코드  자기자본배당률  \
# 8637  (주)에스에프씨  112240.0  2002/12   4.0  2020/06/30     UQ     0.00
# 8638  (주)에스에프씨  112240.0  2003/12   4.0  2020/06/30     UQ     0.00
# 8639  (주)에스에프씨  112240.0  2004/12   4.0  2020/06/30     UQ     0.00
# 8640  (주)에스에프씨  112240.0  2005/12   4.0  2020/06/30     UQ     0.00
# 8641  (주)에스에프씨  112240.0  2006/12   4.0  2020/06/30     UQ     0.00
# 8642  (주)에스에프씨  112240.0  2007/12   4.0  2020/06/30     UQ     0.00
# 8643  (주)에스에프씨  112240.0  2008/12   4.0  2020/06/30     UQ     0.00
# 8644  (주)에스에프씨  112240.0  2009/12   4.0  2020/06/30     UQ     3.64
# 8645  (주)에스에프씨  112240.0  2010/12   4.0  2020/06/30     UQ     1.22
# 8646  (주)에스에프씨  112240.0  2011/12   4.0  2020/06/30     UQ     0.00
# 8647  (주)에스에프씨  112240.0  2012/12   4.0  2020/06/30     UQ     0.35
# 8648  (주)에스에프씨  112240.0  2013/12   4.0  2020/06/30     UQ     0.67
# 8649  (주)에스에프씨  112240.0  2014/12   4.0  2020/06/30     UQ     0.39
# ...

# %%
dataset.at[8651,'부도'] = 1

# %% [markdown]
# ## **(주)에피밸리**

# %%
dataset.loc[dataset['회사명'] == dpt_list[33], dataset.columns[:-8]]
# Out:
#           회사명    거래소코드     회계년도  소속코드       상장폐지일 감사의견코드  자기자본배당률  \
# 9651  (주)에피밸리  68630.0  2000/12   4.0  2012/04/24     UQ     0.00
# 9652  (주)에피밸리  68630.0  2001/12   4.0  2012/04/24     UQ     0.00
# 9653  (주)에피밸리  68630.0  2002/12   4.0  2012/04/24     UQ     0.00
# 9654  (주)에피밸리  68630.0  2003/12   4.0  2012/04/24     UQ     0.00
# 9655  (주)에피밸리  68630.0  2004/12   4.0  2012/04/24     UQ     0.00
# 9656  (주)에피밸리  68630.0  2005/12   4.0  2012/04/24     UQ     1.78
# 9657  (주)에피밸리  68630.0  2006/12   4.0  2012/04/24     UQ     2.93
# 9658  (주)에피밸리  68630.0  2007/12   4.0  2012/04/24     UQ     0.00
# 9659  (주)에피밸리  68630.0  2008/12   4.0  2012/04/24     UQ     0.00
# 9660  (주)에피밸리  68630.0  2009/12   4.0  2012/04/24     UQ     0.00
# 9661  (주)에피밸리  68630.0  2010/12   4.0  2012/04/24     UQ     0.00
# 9662  (주)에피밸리  68630.0  2011/12   4.0  2012/04/24     DU     0.00
#
#       금융비용 대 부채비율  자기자본배율  유동부채비율  매입채무회전률  유동자산회전률  총자본투자효율  순운전자본비율  \
# ...

# %%
dataset.at[9661,'부도'] = 1

# %% [markdown]
# ## **(주)엔에스브이**

# %%
dataset.loc[dataset['회사명'] == dpt_list[34], dataset.columns[:-8]]
# Out:
#            회사명    거래소코드     회계년도  소속코드       상장폐지일 감사의견코드  자기자본배당률  \
# 9778  (주)엔에스브이  95300.0  2002/12   4.0  2017/09/12     UQ      0.0
# 9779  (주)엔에스브이  95300.0  2003/12   4.0  2017/09/12     QS      0.0
# 9780  (주)엔에스브이  95300.0  2004/12   4.0  2017/09/12     UQ      0.0
# 9781  (주)엔에스브이  95300.0  2005/12   4.0  2017/09/12     UQ      0.0
# 9782  (주)엔에스브이  95300.0  2006/12   4.0  2017/09/12     UQ      0.0
# 9783  (주)엔에스브이  95300.0  2007/12   4.0  2017/09/12     UQ      0.0
# 9784  (주)엔에스브이  95300.0  2008/12   4.0  2017/09/12     UQ      0.0
# 9785  (주)엔에스브이  95300.0  2009/12   4.0  2017/09/12     UQ      0.0
# 9786  (주)엔에스브이  95300.0  2010/12   4.0  2017/09/12     UQ      0.0
# 9787  (주)엔에스브이  95300.0  2011/12   4.0  2017/09/12     UQ      0.0
# 9788  (주)엔에스브이  95300.0  2012/12   4.0  2017/09/12     UQ      0.0
# 9789  (주)엔에스브이  95300.0  2013/12   4.0  2017/09/12     UQ      0.0
# 9790  (주)엔에스브이  95300.0  2014/12   4.0  2017/09/12     UQ      0.0
# ...

# %%
dataset.at[9779,'부도'] = 1

# %% [markdown]
# ## **(주)엔케이바이오**

# %%
dataset.loc[dataset['회사명'] == dpt_list[35], dataset.columns[:-8]]
# Out:
#             회사명    거래소코드     회계년도  소속코드       상장폐지일 감사의견코드  자기자본배당률  \
# 9889  (주)엔케이바이오  19260.0  2000/12   4.0  2012/09/05     UQ      0.0
# 9890  (주)엔케이바이오  19260.0  2001/12   4.0  2012/09/05     UQ      0.0
# 9891  (주)엔케이바이오  19260.0  2002/12   4.0  2012/09/05     UQ      0.0
# 9892  (주)엔케이바이오  19260.0  2003/12   4.0  2012/09/05     UQ      0.0
# 9893  (주)엔케이바이오  19260.0  2004/12   4.0  2012/09/05     UQ      0.0
# 9894  (주)엔케이바이오  19260.0  2005/12   4.0  2012/09/05     UQ      0.0
# 9895  (주)엔케이바이오  19260.0  2006/12   4.0  2012/09/05     UQ      0.0
# 9896  (주)엔케이바이오  19260.0  2007/12   4.0  2012/09/05     UQ      0.0
# 9897  (주)엔케이바이오  19260.0  2008/12   4.0  2012/09/05     UQ      0.0
# 9898  (주)엔케이바이오  19260.0  2009/12   4.0  2012/09/05     UQ      0.0
# 9899  (주)엔케이바이오  19260.0  2010/12   4.0  2012/09/05     UQ      0.0
# 9900  (주)엔케이바이오  19260.0  2011/12   4.0  2012/09/05     QU      0.0
#
#       금융비용 대 부채비율  자기자본배율  유동부채비율  매입채무회전률  유동자산회전률  총자본투자효율  순운전자본비율  \
# ...

# %%
dataset.at[9889,'부도'] = 1

# %% [markdown]
# ## **(주)엘앤씨피**

# %%
dataset.loc[dataset['회사명'] == dpt_list[36], dataset.columns[:-8]]
# Out:
#            회사명    거래소코드     회계년도  소속코드       상장폐지일 감사의견코드  자기자본배당률  \
# 10034  (주)엘앤씨피  15390.0  2000/12   4.0  2012/04/13     UQ      0.0
# 10035  (주)엘앤씨피  15390.0  2001/12   4.0  2012/04/13     UQ      0.0
# 10036  (주)엘앤씨피  15390.0  2002/12   4.0  2012/04/13     UQ      0.0
# 10037  (주)엘앤씨피  15390.0  2003/12   4.0  2012/04/13     UQ      0.0
# 10038  (주)엘앤씨피  15390.0  2004/12   4.0  2012/04/13     UQ      0.0
# 10039  (주)엘앤씨피  15390.0  2005/12   4.0  2012/04/13     UQ      0.0
# 10040  (주)엘앤씨피  15390.0  2006/12   4.0  2012/04/13     UQ      0.0
# 10041  (주)엘앤씨피  15390.0  2007/12   4.0  2012/04/13     UQ      0.0
# 10042  (주)엘앤씨피  15390.0  2008/12   4.0  2012/04/13     QU      0.0
# 10043  (주)엘앤씨피  15390.0  2009/12   4.0  2012/04/13     UQ      0.0
# 10044  (주)엘앤씨피  15390.0  2010/12   4.0  2012/04/13     UQ      0.0
# 10045  (주)엘앤씨피  15390.0  2011/12   4.0  2012/04/13     DU      0.0
#
#        금융비용 대 부채비율   자기자본배율  유동부채비율  매입채무회전률  유동자산회전률  총자본투자효율  순운전자본비율  \
# ...

# %%
dataset.at[10044,'부도'] = 1

# %% [markdown]
# ## **(주)영진코퍼레이션**

# %%
dataset.loc[dataset['회사명'] == dpt_list[37], dataset.columns[:-8]]
# Out:
#               회사명    거래소코드     회계년도  소속코드       상장폐지일 감사의견코드  자기자본배당률  \
# 10407  (주)영진코퍼레이션  53330.0  2000/12   4.0  2015/04/23     UQ     1.13
# 10408  (주)영진코퍼레이션  53330.0  2001/12   4.0  2015/04/23     UQ     1.13
# 10409  (주)영진코퍼레이션  53330.0  2002/12   4.0  2015/04/23     UQ     0.00
# 10410  (주)영진코퍼레이션  53330.0  2003/12   4.0  2015/04/23     UQ     0.00
# 10411  (주)영진코퍼레이션  53330.0  2004/12   4.0  2015/04/23     UQ     0.00
# 10412  (주)영진코퍼레이션  53330.0  2005/12   4.0  2015/04/23     UQ     0.00
# 10413  (주)영진코퍼레이션  53330.0  2006/12   4.0  2015/04/23     UQ     0.00
# 10414  (주)영진코퍼레이션  53330.0  2007/12   4.0  2015/04/23     UQ     0.00
# 10415  (주)영진코퍼레이션  53330.0  2008/12   4.0  2015/04/23     UQ     0.00
# 10416  (주)영진코퍼레이션  53330.0  2009/12   4.0  2015/04/23     UQ     0.00
# 10417  (주)영진코퍼레이션  53330.0  2010/12   4.0  2015/04/23     UQ     0.00
# 10418  (주)영진코퍼레이션  53330.0  2011/12   4.0  2015/04/23     UQ     0.00
# ...

# %%
dataset.at[10420,'부도'] = 1

# %% [markdown]
# ## **(주)와이즈파워**

# %%
dataset.loc[dataset['회사명'] == dpt_list[38], dataset.columns[:-8]]
# Out:
#             회사명    거래소코드     회계년도  소속코드       상장폐지일 감사의견코드  자기자본배당률  \
# 10957  (주)와이즈파워  40670.0  2000/12   4.0  2015/07/16     UQ     1.84
# 10958  (주)와이즈파워  40670.0  2001/12   4.0  2015/07/16     UQ     1.13
# 10959  (주)와이즈파워  40670.0  2002/12   4.0  2015/07/16     UQ     0.00
# 10960  (주)와이즈파워  40670.0  2003/12   4.0  2015/07/16     UQ     0.00
# 10961  (주)와이즈파워  40670.0  2004/12   4.0  2015/07/16     UQ     0.00
# 10962  (주)와이즈파워  40670.0  2005/12   4.0  2015/07/16     UQ     0.00
# 10963  (주)와이즈파워  40670.0  2006/12   4.0  2015/07/16     UQ     0.00
# 10964  (주)와이즈파워  40670.0  2007/12   4.0  2015/07/16     UQ     0.00
# 10965  (주)와이즈파워  40670.0  2008/12   4.0  2015/07/16     UQ     0.00
# 10966  (주)와이즈파워  40670.0  2009/12   4.0  2015/07/16     UQ     0.00
# 10967  (주)와이즈파워  40670.0  2010/12   4.0  2015/07/16     UQ     0.00
# 10968  (주)와이즈파워  40670.0  2011/12   4.0  2015/07/16     UQ     0.00
# 10969  (주)와이즈파워  40670.0  2012/12   4.0  2015/07/16     UQ     0.00
# ...

# %%
dataset.at[[10969,10970],'부도'] = 1

# %% [markdown]
# ## **(주)우전**

# %%
dataset.loc[dataset['회사명'] == dpt_list[40], dataset.columns[:-8]]
# Out:
#          회사명    거래소코드     회계년도  소속코드       상장폐지일 감사의견코드  자기자본배당률  금융비용 대 부채비율  \
# 11121  (주)우전  52270.0  2000/12   4.0  2017/04/13     UQ     3.73     0.070181
# 11122  (주)우전  52270.0  2001/12   4.0  2017/04/13     UQ     3.73     0.036522
# 11123  (주)우전  52270.0  2002/12   4.0  2017/04/13     UQ     3.47     0.019996
# 11124  (주)우전  52270.0  2003/12   4.0  2017/04/13     UQ     0.00     0.016949
# 11125  (주)우전  52270.0  2004/12   4.0  2017/04/13     UQ     0.00     0.041667
# 11126  (주)우전  52270.0  2005/12   4.0  2017/04/13     UQ     0.00     0.018309
# 11127  (주)우전  52270.0  2006/12   4.0  2017/04/13     UQ     1.55     0.019042
# 11128  (주)우전  52270.0  2007/12   4.0  2017/04/13     UQ     3.57     0.032535
# 11129  (주)우전  52270.0  2008/12   4.0  2017/04/13     UQ     9.76     0.009713
# 11130  (주)우전  52270.0  2009/12   4.0  2017/04/13     UQ     3.48     0.013936
# 11131  (주)우전  52270.0  2010/12   4.0  2017/04/13     UQ     2.35     0.005461
# ...

# %%
dataset.at[11136,'부도'] = 1

# %% [markdown]
# ## **(주)유니드코리아**

# %%
dataset.loc[dataset['회사명'] == dpt_list[41], dataset.columns[:-8]]
# Out:
#              회사명     거래소코드     회계년도  소속코드       상장폐지일 감사의견코드  자기자본배당률  \
# 11720  (주)유니드코리아  110500.0  2007/12   4.0  2014/09/02      0     0.00
# 11721  (주)유니드코리아  110500.0  2008/12   4.0  2014/09/02     UQ     0.00
# 11722  (주)유니드코리아  110500.0  2009/12   4.0  2014/09/02     UQ     0.00
# 11723  (주)유니드코리아  110500.0  2010/12   4.0  2014/09/02     UQ     0.00
# 11724  (주)유니드코리아  110500.0  2011/12   4.0  2014/09/02     DS     1.18
# 11725  (주)유니드코리아  110500.0  2012/12   4.0  2014/09/02     UQ     0.00
# 11726  (주)유니드코리아  110500.0  2013/12   4.0  2014/09/02     DU     0.00
#
#        금융비용 대 부채비율  자기자본배율  유동부채비율  매입채무회전률  유동자산회전률  총자본투자효율  순운전자본비율  \
# 11720     0.019930  133.21  250.64     5.04     1.92    13.52   -16.93
# 11721     0.043073  133.21  250.64     5.04     1.92    13.52   -16.93
# 11722     0.035916  249.37  115.08     8.49     2.78    23.69     9.52
# 11723     0.028289  348.00  118.71     6.56     1.98    19.60    17.38
# ...

# %%
dataset.at[11724,'부도'] = 1

# %% [markdown]
# ## **(주)유아이에너지**

# %%
dataset.loc[dataset['회사명'] == dpt_list[42], dataset.columns[:-8]]
# Out:
#              회사명    거래소코드     회계년도  소속코드       상장폐지일 감사의견코드  자기자본배당률  \
# 11996  (주)유아이에너지  50050.0  2000/12   4.0  2012/09/26     UQ      0.0
# 11997  (주)유아이에너지  50050.0  2001/12   4.0  2012/09/26     UQ      0.0
# 11998  (주)유아이에너지  50050.0  2002/12   4.0  2012/09/26     UQ      0.0
# 11999  (주)유아이에너지  50050.0  2003/12   4.0  2012/09/26     QG      0.0
# 12000  (주)유아이에너지  50050.0  2004/12   4.0  2012/09/26     UQ      0.0
# 12001  (주)유아이에너지  50050.0  2005/12   4.0  2012/09/26     UQ      0.0
# 12002  (주)유아이에너지  50050.0  2006/12   4.0  2012/09/26     UQ      0.0
# 12003  (주)유아이에너지  50050.0  2007/12   4.0  2012/09/26     UQ      0.0
# 12004  (주)유아이에너지  50050.0  2008/12   4.0  2012/09/26     UQ      0.0
# 12005  (주)유아이에너지  50050.0  2009/12   4.0  2012/09/26     UQ      0.0
# 12006  (주)유아이에너지  50050.0  2010/12   4.0  2012/09/26     UQ      0.0
# 12007  (주)유아이에너지  50050.0  2011/12   4.0  2012/09/26     UQ      0.0
#
# ...

# %%
dataset.at[12001,'부도'] = 1

# %% [markdown]
# ## **(주)이노블루**

# %%
dataset.loc[dataset['회사명'] == dpt_list[43], dataset.columns[:-8]]
# Out:
#            회사명    거래소코드     회계년도  소속코드       상장폐지일 감사의견코드  자기자본배당률  \
# 12214  (주)이노블루  66200.0  2000/12   4.0  2009/04/11     UQ     0.84
# 12215  (주)이노블루  66200.0  2001/12   4.0  2009/04/11     UQ     0.84
# 12216  (주)이노블루  66200.0  2002/12   4.0  2009/04/11     UQ     0.42
# 12217  (주)이노블루  66200.0  2003/12   4.0  2009/04/11     UQ     1.72
# 12218  (주)이노블루  66200.0  2004/12   4.0  2009/04/11     UQ     0.00
# 12219  (주)이노블루  66200.0  2005/12   4.0  2009/04/11     QG     0.00
# 12220  (주)이노블루  66200.0  2006/12   4.0  2009/04/11     UQ     0.00
# 12221  (주)이노블루  66200.0  2007/12   4.0  2009/04/11     UQ     0.00
# 12222  (주)이노블루  66200.0  2008/12   4.0  2009/04/11     QG     0.00
#
#        금융비용 대 부채비율  자기자본배율  유동부채비율  매입채무회전률  유동자산회전률  총자본투자효율  순운전자본비율  \
# 12214     0.000960  542.45   53.41     6.30     1.31    35.19    55.94
# 12215     0.001738  542.45   53.41     6.30     1.31    35.19    55.94
# 12216     0.000758  871.34   31.04    13.81     2.12    55.79    68.28
# ...

# %%
dataset.at[12220,'부도'] = 1

# %% [markdown]
# ## 	**(주)이엠네트웍스**

# %%
dataset.loc[dataset['회사명'] == dpt_list[44], dataset.columns[:-8]]
# Out:
#              회사명    거래소코드     회계년도  소속코드       상장폐지일 감사의견코드  자기자본배당률  \
# 12559  (주)이엠네트웍스  87730.0  2004/12   4.0  2021/10/08     UQ     1.70
# 12560  (주)이엠네트웍스  87730.0  2005/12   4.0  2021/10/08     UQ     1.70
# 12561  (주)이엠네트웍스  87730.0  2006/12   4.0  2021/10/08     UQ     1.22
# 12562  (주)이엠네트웍스  87730.0  2007/12   4.0  2021/10/08     UQ     0.00
# 12563  (주)이엠네트웍스  87730.0  2008/12   4.0  2021/10/08     UQ     0.00
# 12564  (주)이엠네트웍스  87730.0  2009/12   4.0  2021/10/08     UQ     0.00
# 12565  (주)이엠네트웍스  87730.0  2010/12   4.0  2021/10/08     UQ     0.00
# 12566  (주)이엠네트웍스  87730.0  2011/12   4.0  2021/10/08     UQ     0.00
# 12567  (주)이엠네트웍스  87730.0  2012/12   4.0  2021/10/08     UQ     0.00
# 12568  (주)이엠네트웍스  87730.0  2013/12   4.0  2021/10/08     UQ     2.78
# 12569  (주)이엠네트웍스  87730.0  2014/12   4.0  2021/10/08     UQ     3.18
# 12570  (주)이엠네트웍스  87730.0  2015/12   4.0  2021/10/08     UQ     1.90
# 12571  (주)이엠네트웍스  87730.0  2016/12   4.0  2021/10/08     UQ     0.00
# ...

# %%
dataset.at[12574,'부도'] = 1

# %% [markdown]
# ## **(주)제낙스**

# %%
dataset.loc[dataset['회사명'] == dpt_list[45], dataset.columns[:-8]]
# Out:
#           회사명    거래소코드     회계년도  소속코드       상장폐지일 감사의견코드  자기자본배당률  \
# 13353  (주)제낙스  65620.0  2001/12   4.0  2021/08/09     UQ      0.0
# 13354  (주)제낙스  65620.0  2002/12   4.0  2021/08/09     UQ      0.0
# 13355  (주)제낙스  65620.0  2003/12   4.0  2021/08/09     UQ      0.0
# 13356  (주)제낙스  65620.0  2004/12   4.0  2021/08/09     UQ      0.0
# 13357  (주)제낙스  65620.0  2005/12   4.0  2021/08/09     UQ      0.0
# 13358  (주)제낙스  65620.0  2006/12   4.0  2021/08/09     UQ      0.0
# 13359  (주)제낙스  65620.0  2007/12   4.0  2021/08/09     UQ      0.0
# 13360  (주)제낙스  65620.0  2008/12   4.0  2021/08/09     UQ      0.0
# 13361  (주)제낙스  65620.0  2009/12   4.0  2021/08/09     UQ      0.0
# 13362  (주)제낙스  65620.0  2010/12   4.0  2021/08/09     UQ      0.0
# 13363  (주)제낙스  65620.0  2011/12   4.0  2021/08/09     UQ      0.0
# 13364  (주)제낙스  65620.0  2012/12   4.0  2021/08/09     UQ      0.0
# 13365  (주)제낙스  65620.0  2013/12   4.0  2021/08/09     UQ      0.0
# ...

# %%
dataset.at[13371,'부도'] = 1

# %% [markdown]
# ## **(주)제너시스템즈**

# %%
dataset.loc[dataset['회사명'] == dpt_list[46], dataset.columns[:-8]]
# Out:
#              회사명    거래소코드     회계년도  소속코드       상장폐지일 감사의견코드  자기자본배당률  \
# 13382  (주)제너시스템즈  73930.0  2002/12   4.0  2013/07/12     UQ      0.0
# 13383  (주)제너시스템즈  73930.0  2003/12   4.0  2013/07/12     UQ      0.0
# 13384  (주)제너시스템즈  73930.0  2005/03   4.0  2013/07/12     UQ      0.0
# 13385  (주)제너시스템즈  73930.0  2006/03   4.0  2013/07/12     UQ      0.0
# 13386  (주)제너시스템즈  73930.0  2007/03   4.0  2013/07/12     UQ      0.0
# 13387  (주)제너시스템즈  73930.0  2008/03   4.0  2013/07/12     UQ      0.0
# 13388  (주)제너시스템즈  73930.0  2009/03   4.0  2013/07/12     UQ      0.0
# 13389  (주)제너시스템즈  73930.0  2010/03   4.0  2013/07/12     UQ      0.0
# 13390  (주)제너시스템즈  73930.0  2011/03   4.0  2013/07/12     UQ      0.0
# 13391  (주)제너시스템즈  73930.0  2012/03   4.0  2013/07/12     UQ      0.0
# 13392  (주)제너시스템즈  73930.0  2013/03   4.0  2013/07/12     DU      0.0
#
#        금융비용 대 부채비율  자기자본배율  유동부채비율  매입채무회전률  유동자산회전률  총자본투자효율  순운전자본비율  \
# ...

# %%
dataset.at[13391,'부도'] = 1

# %% [markdown]
# ## **(주)주노콜렉션**

# %%
dataset.loc[dataset['회사명'] == dpt_list[47], dataset.columns[:-8]]
# Out:
#             회사명     거래소코드     회계년도  소속코드       상장폐지일 감사의견코드  자기자본배당률  \
# 13922  (주)주노콜렉션  221670.0  2014/12   4.0  2019/07/16      0      0.0
# 13923  (주)주노콜렉션  221670.0  2015/12   4.0  2019/07/16     QS      0.0
# 13924  (주)주노콜렉션  221670.0  2016/12   4.0  2019/07/16     UQ      0.0
# 13925  (주)주노콜렉션  221670.0  2017/12   4.0  2019/07/16     UQ      0.0
# 13926  (주)주노콜렉션  221670.0  2018/12   4.0  2019/07/16     DS      0.0
#
#        금융비용 대 부채비율   자기자본배율  유동부채비율  매입채무회전률  유동자산회전률  총자본투자효율  순운전자본비율  \
# 13922     0.024511  1094.12  115.93    38.32     1.82    16.71    45.80
# 13923     0.032307  1094.12  115.93    38.32     1.82    16.71    45.80
# 13924     0.036793   772.70  127.29    37.09     2.21    18.05    24.15
# 13925     0.035259   434.19  144.54    28.57     1.97    22.22    28.79
# 13926     0.040137   475.64  204.62    29.82     1.52    10.03    23.18
#
#         누적수익성비율  총자산영업이익률    총자산회전율       년         key   부도
# ...

# %%
dataset.at[13924,'부도'] = 1

# %% [markdown]
# ## **(주)중앙디자인**

# %%
dataset.loc[dataset['회사명'] == dpt_list[48], dataset.columns[:-8]]
# Out:
#             회사명    거래소코드     회계년도  소속코드       상장폐지일 감사의견코드  자기자본배당률  \
# 13948  (주)중앙디자인  30030.0  2000/12   4.0  2011/04/13     UQ     0.00
# 13949  (주)중앙디자인  30030.0  2001/12   4.0  2011/04/13     UQ     0.00
# 13950  (주)중앙디자인  30030.0  2002/12   4.0  2011/04/13     UQ     2.91
# 13951  (주)중앙디자인  30030.0  2003/12   4.0  2011/04/13     UQ     2.55
# 13952  (주)중앙디자인  30030.0  2004/12   4.0  2011/04/13     UQ     2.52
# 13953  (주)중앙디자인  30030.0  2005/12   4.0  2011/04/13     UQ     2.71
# 13954  (주)중앙디자인  30030.0  2006/12   4.0  2011/04/13     UQ     1.08
# 13955  (주)중앙디자인  30030.0  2007/12   4.0  2011/04/13     UQ     1.72
# 13956  (주)중앙디자인  30030.0  2008/12   4.0  2011/04/13     UQ     0.00
# 13957  (주)중앙디자인  30030.0  2009/12   4.0  2011/04/13     UQ     0.00
# 13958  (주)중앙디자인  30030.0  2010/12   4.0  2011/04/13     DU     0.00
#
#        금융비용 대 부채비율  자기자본배율  유동부채비율  매입채무회전률  유동자산회전률  총자본투자효율  순운전자본비율  \
# 13948     0.006194  307.42  104.73     6.31     3.15    37.62    37.51
# ...

# %%
dataset.at[13957,'부도'] = 1

# %% [markdown]
# ## **(주)케이알**

# %%
dataset.loc[dataset['회사명'] == dpt_list[49], dataset.columns[:-8]]
# Out:
#           회사명    거래소코드     회계년도  소속코드       상장폐지일 감사의견코드  자기자본배당률  \
# 14881  (주)케이알  35950.0  2000/12   4.0  2009/08/21     UQ     1.60
# 14882  (주)케이알  35950.0  2001/12   4.0  2009/08/21     UQ     2.25
# 14883  (주)케이알  35950.0  2002/12   4.0  2009/08/21     UQ     0.48
# 14884  (주)케이알  35950.0  2003/12   4.0  2009/08/21     UQ     3.42
# 14885  (주)케이알  35950.0  2004/12   4.0  2009/08/21     UQ     1.00
# 14886  (주)케이알  35950.0  2006/03   4.0  2009/08/21     UQ     0.00
# 14887  (주)케이알  35950.0  2007/03   4.0  2009/08/21     UQ     0.00
# 14888  (주)케이알  35950.0  2008/03   4.0  2009/08/21     UQ     0.00
# 14889  (주)케이알  35950.0  2009/03   4.0  2009/08/21     DU     0.00
#
#        금융비용 대 부채비율  자기자본배율  유동부채비율  ...  유동자산회전률  총자본투자효율  순운전자본비율   누적수익성비율  \
# 14881     0.005681  374.70   63.75  ...     1.43    18.31    39.71  0.123209
# 14882     0.002716  407.42   64.22  ...     1.45    21.01    35.09  0.177935
# ...

# %%
dataset.at[14888,'부도'] = 1

# %% [markdown]
# ## **(주)택산아이엔씨**

# %%
dataset.loc[dataset['회사명'] == dpt_list[50], dataset.columns[:-8]]
# Out:
#              회사명    거래소코드     회계년도  소속코드       상장폐지일 감사의견코드  자기자본배당률  \
# 16238  (주)택산아이엔씨  36900.0  2000/12   4.0  2005/04/23     UQ     0.00
# 16239  (주)택산아이엔씨  36900.0  2001/12   4.0  2005/04/23     UQ     3.81
# 16240  (주)택산아이엔씨  36900.0  2002/12   4.0  2005/04/23     UQ     0.00
# 16241  (주)택산아이엔씨  36900.0  2003/12   4.0  2005/04/23     UQ     0.00
# 16242  (주)택산아이엔씨  36900.0  2004/12   4.0  2005/04/23     DU     0.00
#
#        금융비용 대 부채비율  자기자본배율  유동부채비율  ...  유동자산회전률  총자본투자효율  순운전자본비율   누적수익성비율  \
# 16238     0.046360  271.10  101.96  ...     1.54    20.24    40.19  0.073334
# 16239     0.066477  294.62   87.96  ...     1.97    24.33    43.55  0.099705
# 16240     0.054500  319.70  100.63  ...     1.54    14.31    31.35  0.058699
# 16241     0.046139  340.22  107.40  ...     1.44    18.12    24.54  0.063669
# 16242     0.059658    0.00    0.00  ...     0.92  -314.14  -217.51 -3.399219
#
#        총자산영업이익률    총자산회전율       년        key   부도             공시발생일
# ...

# %%
dataset.at[16241,'부도'] = 1

# %% [markdown]
# ## **(주)트레이스**

# %%
dataset.loc[dataset['회사명'] == dpt_list[51], dataset.columns[:-8]]
# Out:
#            회사명    거래소코드     회계년도  소속코드       상장폐지일 감사의견코드  자기자본배당률  \
# 16503  (주)트레이스  52290.0  2000/12   4.0  2018/10/11     UQ      0.0
# 16504  (주)트레이스  52290.0  2001/12   4.0  2018/10/11     UQ      0.0
# 16505  (주)트레이스  52290.0  2002/12   4.0  2018/10/11     UQ      0.0
# 16506  (주)트레이스  52290.0  2003/12   4.0  2018/10/11     UQ      0.0
# 16507  (주)트레이스  52290.0  2004/12   4.0  2018/10/11     UQ      0.0
# 16508  (주)트레이스  52290.0  2005/12   4.0  2018/10/11     UQ      0.0
# 16509  (주)트레이스  52290.0  2006/12   4.0  2018/10/11     UQ      0.0
# 16510  (주)트레이스  52290.0  2007/12   4.0  2018/10/11     UQ      0.0
# 16511  (주)트레이스  52290.0  2008/12   4.0  2018/10/11     UQ      0.0
# 16512  (주)트레이스  52290.0  2009/12   4.0  2018/10/11     UQ      0.0
# 16513  (주)트레이스  52290.0  2010/12   4.0  2018/10/11     UQ      0.0
# 16514  (주)트레이스  52290.0  2011/12   4.0  2018/10/11     UQ      0.0
# 16515  (주)트레이스  52290.0  2012/12   4.0  2018/10/11     UQ      0.0
# ...

# %%
dataset.at[[16517,16518],'부도'] = 1

# %% [markdown]
# ## **(주)플러스프로핏**

# %%
dataset.loc[dataset['회사명'] == dpt_list[53], dataset.columns[:-8]]
# Out:
#              회사명    거래소코드     회계년도  소속코드       상장폐지일 감사의견코드  자기자본배당률  \
# 17770  (주)플러스프로핏  36660.0  2000/12   4.0  2009/11/20     UQ      0.0
# 17771  (주)플러스프로핏  36660.0  2001/12   4.0  2009/11/20     UQ      0.0
# 17772  (주)플러스프로핏  36660.0  2002/12   4.0  2009/11/20     UQ      0.0
# 17773  (주)플러스프로핏  36660.0  2003/12   4.0  2009/11/20     UQ      0.0
# 17774  (주)플러스프로핏  36660.0  2004/12   4.0  2009/11/20     UQ      0.0
# 17775  (주)플러스프로핏  36660.0  2005/12   4.0  2009/11/20     UQ      0.0
# 17776  (주)플러스프로핏  36660.0  2007/06   4.0  2009/11/20     UQ      0.0
# 17777  (주)플러스프로핏  36660.0  2008/06   4.0  2009/11/20     UQ      0.0
# 17778  (주)플러스프로핏  36660.0  2009/06   4.0  2009/11/20     DS      0.0
#
#        금융비용 대 부채비율  자기자본배율  유동부채비율  ...  유동자산회전률  총자본투자효율  순운전자본비율    누적수익성비율  \
# 17770     0.049311  909.57   18.90  ...     0.92    22.68    58.37   0.069745
# 17771     0.090635  108.48  164.58  ...     0.99   -41.75     8.81   0.000000
# ...

# %%
dataset.at[17777,'부도'] = 1

# %% [markdown]
# ## **(주)피앤텔**

# %%
dataset.loc[dataset['회사명'] == dpt_list[54], dataset.columns[:-8]]
# Out:
#           회사명    거래소코드     회계년도  소속코드       상장폐지일 감사의견코드  자기자본배당률  \
# 17883  (주)피앤텔  54340.0  2000/12   4.0  2020/05/21     UQ     3.65
# 17884  (주)피앤텔  54340.0  2001/12   4.0  2020/05/21     UQ     2.33
# 17885  (주)피앤텔  54340.0  2002/12   4.0  2020/05/21     UQ     4.83
# 17886  (주)피앤텔  54340.0  2003/12   4.0  2020/05/21     UQ     3.87
# 17887  (주)피앤텔  54340.0  2004/12   4.0  2020/05/21     UQ     8.69
# 17888  (주)피앤텔  54340.0  2005/12   4.0  2020/05/21     UQ     7.56
# 17889  (주)피앤텔  54340.0  2006/12   4.0  2020/05/21     UQ     4.60
# 17890  (주)피앤텔  54340.0  2007/12   4.0  2020/05/21     UQ     3.24
# 17891  (주)피앤텔  54340.0  2008/12   4.0  2020/05/21     UQ     2.68
# 17892  (주)피앤텔  54340.0  2009/12   4.0  2020/05/21     UQ     1.10
# 17893  (주)피앤텔  54340.0  2010/12   4.0  2020/05/21     UQ     0.00
# 17894  (주)피앤텔  54340.0  2011/12   4.0  2020/05/21     UQ     0.00
# 17895  (주)피앤텔  54340.0  2012/12   4.0  2020/05/21     UQ     0.00
# ...

# %%
dataset.at[[17896,17901],'부도'] = 1

# %% [markdown]
# ## **(주)한신코퍼레이션**

# %%
dataset.loc[dataset['회사명'] == dpt_list[56], dataset.columns[:-8]]
# Out:
#               회사명    거래소코드     회계년도  소속코드       상장폐지일 감사의견코드  자기자본배당률  \
# 18546  (주)한신코퍼레이션  37120.0  2000/06   4.0  2004/10/21     UQ      0.0
# 18547  (주)한신코퍼레이션  37120.0  2001/06   4.0  2004/10/21     UQ      0.0
# 18548  (주)한신코퍼레이션  37120.0  2002/06   4.0  2004/10/21     UQ      0.0
# 18549  (주)한신코퍼레이션  37120.0  2003/06   4.0  2004/10/21     UQ      0.0
# 18550  (주)한신코퍼레이션  37120.0  2004/06   4.0  2004/10/21     DU      0.0
#
#        금융비용 대 부채비율  자기자본배율  유동부채비율  ...  유동자산회전률  총자본투자효율  순운전자본비율   누적수익성비율  \
# 18546     0.013168  507.64   24.87  ...     0.42     8.72    68.54  0.080887
# 18547     0.061722  533.31   56.65  ...     0.62     9.60    52.70  0.098925
# 18548     0.049170  469.26  102.63  ...     0.39    -4.10    36.28  0.006203
# 18549     0.055898  103.55  165.27  ...     0.64   -16.96   -22.33 -0.229111
# 18550     0.050765    0.00    0.00  ...     0.39  -336.50   -49.29 -5.299946
#
#        총자산영업이익률    총자산회전율       년        key   부도             공시발생일
# ...

# %%
dataset.at[18549,'부도'] = 1

# %% [markdown]
# ## **(주)화진**

# %%
dataset.loc[dataset['회사명'] == dpt_list[57], dataset.columns[:-8]]
# Out:
#          회사명     거래소코드     회계년도  소속코드       상장폐지일 감사의견코드  자기자본배당률  \
# 19008  (주)화진  134780.0  2000/12   4.0  2020/07/02     UQ    12.12
# 19009  (주)화진  134780.0  2001/12   4.0  2020/07/02     UQ    13.33
# 19010  (주)화진  134780.0  2002/12   4.0  2020/07/02     UQ    10.25
# 19011  (주)화진  134780.0  2003/12   4.0  2020/07/02     QS     4.21
# 19012  (주)화진  134780.0  2004/12   4.0  2020/07/02     QS     2.13
# 19013  (주)화진  134780.0  2005/12   4.0  2020/07/02     UQ     0.20
# 19014  (주)화진  134780.0  2006/12   4.0  2020/07/02     UQ     0.00
# 19015  (주)화진  134780.0  2007/12   4.0  2020/07/02     UQ     0.00
# 19016  (주)화진  134780.0  2008/12   4.0  2020/07/02     UQ     0.00
# 19017  (주)화진  134780.0  2009/12   4.0  2020/07/02     UQ     2.26
# 19018  (주)화진  134780.0  2010/12   4.0  2020/07/02     UQ     3.22
# 19019  (주)화진  134780.0  2011/12   4.0  2020/07/02     UQ     3.12
# 19020  (주)화진  134780.0  2012/12   4.0  2020/07/02     UQ     2.67
# ...

# %%
dataset.at[[19011,19012,19026],'부도'] = 1

# %% [markdown]
# **

# %% [markdown]
# ## 디브이에스코리아(주)

# %%
dataset.loc[dataset['회사명'] == dpt_list[60], dataset.columns[:-8]]
# Out:
#                회사명    거래소코드     회계년도  소속코드       상장폐지일 감사의견코드  자기자본배당률  \
# 20698  디브이에스코리아(주)  46400.0  2000/03   4.0  2014/09/02     UQ    10.56
# 20699  디브이에스코리아(주)  46400.0  2001/03   4.0  2014/09/02     UQ    10.56
# 20700  디브이에스코리아(주)  46400.0  2002/12   4.0  2014/09/02     UQ     3.81
# 20701  디브이에스코리아(주)  46400.0  2003/12   4.0  2014/09/02     UQ     0.00
# 20702  디브이에스코리아(주)  46400.0  2004/12   4.0  2014/09/02     UQ     0.00
# 20703  디브이에스코리아(주)  46400.0  2005/12   4.0  2014/09/02     UQ     0.00
# 20704  디브이에스코리아(주)  46400.0  2006/12   4.0  2014/09/02     UQ     0.00
# 20705  디브이에스코리아(주)  46400.0  2007/12   4.0  2014/09/02     UQ     0.00
# 20706  디브이에스코리아(주)  46400.0  2008/12   4.0  2014/09/02     UQ     0.00
# 20707  디브이에스코리아(주)  46400.0  2009/12   4.0  2014/09/02     UQ     0.00
# 20708  디브이에스코리아(주)  46400.0  2010/12   4.0  2014/09/02     UQ     0.00
# 20709  디브이에스코리아(주)  46400.0  2011/12   4.0  2014/09/02     UQ     0.00
# ...

# %%
dataset.at[20710,'부도'] = 1

# %% [markdown]
# ## **디에스티(주)**

# %%
dataset.loc[dataset['회사명'] == dpt_list[61], dataset.columns[:-8]]
# Out:
#            회사명    거래소코드     회계년도  소속코드       상장폐지일 감사의견코드  자기자본배당률  \
# 20727  디에스티(주)  33430.0  2000/12   4.0  2021/09/02     UQ      0.0
# 20728  디에스티(주)  33430.0  2001/12   4.0  2021/09/02     UQ      0.0
# 20729  디에스티(주)  33430.0  2002/12   4.0  2021/09/02     UQ      0.0
# 20730  디에스티(주)  33430.0  2003/12   4.0  2021/09/02     UQ      0.0
# 20731  디에스티(주)  33430.0  2004/12   4.0  2021/09/02     UQ      0.0
# 20732  디에스티(주)  33430.0  2005/12   4.0  2021/09/02     UQ      0.0
# 20733  디에스티(주)  33430.0  2006/12   4.0  2021/09/02     UQ      0.0
# 20734  디에스티(주)  33430.0  2007/12   4.0  2021/09/02     UQ      0.0
# 20735  디에스티(주)  33430.0  2008/12   4.0  2021/09/02     UQ      0.0
# 20736  디에스티(주)  33430.0  2009/12   4.0  2021/09/02     UQ      0.0
# 20737  디에스티(주)  33430.0  2010/12   4.0  2021/09/02     UQ      0.0
# 20738  디에스티(주)  33430.0  2011/12   4.0  2021/09/02     UQ      0.0
# 20739  디에스티(주)  33430.0  2012/12   4.0  2021/09/02     UQ      0.0
# ...

# %%
dataset.at[[20739,20743,20746],'부도'] = 1

# %% [markdown]
# ## **레이젠(주)**

# %%
dataset.loc[dataset['회사명'] == dpt_list[64], dataset.columns[:-8]]
# Out:
#           회사명    거래소코드     회계년도  소속코드       상장폐지일 감사의견코드  자기자본배당률  \
# 20859  레이젠(주)  47440.0  2000/12   4.0  2018/10/11     UQ     2.21
# 20860  레이젠(주)  47440.0  2001/12   4.0  2018/10/11     UQ     2.21
# 20861  레이젠(주)  47440.0  2002/12   4.0  2018/10/11     UQ     1.42
# 20862  레이젠(주)  47440.0  2003/12   4.0  2018/10/11     UQ     0.00
# 20863  레이젠(주)  47440.0  2004/12   4.0  2018/10/11     UQ     0.00
# 20864  레이젠(주)  47440.0  2005/12   4.0  2018/10/11     UQ     0.00
# 20865  레이젠(주)  47440.0  2006/12   4.0  2018/10/11     UQ     0.00
# 20866  레이젠(주)  47440.0  2007/12   4.0  2018/10/11     UQ     0.00
# 20867  레이젠(주)  47440.0  2008/12   4.0  2018/10/11     UQ     0.00
# 20868  레이젠(주)  47440.0  2009/12   4.0  2018/10/11     UQ     0.00
# 20869  레이젠(주)  47440.0  2010/12   4.0  2018/10/11     UQ     0.97
# 20870  레이젠(주)  47440.0  2011/12   4.0  2018/10/11     UQ     0.00
# 20871  레이젠(주)  47440.0  2012/12   4.0  2018/10/11     UQ     0.00
# ...

# %%
dataset.at[20875,'부도'] = 1

# %% [markdown]
# ## **미리넷(주)**

# %%
dataset.loc[dataset['회사명'] == dpt_list[65], dataset.columns[:-8]]
# Out:
#           회사명    거래소코드     회계년도  소속코드       상장폐지일 감사의견코드  자기자본배당률  \
# 21109  미리넷(주)  56710.0  2000/12   4.0  2012/04/13     UQ      0.0
# 21110  미리넷(주)  56710.0  2001/12   4.0  2012/04/13     UQ      0.0
# 21111  미리넷(주)  56710.0  2002/12   4.0  2012/04/13     UQ      0.0
# 21112  미리넷(주)  56710.0  2003/12   4.0  2012/04/13     UQ      0.0
# 21113  미리넷(주)  56710.0  2004/12   4.0  2012/04/13     UQ      0.0
# 21114  미리넷(주)  56710.0  2005/12   4.0  2012/04/13     UQ      0.0
# 21115  미리넷(주)  56710.0  2006/12   4.0  2012/04/13     UQ      0.0
# 21116  미리넷(주)  56710.0  2007/12   4.0  2012/04/13     UQ      0.0
# 21117  미리넷(주)  56710.0  2008/12   4.0  2012/04/13     UQ      0.0
# 21118  미리넷(주)  56710.0  2009/12   4.0  2012/04/13     UQ      0.0
# 21119  미리넷(주)  56710.0  2010/12   4.0  2012/04/13     UQ      0.0
# 21120  미리넷(주)  56710.0  2011/12   4.0  2012/04/13     DU      0.0
#
#        금융비용 대 부채비율  자기자본배율  유동부채비율  ...  유동자산회전률  총자본투자효율  순운전자본비율   누적수익성비율  \
# ...

# %%
dataset.at[[21118,21119],'부도'] = 1

# %% [markdown]
# ## **에이스하이텍(주)**

# %%
dataset.loc[dataset['회사명'] == dpt_list[67], dataset.columns[:-8]]
# Out:
#              회사명    거래소코드     회계년도  소속코드       상장폐지일 감사의견코드  자기자본배당률  \
# 23146  에이스하이텍(주)  71930.0  2000/12   4.0  2015/07/10     UQ     0.00
# 23147  에이스하이텍(주)  71930.0  2001/12   4.0  2015/07/10     UQ     0.00
# 23148  에이스하이텍(주)  71930.0  2002/12   4.0  2015/07/10     UQ     3.82
# 23149  에이스하이텍(주)  71930.0  2003/12   4.0  2015/07/10     UQ     3.31
# 23150  에이스하이텍(주)  71930.0  2004/12   4.0  2015/07/10     UQ     0.80
# 23151  에이스하이텍(주)  71930.0  2005/12   4.0  2015/07/10     UQ     0.00
# 23152  에이스하이텍(주)  71930.0  2006/12   4.0  2015/07/10     UQ     0.00
# 23153  에이스하이텍(주)  71930.0  2007/12   4.0  2015/07/10     UQ     0.00
# 23154  에이스하이텍(주)  71930.0  2008/12   4.0  2015/07/10     QU     0.00
# 23155  에이스하이텍(주)  71930.0  2009/12   4.0  2015/07/10     UQ     0.00
# 23156  에이스하이텍(주)  71930.0  2010/12   4.0  2015/07/10     UQ     0.00
# 23157  에이스하이텍(주)  71930.0  2011/12   4.0  2015/07/10     UQ     0.00
# 23158  에이스하이텍(주)  71930.0  2012/12   4.0  2015/07/10     UQ     0.00
# ...

# %%
dataset.at[23159,'부도'] = 1

# %% [markdown]
# ## **엠텍비젼(주)**

# %%
dataset.loc[dataset['회사명'] == dpt_list[68], dataset.columns[:-8]]
# Out:
#            회사명    거래소코드     회계년도  소속코드       상장폐지일 감사의견코드  자기자본배당률  \
# 23639  엠텍비젼(주)  74000.0  2000/12   4.0  2014/03/27     UQ     0.00
# 23640  엠텍비젼(주)  74000.0  2001/12   4.0  2014/03/27     UQ     0.00
# 23641  엠텍비젼(주)  74000.0  2002/12   4.0  2014/03/27     UQ     0.00
# 23642  엠텍비젼(주)  74000.0  2003/12   4.0  2014/03/27     UQ     0.00
# 23643  엠텍비젼(주)  74000.0  2004/12   4.0  2014/03/27     UQ     4.37
# 23644  엠텍비젼(주)  74000.0  2005/12   4.0  2014/03/27     UQ     5.78
# 23645  엠텍비젼(주)  74000.0  2006/12   4.0  2014/03/27     UQ     0.00
# 23646  엠텍비젼(주)  74000.0  2007/12   4.0  2014/03/27     UQ     0.00
# 23647  엠텍비젼(주)  74000.0  2008/12   4.0  2014/03/27     UQ     0.00
# 23648  엠텍비젼(주)  74000.0  2009/12   4.0  2014/03/27     UQ     0.00
# 23649  엠텍비젼(주)  74000.0  2010/12   4.0  2014/03/27     UQ     0.00
# 23650  엠텍비젼(주)  74000.0  2011/12   4.0  2014/03/27     UQ     0.00
# 23651  엠텍비젼(주)  74000.0  2012/12   4.0  2014/03/27     UQ     0.00
# ...

# %%
dataset.at[23651,'부도'] = 1

# %% [markdown]
# ## **우경(주)**

# %%
dataset.loc[dataset['회사명'] == dpt_list[69], dataset.columns[:-8]]
# Out:
#          회사명    거래소코드     회계년도  소속코드       상장폐지일 감사의견코드  자기자본배당률  금융비용 대 부채비율  \
# 23937  우경(주)  25920.0  2000/12   4.0  2013/07/10     UQ     0.00     0.044370
# 23938  우경(주)  25920.0  2001/12   4.0  2013/07/10     UQ     0.00     0.051239
# 23939  우경(주)  25920.0  2002/12   4.0  2013/07/10     UQ     0.00     0.036705
# 23940  우경(주)  25920.0  2003/12   4.0  2013/07/10     UQ     2.56     0.020225
# 23941  우경(주)  25920.0  2004/12   4.0  2013/07/10     UQ     2.83     0.047616
# 23942  우경(주)  25920.0  2005/12   4.0  2013/07/10     UQ     0.00     0.042087
# 23943  우경(주)  25920.0  2006/12   4.0  2013/07/10     UQ     0.00     0.045798
# 23944  우경(주)  25920.0  2007/12   4.0  2013/07/10     UQ     0.00     0.062866
# 23945  우경(주)  25920.0  2008/12   4.0  2013/07/10     UQ     0.00     0.052475
# 23946  우경(주)  25920.0  2009/12   4.0  2013/07/10     UQ     0.00     0.055141
# 23947  우경(주)  25920.0  2010/12   4.0  2013/07/10     UQ     0.00     0.087613
# ...

# %%
dataset.at[23948,'부도'] = 1

# %% [markdown]
# ## **이엘케이(주)**

# %%
dataset.loc[dataset['회사명'] == dpt_list[70], dataset.columns[:-8]]
# Out:
#            회사명    거래소코드     회계년도  소속코드       상장폐지일 감사의견코드  자기자본배당률  \
# 24429  이엘케이(주)  94190.0  2004/12   4.0  2020/05/22     UQ     0.00
# 24430  이엘케이(주)  94190.0  2005/12   4.0  2020/05/22     UQ     0.00
# 24431  이엘케이(주)  94190.0  2006/12   4.0  2020/05/22     UQ     2.40
# 24432  이엘케이(주)  94190.0  2007/12   4.0  2020/05/22     UQ     1.76
# 24433  이엘케이(주)  94190.0  2008/12   4.0  2020/05/22     UQ     0.00
# 24434  이엘케이(주)  94190.0  2009/12   4.0  2020/05/22     UQ     0.00
# 24435  이엘케이(주)  94190.0  2010/12   4.0  2020/05/22     UQ     1.39
# 24436  이엘케이(주)  94190.0  2011/12   4.0  2020/05/22     UQ     1.22
# 24437  이엘케이(주)  94190.0  2012/12   4.0  2020/05/22     UQ     0.00
# 24438  이엘케이(주)  94190.0  2013/12   4.0  2020/05/22     UQ     0.00
# 24439  이엘케이(주)  94190.0  2014/12   4.0  2020/05/22     UQ     0.00
# 24440  이엘케이(주)  94190.0  2015/12   4.0  2020/05/22     UQ     0.00
# 24441  이엘케이(주)  94190.0  2016/12   4.0  2020/05/22     UQ     0.00
# ...

# %%
dataset.at[24443,'부도'] = 1

# %% [markdown]
# ## **잘만테크(주)**

# %%
dataset.loc[dataset['회사명'] == dpt_list[71], dataset.columns[:-8]]
# Out:
#            회사명    거래소코드     회계년도  소속코드       상장폐지일 감사의견코드  자기자본배당률  \
# 24726  잘만테크(주)  90120.0  2004/12   4.0  2015/05/13     QS     0.00
# 24727  잘만테크(주)  90120.0  2005/12   4.0  2015/05/13     UQ     0.00
# 24728  잘만테크(주)  90120.0  2006/12   4.0  2015/05/13     UQ     0.00
# 24729  잘만테크(주)  90120.0  2007/12   4.0  2015/05/13     UQ     1.04
# 24730  잘만테크(주)  90120.0  2008/12   4.0  2015/05/13     UQ     0.00
# 24731  잘만테크(주)  90120.0  2009/12   4.0  2015/05/13     UQ     0.00
# 24732  잘만테크(주)  90120.0  2010/12   4.0  2015/05/13     UQ     0.00
# 24733  잘만테크(주)  90120.0  2011/12   4.0  2015/05/13     UQ     0.00
# 24734  잘만테크(주)  90120.0  2012/12   4.0  2015/05/13     UQ     0.00
# 24735  잘만테크(주)  90120.0  2013/12   4.0  2015/05/13     UQ     0.00
# 24736  잘만테크(주)  90120.0  2014/12   4.0  2015/05/13     DU     0.00
#
#        금융비용 대 부채비율   자기자본배율   유동부채비율  ...  유동자산회전률  총자본투자효율  순운전자본비율  \
# 24726     0.029799  1053.98    28.69  ...     2.18    38.00    43.47
# ...

# %%
dataset.at[[24726,24735],'부도'] = 1

# %% [markdown]
# ## **태산엘시디(주)**

# %%
dataset.loc[dataset['회사명'] == dpt_list[73], dataset.columns[:-8]]
# Out:
#             회사명    거래소코드     회계년도  소속코드       상장폐지일 감사의견코드  자기자본배당률  \
# 25638  태산엘시디(주)  36210.0  2000/12   4.0  2014/04/11     UQ     2.48
# 25639  태산엘시디(주)  36210.0  2001/12   4.0  2014/04/11     UQ     4.34
# 25640  태산엘시디(주)  36210.0  2002/12   4.0  2014/04/11     UQ     3.95
# 25641  태산엘시디(주)  36210.0  2003/12   4.0  2014/04/11     UQ     2.99
# 25642  태산엘시디(주)  36210.0  2004/12   4.0  2014/04/11     UQ     2.83
# 25643  태산엘시디(주)  36210.0  2005/12   4.0  2014/04/11     UQ     2.10
# 25644  태산엘시디(주)  36210.0  2006/12   4.0  2014/04/11     UQ     1.84
# 25645  태산엘시디(주)  36210.0  2007/12   4.0  2014/04/11     UQ     2.02
# 25646  태산엘시디(주)  36210.0  2008/12   4.0  2014/04/11     UQ     0.00
# 25647  태산엘시디(주)  36210.0  2009/12   4.0  2014/04/11     UQ     0.00
# 25648  태산엘시디(주)  36210.0  2010/12   4.0  2014/04/11     UQ     0.00
# 25649  태산엘시디(주)  36210.0  2011/12   4.0  2014/04/11     UQ     0.00
# 25650  태산엘시디(주)  36210.0  2012/12   4.0  2014/04/11     QU     0.00
# ...

# %%
dataset.at[[25645,25650],'부도'] = 1

# %% [markdown]
# ## **텔슨정보통신(주)**

# %%
dataset.loc[dataset['회사명'] == dpt_list[75], dataset.columns[:-8]]
# Out:
#              회사명    거래소코드     회계년도  소속코드       상장폐지일 감사의견코드  자기자본배당률  \
# 25715  텔슨정보통신(주)  18180.0  2000/12   4.0  2005/04/07     UQ     0.73
# 25716  텔슨정보통신(주)  18180.0  2001/12   4.0  2005/04/07     UQ     0.00
# 25717  텔슨정보통신(주)  18180.0  2002/12   4.0  2005/04/07     UQ     0.00
# 25718  텔슨정보통신(주)  18180.0  2003/12   4.0  2005/04/07     UQ     0.00
# 25719  텔슨정보통신(주)  18180.0  2004/12   4.0  2005/04/07     DU     0.00
#
#        금융비용 대 부채비율  자기자본배율  유동부채비율  ...  유동자산회전률  총자본투자효율  순운전자본비율    누적수익성비율  \
# 25715     0.043702  683.29   48.94  ...     1.01     9.69    33.99   0.070513
# 25716     0.083820  519.74   33.54  ...     0.53    -5.33    46.63  -0.089441
# 25717     0.056897  184.58  304.10  ...     1.06   -27.26    -3.76  -0.508530
# 25718     0.097984   24.71  565.44  ...     1.31   -14.68    11.52  -1.600264
# 25719     0.105535    0.00    0.00  ...     0.82  -240.50  -372.87 -11.953203
#
#        총자산영업이익률    총자산회전율       년        key   부도             공시발생일
# ...

# %%
dataset.at[25718,'부도'] = 1

# %% [markdown]
# # **데이터 확인**

# %%
dftcpy = len(dataset.loc[dataset['부도'] == 0]['회사명'].unique())
print('부도로 판정된 기업수: {num}'.format(num=dftcpy))
# Out:
# 부도로 판정된 기업수: 402

# %%
dataset['부도'].value_counts()
# Out:
# 1.0    26426
# 0.0      406
# Name: 부도, dtype: int64

# %% [markdown]
# ## **재수정**

# %%
dataset.loc[dataset['회사명'] == '(주)스틸플라워']
# Out:
#            회사명    거래소코드     회계년도  소속코드       상장폐지일 감사의견코드  자기자본배당률  \
# 6218  (주)스틸플라워  87220.0  2002/12   4.0  2018/05/08     UQ     0.00
# 6219  (주)스틸플라워  87220.0  2003/12   4.0  2018/05/08     QS     0.00
# 6220  (주)스틸플라워  87220.0  2004/12   4.0  2018/05/08     UQ     0.00
# 6221  (주)스틸플라워  87220.0  2005/12   4.0  2018/05/08     UQ     0.00
# 6222  (주)스틸플라워  87220.0  2006/12   4.0  2018/05/08     UQ     0.00
# 6223  (주)스틸플라워  87220.0  2007/12   4.0  2018/05/08     UQ     0.32
# 6224  (주)스틸플라워  87220.0  2008/12   4.0  2018/05/08     UQ     1.13
# 6225  (주)스틸플라워  87220.0  2009/12   4.0  2018/05/08     UQ     1.88
# 6226  (주)스틸플라워  87220.0  2010/12   4.0  2018/05/08     UQ     0.00
# 6227  (주)스틸플라워  87220.0  2011/12   4.0  2018/05/08     UQ     1.24
# 6228  (주)스틸플라워  87220.0  2012/12   4.0  2018/05/08     UQ     0.59
# 6229  (주)스틸플라워  87220.0  2013/12   4.0  2018/05/08     UQ     0.00
# 6230  (주)스틸플라워  87220.0  2014/12   4.0  2018/05/08     UQ     0.00
# ...

# %%
dataset.at[6232,'부도'] = 1

# %%
dataset.loc[dataset['회사명'] == '(주)씨그널엔터테인먼트그룹']
# Out:
#                  회사명    거래소코드     회계년도  소속코드       상장폐지일 감사의견코드  자기자본배당률  \
# 6803  (주)씨그널엔터테인먼트그룹  99830.0  2001/12   4.0  2018/05/04     QS     6.46
# 6804  (주)씨그널엔터테인먼트그룹  99830.0  2002/12   4.0  2018/05/04     UQ     6.46
# 6805  (주)씨그널엔터테인먼트그룹  99830.0  2003/12   4.0  2018/05/04     UQ     2.87
# 6806  (주)씨그널엔터테인먼트그룹  99830.0  2004/12   4.0  2018/05/04     UQ     7.44
# 6807  (주)씨그널엔터테인먼트그룹  99830.0  2005/12   4.0  2018/05/04     UQ     5.91
# 6808  (주)씨그널엔터테인먼트그룹  99830.0  2006/12   4.0  2018/05/04     UQ     9.55
# 6809  (주)씨그널엔터테인먼트그룹  99830.0  2007/12   4.0  2018/05/04     UQ     6.68
# 6810  (주)씨그널엔터테인먼트그룹  99830.0  2008/12   4.0  2018/05/04     UQ     2.90
# 6811  (주)씨그널엔터테인먼트그룹  99830.0  2009/12   4.0  2018/05/04     UQ     3.86
# 6812  (주)씨그널엔터테인먼트그룹  99830.0  2010/12   4.0  2018/05/04     UQ     3.29
# 6813  (주)씨그널엔터테인먼트그룹  99830.0  2011/12   4.0  2018/05/04     UQ     1.23
# 6814  (주)씨그널엔터테인먼트그룹  99830.0  2012/12   4.0  2018/05/04     UQ     0.00
# ...

# %%
dataset.at[6803,'부도'] = 1

# %%
dataset.loc[dataset['회사명'] == '(주)주노콜렉션']
# Out:
#             회사명     거래소코드     회계년도  소속코드       상장폐지일 감사의견코드  자기자본배당률  \
# 13922  (주)주노콜렉션  221670.0  2014/12   4.0  2019/07/16      0      0.0
# 13923  (주)주노콜렉션  221670.0  2015/12   4.0  2019/07/16     QS      0.0
# 13924  (주)주노콜렉션  221670.0  2016/12   4.0  2019/07/16     UQ      0.0
# 13925  (주)주노콜렉션  221670.0  2017/12   4.0  2019/07/16     UQ      0.0
# 13926  (주)주노콜렉션  221670.0  2018/12   4.0  2019/07/16     DS      0.0
#
#        금융비용 대 부채비율   자기자본배율  유동부채비율  ...   부도  공시발생일  정기공시제목  수시공시제목  대표이사 변경  \
# 13922     0.024511  1094.12  115.93  ...  1.0      0       0       0      0.0
# 13923     0.032307  1094.12  115.93  ...  0.0      0       0       0      0.0
# 13924     0.036793   772.70  127.29  ...  1.0      0       0       0      0.0
# 13925     0.035259   434.19  144.54  ...  1.0      0       0       0      0.0
# 13926     0.040137   475.64  204.62  ...  0.0      0       0       0      0.0
#
#        최대주주 변경  회계처리위반  횡령배임  폐지사유요약합본  (13957, 부도)
# ...

# %%
dataset.at[13923,'부도'] = 1

# %%
dataset.loc[dataset['회사명'] == '(주)중앙디자인']
# Out:
#             회사명    거래소코드     회계년도  소속코드       상장폐지일 감사의견코드  자기자본배당률  \
# 13948  (주)중앙디자인  30030.0  2000/12   4.0  2011/04/13     UQ     0.00
# 13949  (주)중앙디자인  30030.0  2001/12   4.0  2011/04/13     UQ     0.00
# 13950  (주)중앙디자인  30030.0  2002/12   4.0  2011/04/13     UQ     2.91
# 13951  (주)중앙디자인  30030.0  2003/12   4.0  2011/04/13     UQ     2.55
# 13952  (주)중앙디자인  30030.0  2004/12   4.0  2011/04/13     UQ     2.52
# 13953  (주)중앙디자인  30030.0  2005/12   4.0  2011/04/13     UQ     2.71
# 13954  (주)중앙디자인  30030.0  2006/12   4.0  2011/04/13     UQ     1.08
# 13955  (주)중앙디자인  30030.0  2007/12   4.0  2011/04/13     UQ     1.72
# 13956  (주)중앙디자인  30030.0  2008/12   4.0  2011/04/13     UQ     0.00
# 13957  (주)중앙디자인  30030.0  2009/12   4.0  2011/04/13     UQ     0.00
# 13958  (주)중앙디자인  30030.0  2010/12   4.0  2011/04/13     DU     0.00
#
#        금융비용 대 부채비율  자기자본배율  유동부채비율  ...   부도             공시발생일  정기공시제목  \
# 13948     0.006194  307.42  104.73  ...  1.0                 0       0
# ...

# %%
dataset.at[13957,'부도'] = 1

# %%
dftcpy = len(dataset.loc[dataset['부도'] == 0]['회사명'].unique())
print('부도로 판정된 기업수: {num}'.format(num=dftcpy))
# Out:
# 부도로 판정된 기업수: 402

# %%
dataset['부도'].value_counts()
# Out:
# 1.0    26430
# 0.0      402
# Name: 부도, dtype: int64

# %%
dataset.to_csv(r'C:\Users\JH\Desktop\Final\CBA\Data\최종데이터셋\Finaldataset_ver6.csv',index=False)

# %% [markdown]
# # **라이브러리**

# %%
import pandas as pd

# %%
dataset = pd.read_csv(r'C:\Users\JH\Desktop\Final\Ubion-CorporateBankruptcyAnalysis\Data\최종데이터셋\Finaldataset_ver7.1.csv')
subset = pd.read_csv(r'C:\Users\JH\Desktop\Final\Ubion-CorporateBankruptcyAnalysis\Code\JH\data\신종사채.csv', encoding='cp949')
subset2 = pd.read_csv(r'C:\Users\JH\Desktop\Final\Ubion-CorporateBankruptcyAnalysis\Code\JY\selenium\0020공시29.csv', index_col=0)
subset3 = pd.read_csv(r'C:\Users\JH\Desktop\Final\Ubion-CorporateBankruptcyAnalysis\Code\JH\data\출자목적.csv', encoding='cp949')
subset.fillna(0, inplace=True)

# %%
dataset
# Out:
#        Unnamed: 0       회사명    거래소코드     회계년도  소속코드 상장폐지일 감사의견코드  자기자본배당률  \
# 0               0  (주)CMG제약  58820.0  2000/12   5.0     0     UQ     0.00
# 1               1  (주)CMG제약  58820.0  2001/12   5.0     0     UQ     0.00
# 2               2  (주)CMG제약  58820.0  2002/12   5.0     0     UQ     0.00
# 3               3  (주)CMG제약  58820.0  2003/12   5.0     0     UQ     0.00
# 4               4  (주)CMG제약  58820.0  2004/12   5.0     0     UQ     0.00
# ...           ...       ...      ...      ...   ...   ...    ...      ...
# 25119       25119   흥구석유(주)  24060.0  2015/12   5.0     0     UQ     1.70
# 25120       25120   흥구석유(주)  24060.0  2016/12   5.0     0     UQ     2.10
# 25121       25121   흥구석유(주)  24060.0  2017/12   5.0     0     UQ     2.08
# 25122       25122   흥구석유(주)  24060.0  2018/12   5.0     0     UQ     2.48
# 25123       25123   흥구석유(주)  24060.0  2019/12   5.0     0     UQ     2.83
#
#        금융비용 대 부채비율   자기자본배율  ...  공시발생일  정기공시제목  수시공시제목  대표이사 변경  최대주주 변경  \
# ...

# %% [markdown]
# # **함수모음**

# %%
def preprots(subset, dataset, col):
    global subdf
    subset.fillna(0, inplace=True)
    subset['key'] = (subset['거래소코드'].astype(str) + subset.회계년도.str[0:4]).astype(float)
    
    subdf = pd.DataFrame({'key': subset3['key'].value_counts().index, col : subset3['key'].value_counts().values})

    dataset = dataset.merge(subdf[['key',col]], how='outer', on ='key')
    dataset[col].fillna(0, inplace=True)
    dataset.dropna(inplace=True)
    dataset.drop('Unnamed: 0',axis=1, inplace=True)

    return dataset

# %%
for i in range(len(subset3['출자목적'].unique())):
    print(subset3['출자목적'].unique()[i])
# Out:
# nan
# 출자금
# 경영권인수
# 출자
# 자회사설립
# 투자수익획득
# 현물출자전환
# 자회사출자
# 사업관련
# 계열회사
# 지분투자
# 종속회사
# 투자
# 사업참여
# 지배
# 공동투자
# 단순투자
# 경영참여
# 해외사업확장
# 해외시장진출
# 게임개발
# 투자/게임개발
# 해외시장
# 신규사업진출
# 물적분할
# 신규법인
# 시장개척
# 연구개발
# 분할
# 사업효율화
# 사업다각화
# 해외거점확보
# 사회공헌
# 방송채널사업
# GDR직영점위탁운영
# 지주회사
# 부동산개발업
# 부동산개발
# 경영참여등
# 인적분할
# 투자수익
# 경영권참여
# 투자수익도모
# 수익도모
# 영업투자
# 관계기업
# 미국내인테리어디자인산업진출
# 인테리어디자인설계및시공
# 영업
# 경영참가
# 투자목적
# 사업협력
# 사업제휴
# 사업확장
# 중국시장진출
# 생산법인설립
# 총판
# 신성장동력확보및사업의다각화
# 협력관계유지
# 해외사업진출
# CDM사업확대
# 타법인출자
# 투자유가증권
# 경영
# 생산확충
# 매출시장다각화
# 지분참여
# 해외발전정비및부대사업
# 영업지원
# 사업의다각화
# 글로벌사업확대
# 해외진출
# 종속기업투자주식
# 신규사업진출목적
# 사업양수
# 분할신설
# 현지법인
# 미국현지법인
# 인도시장진출
# 매출극대화사업확충
# 포괄적주식교환
# 해외현지법인
# 경영권지배
# 기술협력
# 사업활성화
# 유지보수
# 지분취득
# 해외영업강화
# 사무공간확보
# 소프트웨어개발외
# 게임소프트웨어개발외
# 기술용역
# 게임발굴
# 모바일게임개발
# 콘텐츠발굴
# 골프회원권출자전환
# 게임소프트웨어개발
# 사업개발
# 글로벌플랫폼활용
# 인터넷서비스
# 소프트웨어개발
# 경여참여
# 신규사업
# 단순자
# 공동연구개발
# 현지판매법인
# 판매법인
# 제품판매
# 신사업진출
# 신사업발굴
# 사업경쟁력강화
# 중국시장확장
# 조합원자격
# 주주
# 판교테크노벨리입주를위한지분참여
# 차익실현
# 해외법인
# 경영권
# 신약개발
# 해외마케팅
# ...

# %%
keys
# Out:
# 3.576020e+08    111
# 3.576020e+08    102
# 1.137020e+08     86
# 3.589020e+08     83
# 1.309602e+09     81
#                ...
# 3.690020e+08      1
# 8.072020e+08      1
# 2.561502e+09      1
# 1.228002e+09      1
# 6.627020e+08      1
# Name: key, Length: 27164, dtype: int64

# %%
preprots(subset3, dataset, '출자목적')
# Out:
#             회사명    거래소코드     회계년도  소속코드 상장폐지일 감사의견코드  자기자본배당률  금융비용 대 부채비율  \
# 0      (주)CMG제약  58820.0  2000/12   5.0     0     UQ     0.00     0.019074
# 1      (주)CMG제약  58820.0  2001/12   5.0     0     UQ     0.00     0.023517
# 2      (주)CMG제약  58820.0  2002/12   5.0     0     UQ     0.00     0.043081
# 3      (주)CMG제약  58820.0  2003/12   5.0     0     UQ     0.00     0.058531
# 4      (주)CMG제약  58820.0  2004/12   5.0     0     UQ     0.00     0.047346
# ...         ...      ...      ...   ...   ...    ...      ...          ...
# 25119   흥구석유(주)  24060.0  2015/12   5.0     0     UQ     1.70     0.005597
# 25120   흥구석유(주)  24060.0  2016/12   5.0     0     UQ     2.10     0.012651
# 25121   흥구석유(주)  24060.0  2017/12   5.0     0     UQ     2.08     0.012502
# 25122   흥구석유(주)  24060.0  2018/12   5.0     0     UQ     2.48     0.018056
# 25123   흥구석유(주)  24060.0  2019/12   5.0     0     UQ     2.83     0.000300
#
# ...

# %%
subset3.fillna(0, inplace=True)
subset3['key'] = (subset3['거래소코드'].astype(str) + subset3.회계년도.str[0:4]).astype(float)

# %%
subset3['key'].value_counts()
# Out:
# 3.576020e+08    111
# 3.576020e+08    102
# 1.137020e+08     86
# 3.589020e+08     83
# 1.309602e+09     81
#                ...
# 3.690020e+08      1
# 8.072020e+08      1
# 2.561502e+09      1
# 1.228002e+09      1
# 6.627020e+08      1
# Name: key, Length: 27164, dtype: int64

# %%
dataset1 = setss(subset3,dataset,'출자목적')
dataset1
# Out:
#              회사명    거래소코드     회계년도  소속코드 상장폐지일 감사의견코드  자기자본배당률  금융비용 대 부채비율  \
# 0       (주)CMG제약  58820.0  2000/12   5.0     0     UQ     0.00     0.019074
# 1       (주)CMG제약  58820.0  2001/12   5.0     0     UQ     0.00     0.023517
# 2       (주)CMG제약  58820.0  2002/12   5.0     0     UQ     0.00     0.043081
# 3       (주)CMG제약  58820.0  2003/12   5.0     0     UQ     0.00     0.058531
# 4       (주)CMG제약  58820.0  2004/12   5.0     0     UQ     0.00     0.047346
# ...          ...      ...      ...   ...   ...    ...      ...          ...
# 116241   흥구석유(주)  24060.0  2015/12   5.0     0     UQ     1.70     0.005597
# 116242   흥구석유(주)  24060.0  2016/12   5.0     0     UQ     2.10     0.012651
# 116243   흥구석유(주)  24060.0  2017/12   5.0     0     UQ     2.08     0.012502
# 116244   흥구석유(주)  24060.0  2018/12   5.0     0     UQ     2.48     0.018056
# 116245   흥구석유(주)  24060.0  2019/12   5.0     0     UQ     2.83     0.000300
#
# ...

# %%
dataset1.isnull().sum()
# Out:
# Unnamed: 0     2996
# 회사명            2996
# 거래소코드          2996
# 회계년도           2996
# 소속코드           2996
# 상장폐지일          2996
# 감사의견코드         2996
# 자기자본배당률        2996
# 금융비용 대 부채비율    2996
# 자기자본배율         2996
# 유동부채비율         2996
# 매입채무회전률        2996
# 유동자산회전률        2996
# 총자본투자효율        2996
# 순운전자본비율        2996
# 누적수익성비율        2996
# 총자산영업이익률       2996
# 총자산회전율         2996
# 년              2996
# key               0
# 부도             2996
# 공시발생일          2996
# 정기공시제목         2996
# 수시공시제목         2996
# 대표이사 변경        2996
# 최대주주 변경        2996
# 회계처리위반         2996
# 횡령배임           2996
# 폐지사유요약합본       2996
# 신종채권           2996
# 영업조업중단         2996
# 출자목적            375
# dtype: int64

# %% [markdown]
# # **신종채권 TS2000 전처리**

# %%
subset3['출자목적'].value_counts()
# Out:
# 투자                     17603
# 단순투자                    6094
# 경영참여                    5963
# 사업다각화                   2273
# 지분투자                    1370
#                        ...
# 전환권행사                      1
# 무선인터터넷컨텐츠확보                1
# DMB컨소시엄 참여                 1
# 해외법인설립투자                   1
# 매출채권 출자전환에 의한 주식 취득        1
# Name: 출자목적, Length: 3660, dtype: int64

# %%
subset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34346 entries, 0 to 34345
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   회사명     34346 non-null  object
#  1   거래소코드   34346 non-null  int64
#  2   회계년도    34346 non-null  object
#  3   발행종류    34346 non-null  float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 1.0+ MB

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26832 entries, 0 to 26831
# Data columns (total 28 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   회사명          26832 non-null  object
#  1   거래소코드        26832 non-null  float64
#  2   회계년도         26832 non-null  object
#  3   소속코드         26832 non-null  float64
#  4   상장폐지일        26832 non-null  object
#  5   감사의견코드       26832 non-null  object
#  6   자기자본배당률      26832 non-null  float64
#  7   금융비용 대 부채비율  26832 non-null  float64
#  8   자기자본배율       26832 non-null  float64
#  9   유동부채비율       26832 non-null  float64
#  10  매입채무회전률      26832 non-null  float64
#  11  유동자산회전률      26832 non-null  float64
#  12  총자본투자효율      26832 non-null  float64
#  13  순운전자본비율      26832 non-null  float64
#  14  누적수익성비율      26832 non-null  float64
#  15  총자산영업이익률     26832 non-null  float64
#  16  총자산회전율       26832 non-null  float64
#  17  년            26832 non-null  float64
# ...

# %%
subset['key'] = (subset['거래소코드'].astype(str) + subset.회계년도.str[0:4]).astype(float)

# %%
subset['발행종류'] = subset['발행종류'].replace([10,20,90,30], 1)

# %%
subset['발행종류'].value_counts()
# Out:
# 0.0    19632
# 1.0    14714
# Name: 발행종류, dtype: int64

# %%
bond = subset['key'].value_counts() - 1

# %%
bond.index
# Out:
# Float64Index([  88002019.0, 1410202018.0,  998302015.0, 2156002016.0,
#                326002000.0,  741402008.0,  538902007.0,  715302012.0,
#               2263502019.0,  302702016.0,
#               ...
#                799602011.0,  729502009.0, 3575502015.0,  679002018.0,
#               1100202016.0,  997502006.0,  259002015.0, 1435402011.0,
#               3149302015.0,  959102006.0],
#              dtype='float64', length=27164)

# %%
subset_ = pd.DataFrame({'key': bond.index, '신종채권': bond.values})

# %%
dataset = dataset.merge(subset_[['key','신종채권']], how = 'outer', on = 'key')

# %%
dataset.loc[((dataset['부도'] == 0) & (dataset['신종채권'] != 0)),'신종채권'] = 0

# %%
dataset.dropna(axis=0, inplace=True)

# %%
dataset['부도'].value_counts()
# Out:
# 1.0    24722
# 0.0      402
# Name: 부도, dtype: int64

# %%
dataset.to_csv(r'C:\Users\JH\Desktop\Final\Ubion-CorporateBankruptcyAnalysis\Data\최종데이터셋\Finaldataset_ver7.csv', index=False)

# %% [markdown]
# # **영업중단/조업중단 kind 전처리**

# %%
dataset.loc[dataset['거래소코드'] == 79810, ['key','회계년도']]
# Out:
#               key     회계년도
# 2320  798102005.0  2004/12
# 2321  798102006.0  2005/12
# 2322  798102007.0  2006/12
# 2323  798102008.0  2007/12
# 2324  798102009.0  2008/12
# 2325  798102010.0  2009/12
# 2326  798102011.0  2010/12
# 2327  798102012.0  2011/12
# 2328  798102013.0  2012/12
# 2329  798102014.0  2013/12
# 2330  798102015.0  2014/12
# 2331  798102016.0  2015/12
# 2332  798102017.0  2016/12
# 2333  798102018.0  2017/12
# 2334  798102019.0  2018/12
# 2335  798102020.0  2019/12

# %%
subset2['key'] = (subset2['거래소코드'] + subset2.공시발생일.str[0:4]).astype(float)

# %%
subset2.loc[subset2['거래소코드'] == 'ICT']
# Out:
#      회사명 거래소코드             공시발생일           공시제목  \
# 644  포스코   ICT  2019-01-22 15:50  [정정]거래처와의거래중단
# 645  포스코   ICT  2019-01-11 15:44  [정정]거래처와의거래중단
# 649  포스코   ICT  2018-12-27 18:00  [정정]거래처와의거래중단
# 650  포스코   ICT  2018-12-27 17:05      거래처와의거래중단
#
#                                                   text  \
# 644  \r\n\r\n\r\n\r\n\r\n\r\n:: 70247_거래처와의 거래중단\r\...
# 645  \r\n\r\n\r\n\r\n\r\n\r\n:: 70247_거래처와의 거래중단\r\...
# 649  \r\n\r\n\r\n\r\n\r\n\r\n:: 70247_거래처와의 거래중단\r\...
# 650  \r\n\r\n\r\n\r\n\r\n\r\n:: 70247_거래처와의 거래중단\r\...
#
#                                                   link      key
# 644  https://kind.krx.co.kr/external/2019/01/22/000...  ICT2019
# 645  https://kind.krx.co.kr/external/2019/01/11/000...  ICT2019
# 649  https://kind.krx.co.kr/external/2018/12/27/000...  ICT2018
# 650  https://kind.krx.co.kr/external/2018/12/27/000...  ICT2018

# %%
subset2 = subset2.drop(index = [199,606,368,644,645,649,650]) # 거래소코드가 숫자가 아닌 경우 드랍

# %%
salesstop = subset2['key'].value_counts()

# %%
subset3 = pd.DataFrame({'key' : salesstop.index, '영업조업중단' : salesstop.values})

# %%
dataset = dataset.merge(subset3, how = 'outer', on = 'key')

# %%
dataset['영업조업중단'].fillna(0, inplace=True)

# %%
dataset.isnull().sum()
# Out:
# 회사명            22
# 거래소코드          22
# 회계년도           22
# 소속코드           22
# 상장폐지일          22
# 감사의견코드         22
# 자기자본배당률        22
# 금융비용 대 부채비율    22
# 자기자본배율         22
# 유동부채비율         22
# 매입채무회전률        22
# 유동자산회전률        22
# 총자본투자효율        22
# 순운전자본비율        22
# 누적수익성비율        22
# 총자산영업이익률       22
# 총자산회전율         22
# 년              22
# key             0
# 부도             22
# 공시발생일          22
# 정기공시제목         22
# 수시공시제목         22
# 대표이사 변경        22
# 최대주주 변경        22
# 회계처리위반         22
# 횡령배임           22
# 폐지사유요약합본       22
# 신종채권           22
# 영업조업중단          0
# dtype: int64

# %%
dataset.dropna(axis=0, inplace=True)

# %%
dataset.to_csv(r'C:\Users\JH\Desktop\Final\Ubion-CorporateBankruptcyAnalysis\Data\최종데이터셋\Finaldataset_ver7.1.csv')

# %% [markdown]
# # **타법인출자**

# %%
subset3 = pd.read_csv(r'C:\Users\JH\Desktop\Final\Ubion-CorporateBankruptcyAnalysis\Code\JH\data\출자목적.csv', encoding='cp949')

# %%
subset3['key'] = (subset3['거래소코드'].astype(str) + subset3.회계년도.str[0:4]).astype(float)

# %%
subset3['출자목적'] = subset3['출자목적'].str.replace(' ','')

# %%
subset3.loc[subset3['출자목적'] == '출자']
# Out:
#                회사명  거래소코드     회계년도 출자목적          key
# 13        (주)CMG제약  58820  2008/12   출자  588202008.0
# 6572       (주)다원시스  68240  2017/12   출자  682402017.0
# 6579       (주)다원시스  68240  2018/12   출자  682402018.0
# 6585       (주)다원시스  68240  2019/12   출자  682402019.0
# 6654     (주)단성일렉트론  85990  2006/12   출자  859902006.0
# ...            ...    ...      ...  ...          ...
# 116697  한라아이엠에스(주)  92460  2009/12   출자  924602009.0
# 116699  한라아이엠에스(주)  92460  2009/12   출자  924602009.0
# 116700  한라아이엠에스(주)  92460  2009/12   출자  924602009.0
# 117452   한일네트웍스(주)  46110  2016/12   출자  461102016.0
# 117462   한일네트웍스(주)  46110  2017/12   출자  461102017.0
#
# [1195 rows x 5 columns]

# %%
subset3['출자목적'].value_counts()[:10]
# Out:
# 투자       17681
# 단순투자      7467
# 경영참여      7300
# 사업다각화     3180
# 지분투자      1665
# 투자목적      1468
# 출자        1195
# 사업관련      1153
# 경영참가      1115
# 계열회사      1076
# Name: 출자목적, dtype: int64

# %%
subset3['출자목적'].value_counts().index[:100]
# Out:
# Index(['투자', '경영권', '계속영업이익창출', '출자', '출자금', '설립', '조합출자', '타법인출자', '법인설립',
#        '협회가입', '신규사업참여', '조합가입', '해외법인설립', '권고', '전략적투자', '취득', '물적분할',
#        '생산기지확보', '계열편입', 'SPC', '사업투자', '해외시장확대', '사업영위', '-', '신규설립', '보증서발급',
#        '투자참여', '기타', '계열회사편입', '사업자의무가입', '태양광발전사업', '면허유지', '주주', '신사업진출',
#        '출자참여', '사업관련등', '사업관련출자', '중국진출', '해외생산기지', '영업투자', '해외지사설립', '전략투자',
#        '판매법인', '분할', '투자수익실현', '신규사업투자', '채권회수', '분사', '협력', '거래', '유통채널투자',
#        '저임금활용', '신사업발굴', '해외영업강화', '생산및판매', '관계회사출자', 'BTL사업관련', '조합', '콘텐츠발굴',
#        '제휴사업', '합병으로인한취득', '해외사업확장', '계열회사지분취득', '중국사업진출', '현지생산', '가입',
#        '중국현지법인', 'SI사업', '보증보험', 'SI사업목적', '신규시장개척', '계열사설립', '면허취득', '해외사업총괄',
#        '시장확대', '지상파DMB사업', '주식교환', '지분인수', '공모청약', '제품제조', '생산거점', '지분확보',
#        '설립(사업관련)', '판매', '동종업계권익보호', '해외사업지원', '지배권강화', '판매촉진', '미국진출', '채권보상',
#        '인적분할', '매출채권출자전환', '신규사업진출및사업다각화', '시장점유율확대', '주식', '시너지', '투자수익획득',
#        '공동기술사업화', '단순투자목적', '자동차사업강화'],
# ...

# %%
arr = ['단순투자','장기투자증권','투자목적','자금운영','일반투자','장기투자','수익창출을위한단순투자','투자수익','단순','자금운용','투자이익','투자유가증권','유휴자금투자','투자이익',
'장기매도가능증권','매도가능증권','단순투자에따른지분취득','단순출자','투자(국내)','해외투자','투자(SPC)','투자수익창출','투자수익기대','투자자산','종속기업투자주식','투자활동',
'매도가능금융']
for i in arr:
    subset3.loc[subset3['출자목적'] == i, '출자목적'] ='투자'

# %%
arr2 = ['경영참여','지분투자','경영참가', '계열회사','지분참여', '경영권참여', '지분취득', '경영','관계회사','지분출자', '종속회사','지분법적용투자주식','경영권확보','경영참여등'
,'경영목적', '관계사', '경영권참여/사업진출','자회사', '자회사설립','지분증권', '경영지배','경영효율화','경영권지배','자회사지분취득','출자전환', '지배','경영권안정','해외자회사','지배권획득'
,'경영참가등','계열회사출자','계열사','종속기업해외투자', '관계기업투자','자회사출자','경영권인수','관계기업','경영권인수','종속기업']
for i in arr2:
    subset3.loc[subset3['출자목적'] == i, '출자목적'] ='경영권'

# %%
arr3 = ['사업다각화', '사업활성화', '사업','사업다각화','신규사업', '사업제휴', '신규사업진출','사업관련', '사업확장', '사업확대', '해외진출','해외시장진출','영화투자네트워크강화', '설립투자', 
'영업', '전략적제휴', '사업영역확대','게임퍼블리싱', '모바일게임개발', '해외', '사업시너지,투자', '해외시장개척', '민간투자사업참여','사업부분확대와매출증대및수익창출', '사업공조','사업상시너지', 
'사업협력','공동연구개발', '영업상', '사업상필요','시장지배력확대','사업부문확대와매출증대및수익창출','해외마케팅', '영업/생산', '사업시너지','중국시장진출', '해외거점확보', '자사제품의판매촉진',
'게임개발','시장개척','사업강화', '제품의판매','현지생산및판매', '판교인터넷파크조성사업참가', '매출확대','우수개발인력및게임라인업확보', '해외생산기지확보','합병','매출극대화사업확충',
'기술제휴', '연구협력','제품판매', '해외사업확대', '원가절감', '전자제품,부품제조', '사업의다각화','사업효율화','콘텐츠경쟁력강화','영업확대','해외사업', '영업확대', '연구개발', '현지법인설립',
'신규사업추진','현지법인','설립출자', '업무제휴', '해외현지법인','기술협력','생산', '화장품사업다각화', '지방영업망확충', '해외생산', '사업품목확장','경영다각화', '문화컨텐츠투자', '현지시장진출',
'해외법인', '사업전문화', '해외영업', '해외사업진출', '수출촉진','중국전자재료시장진출','사업개발', '사업참여','사업관련등', '사업관련출자', '중국진출', '해외생산기지', '영업투자', '해외지사설립', '전략투자',
'판매법인'
]
for i in arr3:
    subset3.loc[subset3['출자목적'] == i, '출자목적'] ='계속영업이익창출'

# %%
keys = subset3['key'].value_counts()
subset3.loc[subset3['key'] == keys.index[0]]
# Out:
#              회사명  거래소코드     회계년도 출자목적          key
# 32480  (주)씨제이이엔엠  35760  2020/12  경영권  357602020.0
# 32481  (주)씨제이이엔엠  35760  2020/12  경영권  357602020.0
# 32482  (주)씨제이이엔엠  35760  2020/12  경영권  357602020.0
# 32483  (주)씨제이이엔엠  35760  2020/12  경영권  357602020.0
# 32484  (주)씨제이이엔엠  35760  2020/12  경영권  357602020.0
# ...          ...    ...      ...  ...          ...
# 32586  (주)씨제이이엔엠  35760  2020/12   투자  357602020.0
# 32587  (주)씨제이이엔엠  35760  2020/12   투자  357602020.0
# 32588  (주)씨제이이엔엠  35760  2020/12   투자  357602020.0
# 32589  (주)씨제이이엔엠  35760  2020/12   투자  357602020.0
# 32590  (주)씨제이이엔엠  35760  2020/12   투자  357602020.0
#
# [111 rows x 5 columns]

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\JH\Desktop\Final\Ubion-CorporateBankruptcyAnalysis\Data\최종데이터셋\finaldataset_ver7.6.csv',usecols=['경영자산비율',
 '부채구성비율','유동비율','자기자본배율', '유형자산회전율',
       '총자본순이익률', '자기자본영업이익률', '경영자본영업이익률', '매출액증가율', '총자본투자효율', '영업이익증가율',
       '매출채권회수기간'])

# %%
vif = pd.DataFrame()
vif['변수명'] = df.columns 
vif['VIF'] = [variance_inflation_factor(df.values, i) for i in range(df.shape[1])]

# %%
df.corr()
# Out:
#             순운전자본비율   총자본순이익률  자기자본영업이익률  경영자본영업이익률   유형자산회전율   총자본투자효율  \
# 순운전자본비율    1.000000  0.301402   0.098491   0.251624  0.005731  0.333326
# 총자본순이익률    0.301402  1.000000   0.392215   0.669396  0.003442  0.465035
# 자기자본영업이익률  0.098491  0.392215   1.000000   0.581420  0.008278  0.216944
# 경영자본영업이익률  0.251624  0.669396   0.581420   1.000000  0.044276  0.345490
# 유형자산회전율    0.005731  0.003442   0.008278   0.044276  1.000000 -0.001709
# 총자본투자효율    0.333326  0.465035   0.216944   0.345490 -0.001709  1.000000
# 매출액증가율     0.008187  0.011510   0.015660   0.022335  0.003374  0.003785
# 영업이익증가율   -0.000868  0.030641   0.052587   0.077697  0.009514  0.014694
# 부채구성비율    -0.783397 -0.342960  -0.056464  -0.248958 -0.005580 -0.354001
# 경영자산비율     0.208196  0.112210   0.115511   0.127190 -0.045293  0.082054
# 매출채권회수기간   0.014360 -0.060968  -0.035584  -0.058923  0.004466 -0.023852
# 자기자본배율     0.018022 -0.005315  -0.008615  -0.013868 -0.000496 -0.004598
#
# ...

# %%
vif
# Out:
#           변수명        VIF
# 0     순운전자본비율   4.513115
# 1     총자본순이익률   2.120685
# 2   자기자본영업이익률   1.566780
# 3   경영자본영업이익률   2.441479
# 4     유형자산회전율   1.006775
# 5     총자본투자효율   1.386913
# 6      매출액증가율   1.001103
# 7     영업이익증가율   1.011786
# 8      부채구성비율   9.512632
# 9      경영자산비율  12.430510
# 10   매출채권회수기간   1.073692
# 11     자기자본배율   1.001614

# %%
vif
# Out:
#           변수명       VIF
# 0        유동비율  1.001513
# 1     총자본순이익률  2.110366
# 2   자기자본영업이익률  1.566097
# 3   경영자본영업이익률  2.439884
# 4     유형자산회전율  1.005665
# 5     총자본투자효율  1.383659
# 6      매출액증가율  1.001002
# 7     영업이익증가율  1.011786
# 8      부채구성비율  3.323548
# 9      경영자산비율  3.376396
# 10   매출채권회수기간  1.071314
# 11     자기자본배율  1.001550

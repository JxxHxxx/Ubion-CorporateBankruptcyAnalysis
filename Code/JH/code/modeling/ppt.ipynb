# %%
import pandas as pd

# %%
dataset = pd.read_csv(r'C:\Users\JH\Desktop\Final\Ubion-CorporateBankruptcyAnalysis\Code\JH\code\modeling\0년차검증.csv')
dataset.sort_values(by= 'SET2 test Accuracy', ascending=False)
# Out:
#            model  SET1 val Accuracy  SET1 test Accuracy  SET1 test f1-Score  \
# 4            KNN           0.807989              0.8498              0.0534
# 1  Random Forest           0.835205              0.8195              0.0519
# 7       Catboost           0.842455              0.8288              0.0533
# 6       lightGBM           0.812266              0.8008              0.0472
# 9        Xgboost           0.808079              0.8074              0.0488
# 3       logistic           0.673325              0.8762              0.0640
# 2       Adaboost           0.810862              0.8161              0.0487
# 8            MLP           0.732085              0.8223              0.0539
# 0  Decision Tree           0.772159              0.7258              0.0364
# 5            SVC           0.557463              0.0065              0.0124
#
#    SET1 test Precision  SET1 test Recall  SET2 val Accuracy  \
# 4               0.0278            0.6792           0.802299
# 1               0.0268            0.7925           0.868153
# 7               0.0276            0.7736           0.860985
# 6               0.0243            0.7925           0.852422
# 9               0.0252            0.7925           0.839499
# 3               0.0336            0.6792           0.741913
# 2               0.0251            0.7547           0.828128
# 8               0.0278            0.8113           0.770862
# 0               0.0186            0.8302           0.809475
# 5               0.0062            1.0000           0.554589
#
#    SET2 test Accuracy  SET2 test f1_Score  SET2 test Precision  \
# 4              0.8550              0.0552               0.0288
# 1              0.8508              0.0648               0.0337
# 7              0.8495              0.0643               0.0335
# 6              0.8368              0.0583               0.0303
# 9              0.8353              0.0540               0.0280
# 3              0.8307              0.0489               0.0253
# 2              0.8271              0.0553               0.0286
# 8              0.8100              0.0472               0.0243
# 0              0.7314              0.0338               0.0173
# 5              0.0065              0.0124               0.0062
#
#    SET2 test Recall
# 4            0.6792
# 1            0.8302
# 7            0.8302
# 6            0.8113
# 9            0.7547
# 3            0.6981
# 2            0.8113
# 8            0.7547
# 0            0.7547
# 5            1.0000

# %%
dataset1 = pd.read_csv(r'C:\Users\JH\Desktop\Final\Ubion-CorporateBankruptcyAnalysis\Code\JH\code\modeling\1년차검증.csv')
dataset1.sort_values(by= 'SET2 test Accuracy', ascending=False)
# Out:
#            model  SET1 val Accuracy  SET1 test Accuracy  SET1 test f1-Score  \
# 3       logistic           0.775424              0.2814              0.4321
# 7       Catboost           0.802260              0.7356              0.8423
# 4            KNN           0.769774              0.7723              0.8663
# 1  Random Forest           0.803672              0.7317              0.8398
# 2       Adaboost           0.775424              0.7328              0.8405
# 6       lightGBM           0.790960              0.7178              0.8304
# 9        Xgboost           0.779661              0.7073              0.8232
# 8            MLP           0.742938              0.7244              0.8350
# 0  Decision Tree           0.723164              0.6854              0.8081
# 5            SVC           0.538136              0.0056              0.0001
#
#    SET1 test Precision  SET1 test Recall  SET2 val Accuracy  \
# 3               0.9941            0.2814           0.727401
# 7               0.9934            0.7356           0.829096
# 4               0.9924            0.7723           0.752825
# 1               0.9932            0.7317           0.826271
# 2               0.9931            0.7328           0.799435
# 6               0.9930            0.7178           0.807910
# 9               0.9930            0.7073           0.814972
# 8               0.9921            0.7244           0.734463
# 0               0.9916            0.6854           0.723164
# 5               0.0000            0.0056           0.533898
#
#    SET2 test Accuracy  SET2 test f1_Score  SET2 test Precision  \
# 3              0.8107              0.8902               0.9930
# 7              0.7887              0.8766               0.9931
# 4              0.7829              0.8730               0.9924
# 1              0.7823              0.8726               0.9934
# 2              0.7734              0.8670               0.9926
# 6              0.7723              0.8662               0.9932
# 9              0.7608              0.8589               0.9930
# 8              0.7580              0.8570               0.9931
# 0              0.7074              0.8232               0.9934
# 5              0.0056              0.0001               0.0000
#
#    SET2 test Recall
# 3            0.8107
# 7            0.7887
# 4            0.7829
# 1            0.7823
# 2            0.7734
# 6            0.7723
# 9            0.7608
# 8            0.7580
# 0            0.7074
# 5            0.0056

# %%
dataset2 = pd.read_csv(r'C:\Users\JH\Desktop\Final\Ubion-CorporateBankruptcyAnalysis\Code\JH\code\modeling\2년차검증.csv')
dataset2.sort_values(by= 'SET2 test Accuracy', ascending=False)
# Out:
#            model  SET1 val Accuracy  SET1 test Accuracy  SET1 test f1-Score  \
# 3       logistic           0.735218              0.7795              0.8712
# 7       Catboost           0.752119              0.6847              0.8078
# 4            KNN           0.705864              0.7237              0.8348
# 2       Adaboost           0.719799              0.6703              0.7977
# 9        Xgboost           0.711553              0.6519              0.7844
# 6       lightGBM           0.714244              0.6434              0.7780
# 1  Random Forest           0.745120              0.6894              0.8111
# 0  Decision Tree           0.691898              0.5930              0.7398
# 8            MLP           0.686327              0.5928              0.7395
# 5            SVC           0.539318              0.0052              0.0001
#
#    SET1 test Precision  SET1 test Recall  SET2 val Accuracy  \
# 3               0.9926            0.7795           0.736693
# 7               0.9931            0.6847           0.778694
# 4               0.9924            0.7237           0.707206
# 2               0.9925            0.6703           0.756324
# 9               0.9923            0.6519           0.747850
# 6               0.9924            0.6434           0.739455
# 1               0.9931            0.6894           0.782962
# 0               0.9910            0.5930           0.668006
# 8               0.9916            0.5928           0.726822
# 5               0.0000            0.0052           0.551958
#
#    SET2 test Accuracy  SET2 test f1_Score  SET2 test Precision  \
# 3              0.7756              0.8687               0.9923
# 7              0.7431              0.8476               0.9929
# 4              0.7303              0.8393               0.9921
# 2              0.7254              0.8360               0.9919
# 9              0.7143              0.8284               0.9923
# 6              0.7100              0.8255               0.9922
# 1              0.7088              0.8246               0.9932
# 0              0.6605              0.7907               0.9918
# 8              0.6408              0.7761               0.9924
# 5              0.0052              0.0001               0.0000
#
#    SET2 test Recall
# 3            0.7756
# 7            0.7431
# 4            0.7303
# 2            0.7254
# 9            0.7143
# 6            0.7100
# 1            0.7088
# 0            0.6605
# 8            0.6408
# 5            0.0052

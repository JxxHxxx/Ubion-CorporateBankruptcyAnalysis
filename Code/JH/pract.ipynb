# %%
import pandas as pd

# %%
train = pd.read_csv(r'C:\Users\JH\Desktop\Final\CBA\Data\데이터정리중\재무변수_부도이유.csv', index_col= 0)

# %%
train.columns
# Out:
# Index(['회사명', '거래소코드', '회계년도', '소속코드', '상장폐지일', '감사의견코드', '자산총계(요약)',
#        '유동자산(요약)', '당좌자산(요약)', '현금 및 현금성자산(요약)',
#        ...
#        'PSR(Price sales ratio)(최저)', '기업가치(EV)', 'EBITDA', 'EBITDA/매출액',
#        'EBITDA/금융비용', 'EBITDA/평균발행주식수', 'EV/EBITDA', '년', 'key', '공시제목'],
#       dtype='object', length=270)

# %%
tf = train[['거래소코드']].dropna(axis=0)
tf
# Out:
#          거래소코드
# 0      58820.0
# 1      58820.0
# 2      58820.0
# 3      58820.0
# 4      58820.0
# ...        ...
# 27352  24060.0
# 27353  24060.0
# 27354  24060.0
# 27355  24060.0
# 27356  24060.0
#
# [27357 rows x 1 columns]

# %%
train = train.iloc[0:27357]

# %%
train
# Out:
#             회사명    거래소코드     회계년도  소속코드 상장폐지일 감사의견코드  자산총계(요약)  유동자산(요약)  \
# 0      (주)CMG제약  58820.0  2000/12   5.0   NaN     UQ   28990.0   21169.0
# 1      (주)CMG제약  58820.0  2001/12   5.0   NaN     UQ   20908.0   16359.0
# 2      (주)CMG제약  58820.0  2002/12   5.0   NaN     UQ   15401.0    9880.0
# 3      (주)CMG제약  58820.0  2003/12   5.0   NaN     UQ   11063.0    8534.0
# 4      (주)CMG제약  58820.0  2004/12   5.0   NaN     UQ    5179.0    3893.0
# ...         ...      ...      ...   ...   ...    ...       ...       ...
# 27352   흥구석유(주)  24060.0  2016/12   5.0   NaN     UQ   79137.0   14794.0
# 27353   흥구석유(주)  24060.0  2017/12   5.0   NaN     UQ   79912.0   15880.0
# 27354   흥구석유(주)  24060.0  2018/12   5.0   NaN     UQ   75206.0   12515.0
# 27355   흥구석유(주)  24060.0  2019/12   5.0   NaN     UQ   83661.0   22620.0
# 27356   흥구석유(주)  24060.0  2020/12   5.0   NaN     UQ   83721.0   27688.0
#
#        당좌자산(요약)  현금 및 현금성자산(요약)  ...  PSR(Price sales ratio)(최저)   기업가치(EV)  \
# ...

# %% [markdown]
# # **감사의견거절 감사보고서 부적정·의견거절·범위제한한정**
# ![screensh](ClipboardImage_2021-11-22_163548.png)
#
#
#
# - AG, DS, DU, DI, QS

# %%
subset = train[['소속코드','감사의견코드','공시제목']] 
subset
# Out:
#        소속코드 감사의견코드 공시제목
# 0       5.0     UQ  NaN
# 1       5.0     UQ  NaN
# 2       5.0     UQ  NaN
# 3       5.0     UQ  NaN
# 4       5.0     UQ  NaN
# ...     ...    ...  ...
# 27352   5.0     UQ  NaN
# 27353   5.0     UQ  NaN
# 27354   5.0     UQ  NaN
# 27355   5.0     UQ  NaN
# 27356   5.0     UQ  NaN
#
# [27357 rows x 3 columns]

# %%
subset['감사의견코드'].value_counts()
# Out:
# UQ    26182
# DU      232
# QS      123
# DS      123
# QU      114
# QG       42
# AG       15
# NS       11
# QQ        2
# Name: 감사의견코드, dtype: int64

# %%
subset.loc[(subset['소속코드'] == 4) & (subset['감사의견코드'] == 'DS')]

# replace로 해결
# Out:
#        소속코드 감사의견코드      공시제목
# 803     4.0     DS       NaN
# 890     4.0     DS       NaN
# 1209    4.0     DS       NaN
# 1383    4.0     DS  회생절차개시신청
# 1560    4.0     DS       NaN
# ...     ...    ...       ...
# 25348   4.0     DS       NaN
# 25799   4.0     DS       NaN
# 25931   4.0     DS       NaN
# 26814   4.0     DS       NaN
# 27095   4.0     DS       NaN
#
# [86 rows x 3 columns]

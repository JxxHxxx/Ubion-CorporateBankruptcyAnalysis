# %%
import pandas as pd

# %%
train = pd.read_csv(r'C:\Users\JH\Desktop\코드_재무변수.csv', encoding='euc-kr')

# %%
t5.columns
# Out:
# Index(['회사명', '거래소코드', '회계년도', '총자본증가율', '유형자산증가율', '유동자산증가율', '영업이익증가율',
#        '경상이익증가율 (2007년 이전 발생)', '순이익증가율', '재고자산증가율',
#        ...
#        '자본잉여금(요약)', '자본조정(요약)', '기타포괄손익누계액(요약)', '이익잉여금(요약)',
#        '*미처분이익잉여금 및 차기이월미처분이익잉여금(요약)', '*당기순이익(요약)', '부채와자본총계(요약)', '소속코드',
#        '상장폐지일', '감사의견코드'],
#       dtype='object', length=293)

# %%
t5 = pd.read_csv(r'C:\Users\JH\Desktop\Final\CBA\Data\재무데이터 최종.csv', index_col ='Unnamed: 0')

# %%
pd.concat([t4, t5], axis=0)
# Out:
#            회사명  거래소코드     회계년도  소속코드       상장폐지일 감사의견코드  자산총계(요약)  유동자산(요약)  \
# 0       (주)디보스  80140  2002/12   4.0  2010/02/02     UQ   12254.0    7505.0
# 1       (주)디보스  80140  2003/12   4.0  2010/02/02     UQ   22113.0   14942.0
# 2       (주)디보스  80140  2004/12   4.0  2010/02/02     UQ   39390.0   28852.0
# 3       (주)디보스  80140  2005/12   4.0  2010/02/02     UQ   61574.0   40417.0
# 4       (주)디보스  80140  2006/12   4.0  2010/02/02     UQ   74910.0   49939.0
# ...        ...    ...      ...   ...         ...    ...       ...       ...
# 27054  흥구석유(주)  24060  2004/12   5.0         NaN     UQ   71047.0    8768.0
# 27055  흥구석유(주)  24060  2006/12   5.0         NaN     UQ   73369.0   12314.0
# 27056  흥구석유(주)  24060  2002/12   5.0         NaN     UQ   72466.0   11413.0
# 27057  흥구석유(주)  24060  2001/12   5.0         NaN     UQ   69204.0    7637.0
# 27058  흥구석유(주)  24060  2003/12   5.0         NaN     UQ   70899.0    8986.0
#
# ...

# %%
print(t1.shape,t2.shape, t3.shape, t4.shape)
# Out:
# (27059, 175) (27059, 51) (27059, 73) (271, 267)

# %%
for i in range(len(t2.columns)):
    print(t2.columns[i])
# Out:
# 회사명
# 거래소코드
# 회계년도
# 소속코드
# 상장폐지일
# 감사의견코드
# 매출액(요약)(백만원)
# 매출원가(요약)(백만원)
# 매출총이익(요약)(백만원)
# 판매비와 관리비(요약)(백만원)
# 급료
# 임금
# 상여
# 수당 등(요약)(백만원)
# 퇴직급여(요약)(백만원)
# 복리후생비(요약)(백만원)
# 세금과공과(요약)(백만원)
# 임차료(요약)(백만원)
# 감가상각비
# 무형자산상각비
# 영업권상각(요약)(백만원)
# 연구비
# 경상개발비(요약)(백만원)
# 기타 판매비와 관리비(요약)(백만원)
# 영업이익(요약)(백만원)
# 영업외수익(요약)(백만원)
# 이자수익(요약)(백만원)
# 배당금수익(요약)(백만원)
# 외환차익(요약)(백만원)
# 외화환산이익(요약)(백만원)
# 지분법이익(요약)(백만원)
# 기타영업외수익(요약)(백만원)
# 영업외비용(요약)(백만원)
# 이자비용(요약)(백만원)
# 외환차손(요약)(백만원)
# 외화환산손실(요약)(백만원)
# 지분법손실(요약)(백만원)
# 기타영업외비용(요약)(백만원)
# 법인세비용차감전(계속사업)손익(요약)(백만원)
# (계속사업손익)법인세비용(요약)(백만원)
# 계속사업이익(요약)(백만원)
# 중단사업이익(요약)(백만원)
# *법인세효과(요약)(백만원)
# 당기순이익(요약)(백만원)
# 주당계속사업이익(요약)(원)
# 주당순이익(요약)(원)
# 희석화주당계속사업이익(요약)(원)
# 희석화주당순이익(요약)(원)
# CPA수정후 당기순이익(요약)(백만원)
# *주당경상이익(2007년 이전 발생)(요약)(원)
# *희석화주당경상이익(2007년 이전 발생)(요약)(원)

# %%
175 + 51 + 73 - 6
# Out:
# 293

# %%
train = pd.read_csv(r'C:\Users\JH\Desktop\Final\CBA\Code\HJ\재무데이터_최종_0.csv', index_col = 'Unnamed: 0')

# %%
len(train['회사명'].unique())
# Out:
# 2036

# %%
train['찐부도'].value_counts()
# Out:
# 0    26983
# 1       76
# Name: 찐부도, dtype: int64

# %%
train.loc[(train['소속코드'] == 4) & (train['감사의견코드'] == 'DS'), '찐부도'] = 1

# %%
len(train['거래소코드'].values[1].astype(str)) == 5
# Out:
# True

# %%
for i in range(len(train['거래소코드'])):
    if len(train['거래소코드'].values[i].astype(str)) == 5:
        train['거래소코드'] = train['거래소코드'].replace(str(0) + train['거래소코드'].values[i].astype(str)) 
    else:
        pass

# %%
train.sort_values(by='거래소코드' ,ascending=True)
# Out:
#             회사명   거래소코드     회계년도  총자본증가율  유형자산증가율  유동자산증가율  영업이익증가율  \
# 21645  삼천당제약(주)     250  2019/12    7.02   -12.15     9.43    89.31
# 21647  삼천당제약(주)     250  2001/12   18.53    22.35    19.22    -5.53
# 21648  삼천당제약(주)     250  2016/12    9.02    -0.75     7.19    23.98
# 21649  삼천당제약(주)     250  2017/12   12.67    -3.18     3.95     3.33
# 21650  삼천당제약(주)     250  2002/12    9.20     2.06    11.38   -31.11
# ...         ...     ...      ...     ...      ...      ...      ...
# 21213    미투젠(유)  950190  2020/12   93.74   -16.32    97.06     8.44
# 5915     (주)소마젠  950200  2019/12     NaN      NaN      NaN      NaN
# 5914     (주)소마젠  950200  2020/12    0.00     0.00     0.00     0.00
# 744    (주)네오이뮨텍  950220  2020/12    0.00     0.00     0.00     0.00
# 743    (주)네오이뮨텍  950220  2019/12     NaN      NaN      NaN      NaN
#
#        경상이익증가율 (2007년 이전 발생)  순이익증가율  재고자산증가율  ...  자본잉여금(요약)  자본조정(요약)  \
# 21645                    NaN   -5.07    -3.45  ...        NaN       NaN
# ...

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 27059 entries, 0 to 27058
# Columns: 293 entries, 회사명 to 감사의견코드
# dtypes: float64(282), int64(3), object(8)
# memory usage: 60.7+ MB

# %%
train.loc[train['소속코드'] == 4.0]
# Out:
#                 회사명  거래소코드     회계년도  총자본증가율  유형자산증가율  유동자산증가율  영업이익증가율  \
# 89          (주)강원랜드  35250  2000/12     NaN      NaN      NaN      NaN
# 90          (주)강원랜드  35250  2001/12    0.00     0.00     0.00     0.00
# 91          (주)강원랜드  35250  2002/12   18.44   126.65   -23.62    -1.51
# 109    (주)경윤하이드로에너지  19120  2000/12  -13.62     2.78   -13.06   -50.19
# 110    (주)경윤하이드로에너지  19120  2001/12   10.07     3.18    13.90    26.89
# ...             ...    ...      ...     ...      ...      ...      ...
# 26998      후야인포넷(주)  32050  2004/12  -60.69   -79.16   -68.37     0.00
# 26999      후야인포넷(주)  32050  2002/12    3.20    86.83    20.47     0.00
# 27000      후야인포넷(주)  32050  2003/12  -84.80   -80.58   -87.42     0.00
# 27001      후야인포넷(주)  32050  2000/12   88.94    25.16   129.54   -53.76
# 27002      후야인포넷(주)  32050  2001/12  -46.27   -22.51   -53.97     0.00
#
#        경상이익증가율 (2007년 이전 발생)  순이익증가율  재고자산증가율  ...  자본잉여금(요약)  자본조정(요약)  \
# ...

# %%
train['거래소코드'][100]
# Out:
# 63080

# %%
train['거래소코드'].values[1].astype(str)
# Out:
# '58820'

# %%
for i in range(len(train['거래소코드'])):
    if len(train['거래소코드'].values[i].astype(str)) == 5:
        train['거래소코드'] = str(0) + train['거래소코드'].values[i].astype(str)
    elif len(train['거래소코드'].values[i].astype(str)) == 4:
        train['거래소코드'] = str(00) + train['거래소코드'].values[i].astype(str)
    elif len(train['거래소코드'].values[i].astype(str)) == 3:
        train['거래소코드'] = str(000) + train['거래소코드'].values[i].astype(str)
    else:
        pass
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_31448/3371322442.py in <module>
#       1 for i in range(len(train['거래소코드'])):
# ----> 2     if len(train['거래소코드'].values[i].astype(str)) == 5:
#       3         train['거래소코드'] = str(0) + train['거래소코드'].values[i].astype(str)
#       4     elif len(train['거래소코드'].values[i].astype(str)) == 4:
#       5         train['거래소코드'] = str(00) + train['거래소코드'].values[i].astype(str)
#
# AttributeError: 'str' object has no attribute 'astype'

# %%
str(0) + train['거래소코드'].values[1].astype(str)
# Out:
# '058820'

# %%
train.loc[(train['소속코드'] == 4.0) & (train['감사의견코드'] == 'DS')]
# Out:
#                회사명  거래소코드     회계년도  총자본증가율  유형자산증가율  유동자산증가율  영업이익증가율  \
# 798        (주)네오퍼플  28090  2012/12   -4.98   -65.65    24.34      0.0
# 885         (주)넥스지  81970  2017/12    0.67   -14.60    -0.50      0.0
# 1204     (주)뉴젠아이씨티  54150  2010/12  331.61    42.08   303.68      0.0
# 1378     (주)단성일렉트론  85990  2009/12   30.82   -32.50    99.56      0.0
# 1554      (주)대양글로벌  40180  2010/12  -18.92   141.47   -17.29      0.0
# ...            ...    ...      ...     ...      ...      ...      ...
# 25058      제이에스(주)  37110  2009/12   52.21   -73.97   113.22      0.0
# 25503  케이엔에스홀딩스(주)  36760  2008/12  -15.04    -1.57   -15.24      0.0
# 25642    코리아이앤디(주)  27440  2003/12  -38.10   -16.65   -28.31      0.0
# 26513   한국통신데이타(주)  45760  2007/12  135.95   -32.52   144.42      0.0
# 26799     해원에스티(주)  58480  2009/12   -9.48   -12.09   -10.23    -35.4
#
#        경상이익증가율 (2007년 이전 발생)  순이익증가율  재고자산증가율  ...  자본잉여금(요약)  자본조정(요약)  \
# ...

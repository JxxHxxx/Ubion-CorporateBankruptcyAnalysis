# %%
import pandas as pd

# %%
bankrupt = pd.read_csv(r'C:\Users\JH\Desktop\Final\CBA\Data\kind_bankrupt.csv', index_col ='Unnamed: 0')
train = pd.read_csv(r'C:\Users\JH\Desktop\코드_재무변수.csv', encoding='euc-kr', usecols = ['회사명','거래소코드','회계년도','소속코드','상장폐지일'])

# %%
train['년'] = (train['회계년도'].str[0:4].astype(int) + 1).astype(str)

# %%
train.head()
# Out:
#         회사명  거래소코드     회계년도  소속코드 상장폐지일     년
# 0  (주)CMG제약  58820  2000/12     5   NaN  2001
# 1  (주)CMG제약  58820  2001/12     5   NaN  2002
# 2  (주)CMG제약  58820  2002/12     5   NaN  2003
# 3  (주)CMG제약  58820  2003/12     5   NaN  2004
# 4  (주)CMG제약  58820  2004/12     5   NaN  2005

# %%
train['key'] = train['거래소코드'].astype(str) + train['년'].astype(str)

# %%
train.head()
# Out:
#         회사명  거래소코드     회계년도  소속코드 상장폐지일     년        key
# 0  (주)CMG제약  58820  2000/12     5   NaN  2001  588202001
# 1  (주)CMG제약  58820  2001/12     5   NaN  2002  588202002
# 2  (주)CMG제약  58820  2002/12     5   NaN  2003  588202003
# 3  (주)CMG제약  58820  2003/12     5   NaN  2004  588202004
# 4  (주)CMG제약  58820  2004/12     5   NaN  2005  588202005

# %%
bankrupt['년'] = bankrupt['시간']

# %%
bankrupt = bankrupt.reset_index()

# %%
for i in range(len(bankrupt)):
    bankrupt['년'][i] = bankrupt['시간'][i][0:4]
# Out:
# C:\Users\JH\AppData\Local\Temp/ipykernel_19588/2747911623.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bankrupt['년'][i] = bankrupt['시간'][i][0:4]

# %%
bankrupt['key'] = bankrupt['종목코드'].astype(str) + bankrupt['년'].astype(str)

# %%
bankrupt.loc[bankrupt['제출인'] == '제낙스']
# Out:
#      index   번호                시간  회사명   종목코드  \
# 351     57  193  2020-03-25 17:48  제낙스  65620
# 359     65  185  2020-03-13 16:17  제낙스  65620
#
#                                  공시제목  제출인     년        key
# 351  [정정]내부결산시점 관리종목 지정 또는 상장폐지 사유 발생  제낙스  2020  656202020
# 359   내부결산시점 관리종목 지정 또는 상장폐지 사유 발생[정]  제낙스  2020  656202020

# %%
bankrupt
# Out:
#      index   번호                시간     회사명    종목코드  \
# 0        0   24  2002-10-31 18:27    정산애강   22220
# 1        1   23  2002-10-08 12:06   대호특수강   21040
# 2        2   22  2002-05-21 18:16   에이치엘비   28300
# 3        3   21  2002-04-17 17:42   에이치엘비   28300
# 4        4   20  2001-12-26 14:58   대호특수강   21040
# ..     ...  ...               ...     ...     ...
# 389     95  155  2020-02-12 16:21  에스앤더블류  103230
# 390     96  154  2020-02-11 17:02     파나진   46210
# 391     97  153  2020-02-10 16:32     국순당   43650
# 392     98  152  2020-02-10 16:24    유아이디   69330
# 574  (주)나노트로닉스  10670.0  2012/12   4.0  2014/04/11  2013  106702013   40.0
#
#        번호                시간   회사명_y     종목코드  공시제목     제출인   년_y
# 574  79.0  2013-11-19 16:59  나노트로닉스  10670.0  파산신청  나노트로닉스  2013

# %%
print(train.shape, bankrupt.shape, tt.shape)
# Out:
# (27166, 7) (394, 9) (27379, 15)

# %%
27166 + 394 - 27379
# Out:
# 181

# %%
tf = tt.fillna('임시')
tf
# Out:
#           회사명_x    거래소코드     회계년도 소속코드 상장폐지일   년_x         key index     번호  \
# 0      (주)CMG제약  58820.0  2000/12  5.0    임시  2001   588202001    임시     임시
# 1      (주)CMG제약  58820.0  2001/12  5.0    임시  2002   588202002    임시     임시
# 2      (주)CMG제약  58820.0  2002/12  5.0    임시  2003   588202003    임시     임시
# 3      (주)CMG제약  58820.0  2003/12  5.0    임시  2004   588202004    임시     임시
# 4      (주)CMG제약  58820.0  2004/12  5.0    임시  2005   588202005    임시     임시
# ...         ...      ...      ...  ...   ...   ...         ...   ...    ...
# 27374        임시       임시       임시   임시    임시    임시  1019702015  89.0   12.0
# 27375        임시       임시       임시   임시    임시    임시   336002020   6.0  244.0
# 27376        임시       임시       임시   임시    임시    임시   336002020  20.0  230.0
# 27377        임시       임시       임시   임시    임시    임시   862502020  29.0  221.0
# 27378        임시       임시       임시   임시    임시    임시   862502020  44.0  206.0
#
#                      시간   회사명_y      종목코드          공시제목     제출인   년_y
# 0                    임시      임시        임시            임시      임시    임시
# 1                    임시      임시        임시            임시      임시    임시
# 2                    임시      임시        임시            임시      임시    임시
# 3                    임시      임시        임시            임시      임시    임시
# 4                    임시      임시        임시            임시      임시    임시
# ...                 ...     ...       ...           ...     ...   ...
# 27374  2015-03-02 18:15  우양에이치씨  101970.0      회생절차개시신청  우양에이치씨  2015
# 27375  2020-11-17 16:01      럭슬   33600.0  [정정]회생절차개시신청      럭슬  2020
# 27376  2020-09-02 15:40      럭슬   33600.0   회생절차개시신청[정]      럭슬  2020
# 27377  2020-07-28 14:54   이노와이즈   86250.0      회생절차개시결정    화신테크  2020
# 27378  2020-05-08 15:03   이노와이즈   86250.0      회생절차개시신청    화신테크  2020
#
# [27379 rows x 15 columns]

# %%
tf.loc[tf['회사명_x'] == '임시', '회사명_y'].unique()
# Out:
# array(['ST&I', '지노시스템', '엠투엔', '아진산업', '에이치엘비', '엔케이바이오', 'GK파워', '디보스',
#        '평안물산', '에이프로테크놀로지', '우양에이치씨', '럭슬', '이노와이즈'], dtype=object)

# %%
tf.loc[tf['회사명_x'] == '임시', '종목코드'].unique()
# Out:
# array([31800.0, 33850.0, 33310.0, 13310.0, 28300.0, 19260.0, 54020.0,
#        80140.0, 37240.0, 45470.0, 101970.0, 33600.0, 86250.0],
#       dtype=object)

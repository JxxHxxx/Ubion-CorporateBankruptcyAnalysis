# %%
import pandas as pd
import xlrd

# %%
train = pd.read_csv(r'C:\Users\JH\Desktop\Final\CBA\Data\재무데이터 최종.csv', index_col = 'Unnamed: 0')

# %%
train.loc[train['거래소코드'] == 21040]
# Out:
#            회사명  거래소코드     회계년도  총자본증가율  유형자산증가율  유동자산증가율  영업이익증가율  \
# 1663  (주)대호특수강  21040  2000/12   -2.55    -2.84     8.11   -13.84
# 1664  (주)대호특수강  21040  2001/12    0.00     0.00     0.00     0.00
# 1665  (주)대호특수강  21040  2002/12   16.66    -1.41    80.75     0.00
# 1666  (주)대호특수강  21040  2003/12   39.07    23.99    32.50     4.85
# 1667  (주)대호특수강  21040  2004/12   42.77     7.76    13.97   432.23
# 1668  (주)대호특수강  21040  2005/12   24.76    17.73    36.40   -41.07
# 1669  (주)대호특수강  21040  2006/12   15.46    -0.10    45.10     0.00
# 1670  (주)대호특수강  21040  2007/12   14.87     0.37    24.90     0.00
# 1671  (주)대호특수강  21040  2008/12  -22.30    -4.15   -37.06  2405.82
# 1672  (주)대호특수강  21040  2009/12   83.53     2.57   142.15   -55.61
# 1673  (주)대호특수강  21040  2010/12    5.16     0.67    12.45   303.89
# 1674  (주)대호특수강  21040  2011/12   21.89     2.30    33.11   -46.13
# 1675  (주)대호특수강  21040  2012/12   92.58   254.01    62.29     0.00
# ...

# %%
sub = pd.read_csv(r'C:\Users\JH\Desktop\Final\CBA\Data\부도사유데이터\부도사유0305.csv')

# %%
sub
# Out:
#    번호                시간    회사명   종목코드           공시제목    제출인
# 0   6  2005-01-12 15:20    파워넷  37030     회사정리절차개시결정    파워넷
# 1   5  2004-12-10 16:58    파워넷  37030     회사재산보전처분결정    파워넷
# 2   4  2004-12-08 18:21    파워넷  37030     회사정리절차개시신청    파워넷
# 3   3  2003-06-10 11:06    유니크  11320  화의채무변제완료보고서제출    유니크
# 4   2  2003-02-05 15:07  대호특수강  21040     회사정리절차종결결정  대호특수강
# 5   1  2003-01-28 14:15  대호특수강  21040     회사정리절차종결신청  대호특수강

# %%
print('나는 나쁜사람')
# Out:
# 나는 나쁜사람

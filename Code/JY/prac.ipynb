# %%
import pandas as pd

# %%
train = pd.read_csv('C:/Users/qorwl/Desktop/Ubion-CorporateBankruptcyAnalysis/Data/재무데이터 최종.csv', encoding ='utf-8', index_col=0)

# %%
train.head()
# Out:
#         회사명  거래소코드     회계년도  총자본증가율  유형자산증가율  유동자산증가율  영업이익증가율  \
# 0  (주)CMG제약  58820  2000/12     NaN      NaN      NaN      NaN
# 1  (주)CMG제약  58820  2001/12    0.00     0.00     0.00      0.0
# 2  (주)CMG제약  58820  2002/12  -26.34   -17.72   -39.61      0.0
# 3  (주)CMG제약  58820  2003/12  -28.17   -79.37   -13.62      0.0
# 4  (주)CMG제약  58820  2004/12  -53.18   -25.94   -54.38      0.0
#
#    경상이익증가율 (2007년 이전 발생)  순이익증가율  재고자산증가율  ...  자본잉여금(요약)  자본조정(요약)  \
# 0                    NaN     NaN      NaN  ...        NaN       NaN
# 1                   0.00     0.0     0.00  ...        NaN       NaN
# 2                    NaN     0.0   -39.91  ...        NaN       NaN
# 3                   0.00     0.0   -11.75  ...        NaN       NaN
# 4               -2128.48     0.0   -53.72  ...        NaN       NaN
#
#    기타포괄손익누계액(요약)  이익잉여금(요약)  *미처분이익잉여금 및 차기이월미처분이익잉여금(요약)  *당기순이익(요약)  \
# 0            NaN        NaN                           NaN         NaN
# 1            NaN        NaN                           NaN         NaN
# 2            NaN        NaN                           NaN         NaN
# 3            NaN        NaN                           NaN         NaN
# 4            NaN        NaN                           NaN         NaN
#
#    부채와자본총계(요약)  소속코드  상장폐지일  감사의견코드
# 0          NaN   5.0    NaN      UQ
# 1          NaN   5.0    NaN      UQ
# 2          NaN   5.0    NaN      UQ
# 3          NaN   5.0    NaN      UQ
# 4          NaN   5.0    NaN      UQ
#
# [5 rows x 293 columns]

# %%
data.shape
# Out:
# (27059, 294)

# %% [markdown]
# #### 재무데이터 거래소코드 6자리로 변환

# %%
# 확인
train['거래소코드'].dtypes
# Out:
# dtype('int64')

# %%
# 변환
train['거래소코드'] = train['거래소코드'].astype('str')

# %%
train['거래소코드'] = train['거래소코드'].str.zfill(6)

# %%
train
# Out:
#             회사명   거래소코드     회계년도  총자본증가율  유형자산증가율  유동자산증가율  영업이익증가율  \
# 0      (주)CMG제약  058820  2000/12     NaN      NaN      NaN      NaN
# 1      (주)CMG제약  058820  2001/12    0.00     0.00     0.00     0.00
# 2      (주)CMG제약  058820  2002/12  -26.34   -17.72   -39.61     0.00
# 3      (주)CMG제약  058820  2003/12  -28.17   -79.37   -13.62     0.00
# 4      (주)CMG제약  058820  2004/12  -53.18   -25.94   -54.38     0.00
# ...         ...     ...      ...     ...      ...      ...      ...
# 27054   흥구석유(주)  024060  2004/12    0.21     0.07    -2.43    26.81
# 27055   흥구석유(주)  024060  2006/12    1.60     1.69    24.04   -22.09
# 27056   흥구석유(주)  024060  2002/12    4.71    -1.19    49.44     2.21
# 27057   흥구석유(주)  024060  2001/12   -8.26    -0.72   -33.74  2973.17
# 27058   흥구석유(주)  024060  2003/12   -2.16    -0.78   -21.26    -7.27
#
#        경상이익증가율 (2007년 이전 발생)  순이익증가율  재고자산증가율  ...  자본잉여금(요약)  자본조정(요약)  \
# 0                        NaN     NaN      NaN  ...        NaN       NaN
# 1                       0.00    0.00     0.00  ...        NaN       NaN
# 2                        NaN    0.00   -39.91  ...        NaN       NaN
# 3                       0.00    0.00   -11.75  ...        NaN       NaN
# 4                   -2128.48    0.00   -53.72  ...        NaN       NaN
# ...                      ...     ...      ...  ...        ...       ...
# 27054                  14.93    9.72   -61.31  ...        NaN       NaN
# 27055                 -15.73  -14.52   -18.56  ...        NaN       NaN
# 27056                   3.97    8.01    18.63  ...        NaN       NaN
# 27057                  41.09   35.81     8.59  ...        NaN       NaN
# 27058                 -21.43  -21.74     0.84  ...        NaN       NaN
#
#        기타포괄손익누계액(요약)  이익잉여금(요약)  *미처분이익잉여금 및 차기이월미처분이익잉여금(요약)  *당기순이익(요약)  \
# 0                NaN        NaN                           NaN         NaN
# 1                NaN        NaN                           NaN         NaN
# 2                NaN        NaN                           NaN         NaN
# 3                NaN        NaN                           NaN         NaN
# 4                NaN        NaN                           NaN         NaN
# ...              ...        ...                           ...         ...
# 27054            NaN        NaN                           NaN         NaN
# 27055            NaN        NaN                           NaN         NaN
# 27056            NaN        NaN                           NaN         NaN
# 27057            NaN        NaN                           NaN         NaN
# 27058            NaN        NaN                           NaN         NaN
#
#        부채와자본총계(요약)  소속코드  상장폐지일  감사의견코드
# 0              NaN   5.0    NaN      UQ
# 1              NaN   5.0    NaN      UQ
# 2              NaN   5.0    NaN      UQ
# 3              NaN   5.0    NaN      UQ
# 4              NaN   5.0    NaN      UQ
# ...            ...   ...    ...     ...
# 27054          NaN   5.0    NaN      UQ
# 27055          NaN   5.0    NaN      UQ
# 27056          NaN   5.0    NaN      UQ
# 27057          NaN   5.0    NaN      UQ
# 27058          NaN   5.0    NaN      UQ
#
# [27059 rows x 293 columns]

# %% [markdown]
# #### 부도사유 거래소코드 6자리로 변환

# %%
bankrupt = pd.read_csv(r'C:\Users\qorwl\Desktop\Ubion-CorporateBankruptcyAnalysis\Data\부도사유데이터\부도사유0002.csv')

# %%
bankrupt['종목코드'].unique()
# Out:
# array([22220, 21040, 28300,  3310, 17160, 19260, 31800, 33850, 33310,
#        13310], dtype=int64)

# %% [markdown]
# #### 부도사유 csv 파일 병합

# %%
import csv
import glob
import pandas as pd

# %%
temp_0002 = pd.read_csv(r"C:\Users\qorwl\Desktop\Ubion-CorporateBankruptcyAnalysis\Data\부도사유데이터\부도사유0002.csv", encoding='utf-8')
temp_0305 = pd.read_csv(r"C:\Users\qorwl\Desktop\Ubion-CorporateBankruptcyAnalysis\Data\부도사유데이터\부도사유0305.csv", encoding='utf-8')
temp_0608 = pd.read_csv(r"C:\Users\qorwl\Desktop\Ubion-CorporateBankruptcyAnalysis\Data\부도사유데이터\부도사유0608.csv", encoding='utf-8')
temp_0911 = pd.read_csv(r"C:\Users\qorwl\Desktop\Ubion-CorporateBankruptcyAnalysis\Data\부도사유데이터\부도사유0911.csv", encoding='utf-8')
temp_1214 = pd.read_csv(r"C:\Users\qorwl\Desktop\Ubion-CorporateBankruptcyAnalysis\Data\부도사유데이터\부도사유1214.csv", encoding='utf-8')
temp_1517 = pd.read_csv(r"C:\Users\qorwl\Desktop\Ubion-CorporateBankruptcyAnalysis\Data\부도사유데이터\부도사유1517.csv", encoding='utf-8')
temp_1820 = pd.read_csv(r"C:\Users\qorwl\Desktop\Ubion-CorporateBankruptcyAnalysis\Data\부도사유데이터\부도사유1820.csv", encoding='utf-8')

# %%
bankrupt_df = pd.concat([temp_0002, temp_0305, temp_0608, temp_0911, temp_1214, temp_1517, temp_1820], axis=0)

# %%
bankrupt_df.reset_index()
# Out:
#      index   번호                시간     회사명    종목코드  \
# 0        0   24  2002-10-31 18:27    정산애강   22220
# 1        1   23  2002-10-08 12:06   대호특수강   21040
# 2        2   22  2002-05-21 18:16   에이치엘비   28300
# 3        3   21  2002-04-17 17:42   에이치엘비   28300
# 4        4   20  2001-12-26 14:58   대호특수강   21040
# ..     ...  ...               ...     ...     ...
# 389     95  155  2020-02-12 16:21  에스앤더블류  103230
# 390     96  154  2020-02-11 17:02     파나진   46210
# 391     97  153  2020-02-10 16:32     국순당   43650
# 392     98  152  2020-02-10 16:24    유아이디   69330
# 393     99  151  2020-02-07 17:14     이녹스   88390
#
#                                              공시제목     제출인
# 0                                     부도발생및은행거래정지    정산애강
# 1                                          은행거래재개   대호특수강
# 2                                      회사정리절차종결결정   에이치엘비
# 3                                      회사정리절차종결신청   에이치엘비
# 4                                      회사정리절차개시결정   대호특수강
# ..                                            ...     ...
# 389                  내부결산시점 관리종목 지정 또는 상장폐지 사유 발생  에스앤더블류
# 390                  내부결산시점 관리종목 지정 또는 상장폐지 사유 발생     파나진
# 391               내부결산시점 관리종목 지정 또는 상장폐지 사유 발생[정]     국순당
# 392                  내부결산시점 관리종목 지정 또는 상장폐지 사유 발생    유아이디
# 393  내부결산시점 관리종목 지정 또는 상장폐지 사유 발생(자회사의 주요경영사항)[정]     이녹스
#
# [394 rows x 7 columns]

# %%
type(bankrupt_df)
# Out:
# pandas.core.frame.DataFrame

# %%
bankrupt_df.to_csv('bankrupt_df.csv', encoding="utf-8-sig")

# %%
pd.read_csv('bankrupt_df.csv', index_col=0)
# Out:
#      번호                시간     회사명    종목코드  \
# 0    24  2002-10-31 18:27    정산애강   22220
# 1    23  2002-10-08 12:06   대호특수강   21040
# 2    22  2002-05-21 18:16   에이치엘비   28300
# 3    21  2002-04-17 17:42   에이치엘비   28300
# 4    20  2001-12-26 14:58   대호특수강   21040
# ..  ...               ...     ...     ...
# 95  155  2020-02-12 16:21  에스앤더블류  103230
# 96  154  2020-02-11 17:02     파나진   46210
# 97  153  2020-02-10 16:32     국순당   43650
# 98  152  2020-02-10 16:24    유아이디   69330
# 99  151  2020-02-07 17:14     이녹스   88390
#
#                                             공시제목     제출인
# 0                                    부도발생및은행거래정지    정산애강
# 1                                         은행거래재개   대호특수강
# 2                                     회사정리절차종결결정   에이치엘비
# 3                                     회사정리절차종결신청   에이치엘비
# 4                                     회사정리절차개시결정   대호특수강
# ..                                           ...     ...
# 95                  내부결산시점 관리종목 지정 또는 상장폐지 사유 발생  에스앤더블류
# 96                  내부결산시점 관리종목 지정 또는 상장폐지 사유 발생     파나진
# 97               내부결산시점 관리종목 지정 또는 상장폐지 사유 발생[정]     국순당
# 98                  내부결산시점 관리종목 지정 또는 상장폐지 사유 발생    유아이디
# 99  내부결산시점 관리종목 지정 또는 상장폐지 사유 발생(자회사의 주요경영사항)[정]     이녹스
#
# [394 rows x 6 columns]

# %%
bankrupt_df.to_csv('../../Data/kind_bankrupt.csv', encoding="utf-8-sig")

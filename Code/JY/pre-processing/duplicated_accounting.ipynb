# %%
import pandas as pd

# %%
### 주의) 데이터에 '시간 column' 추가해서 살펴볼 것 

train = pd.read_csv(r'C:\Users\qorwl\Desktop\Ubion-CorporateBankruptcyAnalysis\Data\데이터정리중\결측지마무리.csv', index_col = 0)
#train_part = pd.read_csv(r'C:\Users\qorwl\Desktop\Ubion-CorporateBankruptcyAnalysis\Data\데이터정리중\결측지마무리.csv', usecols = ['회사명','거래소코드','회계년도','소속코드','상장폐지일','key'])

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 27357 entries, 0 to 27356
# Columns: 271 entries, 회사명 to 부도
# dtypes: float64(265), int64(1), object(5)
# memory usage: 56.8+ MB

# %%
# 컬럼 전체 살펴보기
for i in range(271): 
    print(train.columns[i])
# Out:
# 회사명
# 거래소코드
# 회계년도
# 소속코드
# 상장폐지일
# 감사의견코드
# 자산총계(요약)
# 유동자산(요약)
# 당좌자산(요약)
# 현금 및 현금성자산(요약)
# 단기투자자산(요약)
# 단기예금(요약)
# 단기매매증권(요약)
# 단기대여금(요약)
# 기타단기투자자산(요약)
# 매출채권(요약)
# *할인어음 또는 배서어음(요약)
# 기타당좌자산(요약)
# 재고자산(요약)
# 상품(요약)
# 제품(요약)
# 반제품(요약)
# 재공품(요약)
# 원재료(요약)
# 기타재고자산(요약)
# 임대주택자산(요약)
# 비유동자산(요약)
# 투자자산(요약)
# *장기금융상품(요약)
# *투자유가증권(장기투자증권)(요약)
# 유형자산(요약)
# 토지
# 건설중인자산
# 건물
# 기계장치
# 차량운반구
# 렌탈자산
# 설비자산
# 무형자산(요약)
# 기타비유동자산(요약)
# 이연자산(요약)
# 부채총계(요약)
# 유동부채(요약)
# 매입채무(요약)
# 단기차입금(요약)
# 유동성장기부채(요약)
# 기타유동부채(요약)
# 비유동부채(요약)
# 사채(요약)
# 장기차입금(요약)
# 제충당금(요약)
# 기타비유동부채(요약)
# 이연부채(요약)
# 자본총계(요약)
# 자본금(요약)
# 자본잉여금(요약)
# 자본조정(요약)
# 기타포괄손익누계액(요약)
# 이익잉여금(요약)
# *미처분이익잉여금 및 차기이월미처분이익잉여금(요약)
# *당기순이익(요약)
# 부채와자본총계(요약)
# 매출액(요약)
# 매출원가(요약)
# 매출총이익(요약)
# 판매비와 관리비(요약)
# 급료
# 퇴직급여(요약)
# 복리후생비(요약)
# 세금과공과(요약)
# 임차료(요약)
# 감가상각비
# 연구비
# 기타 판매비와 관리비(요약)
# 영업이익(요약)
# 영업외수익(요약)
# 이자수익(요약)
# 배당금수익(요약)
# 외환차익(요약)
# 외화환산이익(요약)
# 지분법이익(요약)
# 기타영업외수익(요약)
# 영업외비용(요약)
# 이자비용(요약)
# 외환차손(요약)
# 외화환산손실(요약)
# 지분법손실(요약)
# ...

# %%
train['공시제목'].astype
# Out:
# <bound method NDFrame.astype of 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 27352    0
# 27353    0
# 27354    0
# 27355    0
# 27356    0
# Name: 공시제목, Length: 27357, dtype: object>

# %%
train.loc[train['공시제목'] != '0' ,'회사명'].unique()
# Out:
# array(['(주)국순당', '(주)나노트로닉스', '(주)나리지*온', '(주)단성일렉트론', '(주)대성엘텍',
#        '(주)대호특수강', '(주)더블유아이', '(주)디보스', '(주)디아이디', '(주)디에스피이엔티',
#        '(주)디지텍시스템스', '(주)리드', '(주)릭스솔루션', '(주)마이스코', '(주)매직마이크로',
#        '(주)메디콕스', '(주)모린스', '(주)미성포리테크', '(주)바른전자', '(주)바이오빌', '(주)보광티에스',
#        '(주)블루젬디앤씨', '(주)비앤비성원', '(주)비츠로시스', '(주)삼우이엠씨', '(주)삼표시멘트',
#        '(주)샤인시스템', '(주)세븐코스프', '(주)솔고바이오메디칼', '(주)스카이문스테크놀로지', '(주)스틸플라워',
#        '(주)시너지이노베이션', '(주)신양오라컴디스플레이', '(주)쌈지', '(주)썬코어', '(주)쎄니트',
#        '(주)씨모텍', '(주)씨앤케이인터내셔널', '(주)씨에스에이코스믹', '(주)씨엔플러스', '(주)씨엘인터내셔널',
#        '(주)씨유전자', '(주)씨티앤티', '(주)아라온테크', '(주)아리온테크놀로지', '(주)아이디에스',
#        '(주)아이디에이치', '(주)아이비진', '(주)아이앤씨테크놀로지', '(주)아이에이', '(주)아이엠텍',
#        '(주)아이팩토리', '(주)아큐텍', '(주)알톤스포츠', '(주)에스디시스템', '(주)에스마크',
#        '(주)에스비엠', '(주)에스앤더블류', '(주)에스에스컴텍', '(주)에스에프씨', '(주)에이디칩스',
#        '(주)에이제이에스', '(주)에이프로테크놀로지', '(주)에피밸리', '(주)엔스퍼트', '(주)엔에스브이',
#        '(주)엔케이바이오', '(주)엘아이에스', '(주)엘앤씨피', '(주)엠엔에프씨', '(주)엠투엔',
# ...

# %%
len(train.loc[train['공시제목'] != '0' ,'회사명'].unique())
# Out:
# 155

# %% [markdown]
# # **동일회계년도에 회계보고서 중복제출**

# %%
train_duplicated_info = train.duplicated(subset=['key'], keep=False)
train_duplicated = train.loc[train_duplicated_info, :]
train_duplicated
# Out:
#                 회사명    거래소코드     회계년도  소속코드       상장폐지일 감사의견코드  자산총계(요약)  \
# 318          (주)국순당  43650.0  2019/12   5.0           0     UQ  210007.0
# 319          (주)국순당  43650.0  2019/12   5.0           0     UQ  210007.0
# 320          (주)국순당  43650.0  2019/12   5.0           0     UQ  210007.0
# 590        (주)나리지*온  36850.0  2006/12   4.0  2010/07/14     UQ   35220.0
# 591        (주)나리지*온  36850.0  2006/12   4.0  2010/07/14     UQ   35220.0
# ...             ...      ...      ...   ...         ...    ...       ...
# 27109  현대바이오사이언스(주)  48410.0  2005/12   5.0           0     UQ  161420.0
# 27110  현대바이오사이언스(주)  48410.0  2005/12   5.0           0     UQ  161420.0
# 27231       현진소재(주)  53660.0  2019/12   6.0           0     DU  133965.0
# 27232       현진소재(주)  53660.0  2019/12   6.0           0     DU  133965.0
# 27233       현진소재(주)  53660.0  2019/12   6.0           0     DU  133965.0
#
#        유동자산(요약)  당좌자산(요약)  현금 및 현금성자산(요약)  ...   기업가치(EV)    EBITDA  \
# ...

# %%
train_duplicated['회사명'].unique()
# Out:
# array(['(주)국순당', '(주)나리지*온', '(주)대성엘텍', '(주)대호특수강', '(주)더블유아이', '(주)디보스',
#        '(주)디아이디', '(주)디지텍시스템스', '(주)리드', '(주)릭스솔루션', '(주)마이스코',
#        '(주)매직마이크로', '(주)메디콕스', '(주)모린스', '(주)미성포리테크', '(주)바른전자',
#        '(주)바이오빌', '(주)비츠로시스', '(주)삼표시멘트', '(주)서진시스템', '(주)솔고바이오메디칼',
#        '(주)시너지이노베이션', '(주)신양오라컴디스플레이', '(주)씨모텍', '(주)씨앤케이인터내셔널',
#        '(주)씨에스에이코스믹', '(주)씨엔플러스', '(주)씨티앤티', '(주)아리온테크놀로지', '(주)아이디에스',
#        '(주)아이디에이치', '(주)아이엠텍', '(주)에스마크', '(주)에스비엠', '(주)에스에스컴텍',
#        '(주)에스에프씨', '(주)에이제이에스', '(주)에피밸리', '(주)엔스퍼트', '(주)엔에스브이',
#        '(주)엘앤씨피', '(주)영진코퍼레이션', '(주)오리엔탈정공', '(주)와이즈파워', '(주)우전',
#        '(주)유일엔시스', '(주)이녹스', '(주)이엠네트웍스', '(주)이엠따블유', '(주)이엠앤아이',
#        '(주)제낙스', '(주)지티앤티', '(주)케너텍', '(주)케이에스피', '(주)코데즈컴바인', '(주)코세스',
#        '(주)티에스엠텍', '(주)파워넷', '(주)포이보스', '(주)프리젠', '(주)플렉스컴', '(주)피엘에이',
#        '(주)하이드로젠파워', '(주)한진피앤씨', '(주)한프', '(주)행남사', '(주)화진', '(주)휴온스블러썸',
#        '나노스(주)', '동양텔레콤(주)', '동화기업(주)', '디에스티(주)', '레이젠(주)', '미리넷(주)',
# ...

# %%
len(train_duplicated['회사명'].unique())
# Out:
# 90

# %%
import pandas as pd

train = pd.read_csv(r'C:\Users\qorwl\Desktop\Ubion-CorporateBankruptcyAnalysis\Data\데이터정리중\재무변수_부도이유.csv', index_col='Unnamed: 0')

# %%
train
# Out:
#             회사명    거래소코드     회계년도  소속코드 상장폐지일 감사의견코드  자산총계(요약)  유동자산(요약)  \
# 0      (주)CMG제약  58820.0  2000/12   5.0   NaN     UQ   28990.0   21169.0
# 1      (주)CMG제약  58820.0  2001/12   5.0   NaN     UQ   20908.0   16359.0
# 2      (주)CMG제약  58820.0  2002/12   5.0   NaN     UQ   15401.0    9880.0
# 3      (주)CMG제약  58820.0  2003/12   5.0   NaN     UQ   11063.0    8534.0
# 4      (주)CMG제약  58820.0  2004/12   5.0   NaN     UQ    5179.0    3893.0
# ...         ...      ...      ...   ...   ...    ...       ...       ...
# 27374       NaN      NaN      NaN   NaN   NaN    NaN       NaN       NaN
# 27375       NaN      NaN      NaN   NaN   NaN    NaN       NaN       NaN
# 27376       NaN      NaN      NaN   NaN   NaN    NaN       NaN       NaN
# 27377       NaN      NaN      NaN   NaN   NaN    NaN       NaN       NaN
# 27378       NaN      NaN      NaN   NaN   NaN    NaN       NaN       NaN
#
#        당좌자산(요약)  현금 및 현금성자산(요약)  ...  PSR(Price sales ratio)(최저)  기업가치(EV)  \
# ...

# %% [markdown]
# ### **회사명 NaN 제거**

# %%
train.dropna(subset=['회사명'], axis = 0, inplace=True)

# %%
train
# Out:
#             회사명    거래소코드     회계년도  소속코드 상장폐지일 감사의견코드  자산총계(요약)  유동자산(요약)  \
# 0      (주)CMG제약  58820.0  2000/12   5.0   NaN     UQ   28990.0   21169.0
# 1      (주)CMG제약  58820.0  2001/12   5.0   NaN     UQ   20908.0   16359.0
# 2      (주)CMG제약  58820.0  2002/12   5.0   NaN     UQ   15401.0    9880.0
# 3      (주)CMG제약  58820.0  2003/12   5.0   NaN     UQ   11063.0    8534.0
# 4      (주)CMG제약  58820.0  2004/12   5.0   NaN     UQ    5179.0    3893.0
# ...         ...      ...      ...   ...   ...    ...       ...       ...
# 27352   흥구석유(주)  24060.0  2016/12   5.0   NaN     UQ   79137.0   14794.0
# 27353   흥구석유(주)  24060.0  2017/12   5.0   NaN     UQ   79912.0   15880.0
# 27354   흥구석유(주)  24060.0  2018/12   5.0   NaN     UQ   75206.0   12515.0
# 27355   흥구석유(주)  24060.0  2019/12   5.0   NaN     UQ   83661.0   22620.0
# 27356   흥구석유(주)  24060.0  2020/12   5.0   NaN     UQ   83721.0   27688.0
#
#        당좌자산(요약)  현금 및 현금성자산(요약)  ...  PSR(Price sales ratio)(최저)   기업가치(EV)  \
# ...

# %% [markdown]
# ### **부도컬럼 생성**

# %% [markdown]
# 감사의견거절 감사보고서 부적정, 의견거절, 범위제한한정
# - 의견코드 : AG, DS, DI, DU, QS

# %%
# train['부도'] = ""

# %%
train[['소속코드','감사의견코드','공시제목']]
# Out:
#        소속코드 감사의견코드 공시제목
# 0       5.0     UQ  NaN
# 1       5.0     UQ  NaN
# 2       5.0     UQ  NaN
# 3       5.0     UQ  NaN
# 4       5.0     UQ  NaN
# ...     ...    ...  ...
# 27352   5.0     UQ  NaN
# 27353   5.0     UQ  NaN
# 27354   5.0     UQ  NaN
# 27355   5.0     UQ  NaN
# 27356   5.0     UQ  NaN
#
# [27357 rows x 3 columns]

# %%
train['소속코드'].value_counts()
# Out:
# 5.0    20347
# 4.0     5436
# 6.0     1574
# Name: 소속코드, dtype: int64

# %%
train['감사의견코드'].value_counts()
# Out:
# UQ    26182
# DU      232
# QS      123
# DS      123
# QU      114
# QG       42
# AG       15
# NS       11
# QQ        2
# Name: 감사의견코드, dtype: int64

# %%
# con1 = train['소속코드'] == '4.0'
# con2 = [(train['감사의견코드'] == 'DS')|(train['감사의견코드'] =='DI')|(train['감사의견코드'] =='DU')|(train['감사의견코드'] =='AG')|(train['감사의견코드'] =='QS')]
# con3 = train['공시제목'] != 'NaN'

# %%
train['부도'] = train.loc[train['공시제목'] != 'NaN', '부도'] = 1

# %%
train['부도'].value_counts()
# Out:
# 1    27357
# Name: 부도, dtype: int64

# %%
train.isnull().sum()[1]
# Out:
# 22

# %%
for i in range(270):
    print(train.columns[i], train.isnull().sum()[i])
# Out:
# 회사명 22
# 거래소코드 22
# 회계년도 22
# 소속코드 22
# 상장폐지일 21943
# 감사의견코드 535
# 자산총계(요약) 355
# 유동자산(요약) 355
# 당좌자산(요약) 355
# 현금 및 현금성자산(요약) 355
# 단기투자자산(요약) 355
# 단기예금(요약) 355
# 단기매매증권(요약) 355
# 단기대여금(요약) 355
# 기타단기투자자산(요약) 355
# 매출채권(요약) 355
# *할인어음 또는 배서어음(요약) 355
# 기타당좌자산(요약) 355
# 재고자산(요약) 355
# 상품(요약) 355
# 제품(요약) 355
# 반제품(요약) 355
# 재공품(요약) 355
# 원재료(요약) 355
# 기타재고자산(요약) 355
# 임대주택자산(요약) 355
# 비유동자산(요약) 355
# 투자자산(요약) 355
# *장기금융상품(요약) 355
# *투자유가증권(장기투자증권)(요약) 355
# 유형자산(요약) 355
# 토지 355
# 건설중인자산 355
# 건물 355
# 기계장치 355
# 차량운반구 355
# 렌탈자산 355
# 설비자산 355
# 무형자산(요약) 355
# 기타비유동자산(요약) 355
# 이연자산(요약) 355
# 부채총계(요약) 355
# 유동부채(요약) 355
# 매입채무(요약) 355
# 단기차입금(요약) 355
# 유동성장기부채(요약) 355
# 기타유동부채(요약) 355
# 비유동부채(요약) 355
# 사채(요약) 355
# 장기차입금(요약) 355
# 제충당금(요약) 355
# 기타비유동부채(요약) 355
# 이연부채(요약) 355
# 자본총계(요약) 355
# 자본금(요약) 355
# 자본잉여금(요약) 355
# 자본조정(요약) 355
# 기타포괄손익누계액(요약) 355
# 이익잉여금(요약) 355
# *미처분이익잉여금 및 차기이월미처분이익잉여금(요약) 355
# *당기순이익(요약) 355
# 부채와자본총계(요약) 355
# 매출액(요약) 355
# 매출원가(요약) 355
# ...

# %%
train[['매출액영업이익률', '매출액경상이익률 (2007년 이전 발생)']].transpose()
# Out:
#                         0      1      2      3      4      5       6      \
# 매출액영업이익률                  NaN   1.86 -14.46  -5.26 -21.69 -47.66  -35.59
# 매출액경상이익률 (2007년 이전 발생)    NaN   0.71    NaN   0.89 -23.99 -61.11 -102.58
#
#                         7      8      9      ...  27369  27370  27371  27372  \
# 매출액영업이익률                -74.3 -35.02 -85.24  ...    NaN    NaN    NaN    NaN
# 매출액경상이익률 (2007년 이전 발생)    NaN   0.00   0.00  ...    NaN    NaN    NaN    NaN
#
#                         27373  27374  27375  27376  27377  27378
# 매출액영업이익률                  NaN    NaN    NaN    NaN    NaN    NaN
# 매출액경상이익률 (2007년 이전 발생)    NaN    NaN    NaN    NaN    NaN    NaN
#
# [2 rows x 27379 columns]

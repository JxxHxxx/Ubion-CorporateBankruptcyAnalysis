# %%
import pandas as pd

# %%
data = pd.read_csv('C:/Users/qorwl/Desktop/Ubion-CorporateBankruptcyAnalysis/Data/재무데이터 최종.csv', encoding = 'utf-8')

# %%
data.head()
# Out:
#    Unnamed: 0       회사명  거래소코드     회계년도  총자본증가율  유형자산증가율  유동자산증가율  영업이익증가율  \
# 0           0  (주)CMG제약  58820  2000/12     NaN      NaN      NaN      NaN
# 1           1  (주)CMG제약  58820  2001/12    0.00     0.00     0.00      0.0
# 2           2  (주)CMG제약  58820  2002/12  -26.34   -17.72   -39.61      0.0
# 3           3  (주)CMG제약  58820  2003/12  -28.17   -79.37   -13.62      0.0
# 4           4  (주)CMG제약  58820  2004/12  -53.18   -25.94   -54.38      0.0
#
#    경상이익증가율 (2007년 이전 발생)  순이익증가율  ...  자본잉여금(요약)  자본조정(요약)  기타포괄손익누계액(요약)  \
# 0                    NaN     NaN  ...        NaN       NaN            NaN
# 1                   0.00     0.0  ...        NaN       NaN            NaN
# 2                    NaN     0.0  ...        NaN       NaN            NaN
# 3                   0.00     0.0  ...        NaN       NaN            NaN
# 4               -2128.48     0.0  ...        NaN       NaN            NaN
#
# ...

# %%
data.shape
# Out:
# (27059, 294)
